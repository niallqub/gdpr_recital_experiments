# %%
import ollama
import json
import pandas as pd
import datetime
import chromadb
from deepeval.dataset import EvaluationDataset
from deepeval.test_case import LLMTestCase, LLMTestCaseParams
import numpy as np

# %%
# Define the function to extract regulatory data
def extract_regulatory_data(regulatory_text):
    prompt = f"""
You are an expert in the legal domain and computational linguistics. Follow these steps strictly:

1. Convert passive voice input sentences into active voice.
2. Break down the input into syntactic parts following the schema precisely.
3. Before categorizing any part, explicitly verify: "Can this logically belong to this category based on provided markers?" If yes, categorize it; if not, do not categorize it.
4. Use schema markers ONLY as hints; do NOT include markers in the final JSON output.

Schema:
{{
    "Type": ["Definition", "Prohibition", "Obligation", "Fact", "Penalty", "Permission", "Recommendation", "Exemption"],
    "Action": "VP excluding modality, condition, exception, and reason annotations",
    "Condition": ["SRel << (condition marker)", "PP << (condition marker)", "Ssub << (condition marker)", "NP < (VPinf !<< (exception marker) !<< (reason marker))", "NP < (VPart !<< (exception marker) !<< (reason marker))"],
    "Condition Marker": ["if", "in case of", "provided that", "when", "in the context of", "limit", "who", "whose", "which"],
    "Modality": ["VN < (modality marker)"],
    "Modality Marker": ["may", "must", "is prohibited from", "should", "shall", "can", "need to", "required to", "is authorized to"],
    "Actor": ["subject dependency and NP < (actor marker)", "object dependency and passive voice and PP < P $ (NP < (actor marker))", "object dependency and active voice and NP < (actor marker)"],
    "Actor Marker": ["firm", "expert", "staff", "company", "consumer", "tax"],
    "Artifact": ["NP < (artifact marker)", "NP !<< (violation marker) | !<< (time marker) | !<< (situation marker) | !<< (sanction marker) | !<< (reference marker) | !<< (location marker) | !<< (action marker)"],
    "Artifact Marker": ["document", "agreement", "certificate", "license", "permit", "warrant", "pass"],
    "Exception": ["Srel << (exception marker)", "Ssub << (exception marker)", "NP < (VPinf !<< (exception marker))", "PP << (exception marker)", "NP << (P < (exception marker) $ VPinf)"],
    "Exception Marker": ["with the exception of", "except for", "derogation", "apart from", "other than"],
    "Presence": ["NP < (location marker)"],
    "Presence Marker": ["site", "place", "target market", "customer base", "street"],
    "Reason": ["Srel << (reason marker)", "Ssub << (reason marker)", "PP << (reason marker)", "NP < (VPart << (reason marker))", "NP << (P < (reason marker) $ VPinf)"],
    "Reason Marker": ["in order to", "for the purpose of", "so as to", "so that", "in the interest of", "in view of"],
    "Sanction": ["NP < (sanction marker)"],
    "Sanction Marker": ["punishment", "jail sentence", "imprisonment", "prison term", "fine"],
    "Situation": ["NP < (situation marker)"],
    "Situation Marker": ["renewal", "inspection", "registration", "deliberation"],
    "Time": ["NP < (time marker)", "PP < (P < (time marker)) $ NP"],
    "Time Marker": ["before", "after", "temporary", "permanent", "period", "day", "year", "month", "date"],
    "Violation": ["NP < (violation marker)"],
    "Violation Marker": ["offence", "crime", "misdemeanor", "civil wrong", "infraction", "transgression"]
}}

Sample:
'Input': 'Firms should be able to provide us with the information they are using to monitor whether they are achieving outcomes for consumers with characteristics of vulnerability that are as good as those for other consumers (see monitoring and evaluation in Chapter 5).',
  'JSON': 
    'Type': 'Obligation',
    'Actor': 'Firm',
    'Modality': 'should',
    'Action': 'be able to provide us with the information they are using',
    'Reason': 'to monitor whether they are achieving outcomes as good as those for other consumers',
    'Condition': 'for consumers with characteristics of vulnerability',
    'Artifact': 'monitoring and evaluation in Chapter 5',
    'Violation': null,
    'Exception': null,
    'Presence': null,
    'Time': null,
  
 'Input': 'Where possible, staff should be able to respond to the consumer’s needs promptly so that action is taken to ensure harm does not occur or become more severe.',
  'JSON': 
    'Type': 'Obligation',
    'Actor': 'Staff',
    'Modality': 'should',
    'Action': "respond to the consumer\'s needs promptly",
    'Reason': 'action is taken to ensure harm does not occur or become more severe',
    'Condition': 'where possible',
    'Artifact': null,
    'Violation': null,
    'Exception': null,
    'Presence': null,
    'Time': null,
 'Input': 'Firms should improve the skills and capability of staff in a way that is proportionate.',
  'JSON': 
    'Type': 'Obligation',
    'Actor': 'Firm',
    'Modality': 'should',
    'Action': 'improve the skills and capability of staff',
    'Reason': null,
    'Condition': 'in a way that is proportionate',
    'Artifact': null,
    'Violation': null,
    'Exception': null,
    'Presence': null,
    'Time': null,
 'Input': 'If a firm’s business model intentionally exploits vulnerable consumers, this would be a clear breach of our Principles.',
  'JSON': 
    'Type': 'Prohibition',
    'Actor': 'Firm’s business model',
    'Modality': 'if',
    'Action': 'intentionally exploits vulnerable consumers',
    'Reason': null,
    'Condition': null,
    'Artifact': null,
    'Violation': 'breach of our Principles',
    'Exception': null,
    'Presence': null,
    'Time': null,
 'Input': 'Firms should ensure they record and process data in line with requirements of data protection legislation, see Appendix 1.',
  'JSON': 
    'Type': 'Obligation',
    'Actor': 'Firm',
    'Modality': 'should',
    'Action': 'ensure they record and process data in line with requirements of data protection legislation',
    'Reason': null,
    'Condition': null,
    'Artifact': 'Appendix 1',
    'Violation': null,
    'Exception': null,
    'Presence': null,
    'Time': null,



Return strictly structured JSON adhering to the schema above, excluding the markers themselves.

Input:
"{regulatory_text}"

JSON:
    """

    # Generate response from Llama model via Ollama
    response = ollama.generate(model="llama3:8b", prompt=prompt, format="json")

    # Parse and return JSON output
    return json.loads(response["response"])

# Example usage:
regulation_example = """Under Article 5(1)(d) firms should take care to ensure the accuracy of information they record about customers and vulnerabilities. This may be challenging for firms where vulnerabilities are temporary, and firms should consider this in the context of the customer service they provide."""

structured_data = extract_regulatory_data(regulation_example)

print(json.dumps(structured_data, indent=2))
# Out:
# {
#   "Type": "Obligation",
#   "Action": "take care to ensure the accuracy of information they record about customers and vulnerabilities",
#   "Condition": null,
#   "Reason": null,
#   "Actor": "Firm",
#   "Modality": "should",
#   "Artifact": null,
#   "Violation": null,
#   "Exception": null,
#   "Presence": null,
#   "Time": null
# }

# %%
#gdpr_articles_json_filename = 'Output/gdpr_articles_24_43_qa_output.json'
gdpr_articles_json_filename = 'Output/gdpr_chapter4_recital_qa_correct_output.json'

with open(gdpr_articles_json_filename) as json_file:
    article_json_data = json.load(json_file)
print(len(article_json_data))

statements_all =[]
for article in article_json_data:
    statements_all.append(article['InputText'])

print(len(statements_all))
# Out:
# 46
# 46

# %%
import pandas as pd
import datetime
#data = pd.read_excel("data/GDPR_Obligation_Output.xlsx")
#statements_all = data["Text"].tolist()

#data = pd.read_csv('data/cejas_dpa_compliance_req.txt', sep="\t", header=None)
#data.columns = ["Statement"]

#data = pd.read_excel("data/Generated_Ontology_GDPR_Output.xlsx")
#statements_all = data["Statement"].tolist()

import pandas as pd

def is_valid_output(json_output):
    required_fields = ["Type", "Actor", "Action"]
    for field in required_fields:
        if not json_output.get(field):
            return False
    return True

knowledge_graph = []
#statements = statements_all[:50]
statements = statements_all

for index,text in enumerate(statements):
    now = datetime.datetime.now()
    
    print(now.time())
    print(index)
    print(text)
    retries = 3
    json_output = None
    while retries > 0:
        json_output = extract_regulatory_data(text)
        if is_valid_output(json_output):
            break
        retries -= 1
    print(json_output)
    
    if json_output:
        json_output["InputText"] = text  # Add the original text to the JSON output
        knowledge_graph.append(json_output)

# %%
# Save the knowledge graph to a JSON file
#output_json_filename = "Output/my_knowledge_graph_output.json"
#output_json_filename = "Output/cejas_dpa_compliance_graph_output.json"

#output_json_filename = "Output/gdpr_articles_24_43_kg_output.json"
output_json_filename = "Output/gdpr_chapter4_recital_kg_output.json"

with open(output_json_filename, 'w') as json_file:
    json.dump(knowledge_graph, json_file, indent=4)

print(f"Knowledge graph saved to {output_json_filename}")

# Convert the knowledge graph to a DataFrame and save to an Excel file
df = pd.DataFrame(knowledge_graph)
# Reorder columns to have 'InputText' as the first column
columns = ["InputText"] + [col for col in df.columns if col != "InputText"]
df = df[columns]

print(columns)

#output_excel_filename = "Output/cejas_dpa_compliance_graph_output.xlsx"

#output_excel_filename = "Output/my_knowledge_graph_output.xlsx"

#output_excel_filename = "Output/gdpr_articles_24_43_kg_output.xlsx"
output_excel_filename = "Output/gdpr_chapter4_recital_kg_output.xlsx"

df.to_excel(output_excel_filename, index=False)

print(f"Knowledge graph saved to {output_excel_filename}")
# Out:
# Knowledge graph saved to Output/gdpr_chapter4_recital_kg_output.json
# ['InputText', 'Type', 'Actor', 'Modality', 'Action', 'Reason', 'Condition', 'Artifact', 'Violation', 'Exception', 'Presence', 'Time', 'Condition Marker', 'JSON', 'Situation', 'Sanction', 'Violations', 'Exceptions']
# Knowledge graph saved to Output/gdpr_chapter4_recital_kg_output.xlsx

# %%
data = pd.read_excel("Output/gdpr_articles_24_43_kg_output_corrected.xlsx")
# one more entry in the following txt as noticed as indvidual sentence at the end of recital 86 with no qa but seems an obligation
#data = pd.read_excel("Output/gdpr_chapter4_recital_kg_output_corrected.xlsx")

statements_all = data["InputText"].tolist()
print(len(statements_all))


    # Iterate over each row and generate the improved statement
for index,kg_row in enumerate(data.iterrows()):
        
        kg_row = kg_row[1]  # Extract the row data
        modality = kg_row['Modality']
    
        print("index:%d %s" %(index,kg_row['Sanction']))
        artifact = kg_row['Artifact']
        artifact = str(artifact)

        continue
    
        if not artifact== 'nan':
            print(artifact)
            
            art_list = re.split(r"[\,|\[|\]]",artifact)

            for art in art_list:
                art=  art.strip()
                if len(art)>0:
                    print(art)
        if index> 1:
            break

# %%
import ollama
import json

def generate_question_answer(context):
    empty_result= "{}"
    try:

        
        messages = f'''
            Your task is to generate realistic and applied questions that pertain to the provided regulatory or compliance material. Ensure that the context explicitly contains the answer to the question and the question should not expect a binary answer. the answer should be concise"
            Each single question and answer into a valid JSON format. Each JSON should contain a single question with a single answer. Only respond with valid JSON and no additional text. Test the JSON for validity before returning it.
        Input:
        "{context}"
        '''

        response = ollama.generate(model="llama3:8b", prompt=messages,format="json")

        return json.loads(response["response"])

        #question_list = chat_completion.choices[0].message.content.strip().split('\n')
        #questions = [re.sub(r'^\d+\.\s+', '', q).strip() for q in question_list if q.strip().endswith('?')]
    except Exception as e:
        print(f"An error occurred: {e}")
        time.sleep(20)
    return json.loads(empty_result)

# %%
# Example usage:
regulation_example = """The processing of personal data should be designed to serve mankind. The right to the protection of personal data is not an absolute right; it must be considered in relation to its function in society and be balanced against other fundamental rights, in accordance with the principle of proportionality."""

structured_data = generate_question_answer(regulation_example)

print(json.dumps(structured_data, indent=2))
# Out:
# {
#   "question": "What is the purpose of processing personal data according to this regulatory material?",
#   "answer": "The processing of personal data should be designed to serve mankind."
# }

# %%
import pandas as pd
import datetime

data = pd.read_excel("data/Generated_Ontology_GDPR_Output.xlsx")
obligations_all = data[data.Type=="['Obligation']"]

print(len(obligations_all))
# Out:
# 409

# %%
use_sentences=False
if use_sentences:
    #obligations_all = pd.read_csv('data/gdpr_articles_sentences_clean.txt', sep="\t", header=None)
    # article sentences related to controller and processor
    #obligations_all = pd.read_csv('data/gdpr_articles_24_43_sentences_clean.txt', sep="\t", header=None)
  
    obligations_all = pd.read_csv('data/gdpr_recitals_sentences_clean.txt', sep="\t", header=None)
else:
    
    #obligations_all = pd.read_csv('data/gdpr_articles_clean.txt', sep="\t", header=None)
    obligations_all = pd.read_csv('data/gdpr_recitals.txt', sep="\t", header=None)
    
obligations_all.columns = ["Statement"]
print(len(obligations_all))
# Out:
# 173

# %%
import random
statements_all = obligations_all["Statement"].tolist()



def is_valid_output(json_output):
    required_fields = ["question", "answer"]
    for field in required_fields:
        if not json_output.get(field):
            return False
    return True

question_answers = []
if use_sentences:
    # shuffle sentences
    #random.shuffle(statements_all)
    #statements = statements_all[:50]
    statements = statements_all
else:
    statements = statements_all
    #statements = statements_all[:173]

current_article =''
current_recital = '1'
process_recitals = True

for index,text in enumerate(statements):
    now = datetime.datetime.now()

    current_recital = str(index+1)
    #if index==100:
    #    break
        
    print("%d %s" %(index,now.time()))
    print(text)
    print(current_recital)

    if text.startswith("Article"):
        current_article = text.split(" ")[1]
    print(current_article)     
        
    # skip certain lines in gdpr articles
    if text== '\n' or text == '' or text.startswith("Article") or text.startswith("CHAPTER") or text.startswith("Section"):
        continue
        
    retries = 3
    json_output = None
    while retries > 0:
        
        json_output = generate_question_answer(text)
        if is_valid_output(json_output):
            break
        retries -= 1
    print(json_output)
    
    if json_output:
        #json_output["InputText"] = text  # Add the original text to the JSON output
        json_output["InputText"] = text.replace(u"\u2018", "'").replace(u"\u2019", "'")  # change unicode chars for quotes
        if process_recitals:
            json_output["Recital"] = current_recital
        else:    
            json_output["Article"] = current_article
        question_answers.append(json_output)

# Save the knowledge graph to a JSON file
#output_json_filename = "Output/obligation_question_answer_output.json"
if use_sentences:
    output_json_filename = "Output/gdpr_recital_sentences_question_answer_output.json"
    #output_json_filename = "Output/gdpr_articles_sentences_question_answer_output.json"
    #output_json_filename = "Output/gdpr_articles_24_43_sentences_question_answer_output.json"
   
    
else:    
    output_json_filename = "Output/gdpr_recital_question_answer_output.json"
    #output_json_filename = "Output/gdpr_articles_question_answer_output.json"

with open(output_json_filename, 'w') as json_file:
    json.dump(question_answers, json_file, indent=4)

print(f"obligations question answer  saved to {output_json_filename}")

# %%
samples =f'''

        'Input':
        "Public authorities to which personal data are disclosed in accordance with a legal obligation for the exercise of their official mission, such as tax and customs authorities, financial investigation units, independent adminis\u00ad trative authorities, or financial market authorities responsible for the regulation and supervision of securities markets should not be regarded as recipients if they receive personal data which are necessary to carry out a particular inquiry in the general interest, in accordance with Union or Member State law. The requests for disclosure sent by the public authorities should always be in writing, reasoned and occasional and should not concern the entirety of a filing system or lead to the interconnection of filing systems. The processing of personal data by those public authorities should comply with the applicable data-protection rules according to the purposes of the processing"

        'JSON':
        {
        "question": "What type of public authorities are exempt from being considered recipients if they receive personal data necessary for a particular inquiry?",
        "answer": "Tax and customs authorities, financial investigation units, independent administrative authorities, or financial market authorities responsible for the regulation and supervision of securities markets" 
        }
        'Input': 
        "In the absence of an adequacy decision, the controller or processor should take measures to compensate for the lack of data protection in a third country by way of appropriate safeguards for the data subject. Such appropriate safeguards may consist of making use of binding corporate rules, standard data protection clauses adopted by the Commission, standard data protection clauses adopted by a supervisory authority or contractual clauses authorised by a supervisory authority. Those safeguards should ensure compliance with data protection requirements and the rights of the data subjects appropriate to processing within the Union, including the availability of enforceable data subject rights and of effective legal remedies, including to obtain effective adminis\u00ad trative or judicial redress and to claim compensation, in the Union or in a third country. They should relate in particular to compliance with the general principles relating to personal data processing, the principles of data protection by design and by default. Transfers may also be carried out by public authorities or bodies with public authorities or bodies in third countries or with international organisations with corresponding duties or functions, including on the basis of provisions to be inserted into administrative arrangements, such as a memorandum of understanding, providing for enforceable and effective rights for data subjects. Authorisation by the competent supervisory authority should be obtained when the safeguards are provided for in administrative arrangements that are not legally binding."
        'JSON':
        {
        "question": "What types of safeguards can a controller or processor use to compensate for the lack of an adequacy decision when transferring personal data to a third country?",
        "answer": "Binding corporate rules, standard data protection clauses adopted by the Commission, standard data protection clauses adopted by a supervisory authority, contractual clauses authorised by a supervisory authority"
        }
        'Input':
        "The decision should be agreed jointly by the lead supervisory authority and the supervisory authorities concerned and should be directed towards the main or single establishment of the controller or processor and be binding on the controller and processor. The controller or processor should take the necessary measures to ensure compliance with this Regulation and the implementation of the decision notified by the lead supervisory authority to the main establishment of the controller or processor as regards the processing activities in the Union."
        'JSON':
        {
        "question": "What is the process for agreeing on a decision regarding a data controller or processor?",
        "answer": "The decision should be agreed jointly by the lead supervisory authority and the supervisory authorities concerned."
        }

        
        '''
        samples =f'''
        "question": "What type of public authorities are exempt from being considered recipients if they receive personal data necessary for a particular inquiry?"
        "answer": "Tax and customs authorities, financial investigation units, independent administrative authorities, or financial market authorities responsible for the regulation and supervision of securities markets" 
         "question": "What types of safeguards can a controller or processor use to compensate for the lack of an adequacy decision when transferring personal data to a third country?"
        "answer": "Binding corporate rules, standard data protection clauses adopted by the Commission, standard data protection clauses adopted by a supervisory authority, contractual clauses authorised by a supervisory authority"
        "question": "What is the process for agreeing on a decision regarding a data controller or processor?"
        "answer": "The decision should be agreed jointly by the lead supervisory authority and the supervisory authorities concerned."
        '''
        '''

# %%
import time

def generate_question_answer_with_samples(context):
    empty_result= "{}"
    try:

        samples =f'''

        'Input':
        "Public authorities to which personal data are disclosed in accordance with a legal obligation for the exercise of their official mission, such as tax and customs authorities, financial investigation units, independent adminis\u00ad trative authorities, or financial market authorities responsible for the regulation and supervision of securities markets should not be regarded as recipients if they receive personal data which are necessary to carry out a particular inquiry in the general interest, in accordance with Union or Member State law. The requests for disclosure sent by the public authorities should always be in writing, reasoned and occasional and should not concern the entirety of a filing system or lead to the interconnection of filing systems. The processing of personal data by those public authorities should comply with the applicable data-protection rules according to the purposes of the processing"
        'JSON':
        "question": "What type of public authorities are exempt from being considered recipients if they receive personal data necessary for a particular inquiry?"
        "answer": "Tax and customs authorities, financial investigation units, independent administrative authorities, or financial market authorities responsible for the regulation and supervision of securities markets" 
        'Input': 
        "In the absence of an adequacy decision, the controller or processor should take measures to compensate for the lack of data protection in a third country by way of appropriate safeguards for the data subject. Such appropriate safeguards may consist of making use of binding corporate rules, standard data protection clauses adopted by the Commission, standard data protection clauses adopted by a supervisory authority or contractual clauses authorised by a supervisory authority. Those safeguards should ensure compliance with data protection requirements and the rights of the data subjects appropriate to processing within the Union, including the availability of enforceable data subject rights and of effective legal remedies, including to obtain effective adminis\u00ad trative or judicial redress and to claim compensation, in the Union or in a third country. They should relate in particular to compliance with the general principles relating to personal data processing, the principles of data protection by design and by default. Transfers may also be carried out by public authorities or bodies with public authorities or bodies in third countries or with international organisations with corresponding duties or functions, including on the basis of provisions to be inserted into administrative arrangements, such as a memorandum of understanding, providing for enforceable and effective rights for data subjects. Authorisation by the competent supervisory authority should be obtained when the safeguards are provided for in administrative arrangements that are not legally binding."
        'JSON':
        "question": "What types of safeguards can a controller or processor use to compensate for the lack of an adequacy decision when transferring personal data to a third country?",
        "answer": "Binding corporate rules, standard data protection clauses adopted by the Commission, standard data protection clauses adopted by a supervisory authority, contractual clauses authorised by a supervisory authority"
        '''

        
        
        messages = f'''
            Your task is to generate realistic and applied questions that pertain to the provided regulatory or compliance material. Ensure that the context explicitly contains the answer to the question and the question should not return a binary answer. the answer should be concise"
            Each single question and answer should be in a valid JSON format. Each JSON should contain a single question with a single answer. Only respond with valid JSON and no additional text. Test the JSON for validity before returning it.
            Below are a few examples of a sample input and the returned JSON:
            "{samples}"
        Input:
        "{context}"
        '''

        #print(messages)
        
        response = ollama.generate(model="llama3:8b", prompt=messages,format="json")

        return json.loads(response["response"])

        
    except Exception as e:
        print(f"An error occurred: {e}")
        time.sleep(20)
    return json.loads(empty_result)

# %%
regulation_example = """The processing of personal data should be designed to serve mankind. The right to the protection of personal data is not an absolute right; it must be considered in relation to its function in society and be balanced against other fundamental rights, in accordance with the principle of proportionality."""

print(regulation_example)

structured_data = generate_question_answer_with_samples(regulation_example)

print(json.dumps(structured_data, indent=2))
# Out:
# The processing of personal data should be designed to serve mankind. The right to the protection of personal data is not an absolute right; it must be considered in relation to its function in society and be balanced against other fundamental rights, in accordance with the principle of proportionality.
# {
#   "question": "What is the primary consideration for processing personal data according to this regulation?",
#   "answer": "The processing of personal data should be designed to serve mankind"
# }

# %%
# Example usage:
import datetime
use_value= 4
if use_value==1:
    
    regulation_example = """The processing of personal data should be designed to serve mankind. The right to the protection of personal data is not an absolute right; it must be considered in relation to its function in society and be balanced against other fundamental rights, in accordance with the principle of proportionality."""
elif use_value==2:
    regulation_example = """
    Those developments require a strong and more coherent data protection framework in the Union, backed by strong enforcement, given the importance of creating the trust that will allow the digital economy to develop across the internal market. Natural persons should have control of their own personal data. Legal and practical certainty for natural persons, economic operators 
    and public authorities should be enhanced.
    """

elif use_value==3:
    regulation_example = """
    The processing of personal data of data subjects who are in the Union by a controller or processor not established in the Union should
    also be subject to this Regulation when it is related to the monitoring of the behaviour of such data subjects in so far as their behaviour takes place within
    the Union. In order to determine whether a processing activity can be considered to monitor the behaviour of data subjects, it should be ascertained whether natural persons 
    are tracked on the internet including potential subsequent use of personal data processing techniques which consist of profiling a natural person, particularly in order to take decisions concerning her or him or for analysing 
    or predicting her or his personal preferences, behaviours and attitudes.
    """
elif use_value==4:
    regulation_example = """"
    The establishment of supervisory authorities in Member States, empowered to perform their tasks and exercise their powers with complete independence, is an essential component of the protection of natural persons with regard to the processing of their personal 
    data. Member States should be able to establish more than one supervisory authority, to reflect their constitutional, organisational and administrative structure
    """

now = datetime.datetime.now()
print(now.time())

print(regulation_example)

structured_data = generate_question_answer_with_samples(regulation_example)

now = datetime.datetime.now()
print(now.time())

print(json.dumps(structured_data, indent=2))
# Out:
# 10:10:53.379958
# "
#     The establishment of supervisory authorities in Member States, empowered to perform their tasks and exercise their powers with complete independence, is an essential component of the protection of natural persons with regard to the processing of their personal
#     data. Member States should be able to establish more than one supervisory authority, to reflect their constitutional, organisational and administrative structure
#
# 10:10:59.375514
# {
#   "question": "How many supervisory authorities can a Member State establish?",
#   "answer": "More than one"
# }

# %%
import pandas as pd
use_sentences=True
if use_sentences:
    #obligations_all = pd.read_csv('data/gdpr_articles_sentences_clean.txt', sep="\t", header=None)
    # articles related to controller and processor
    #obligations_all = pd.read_csv('data/gdpr_articles_24_43_sentences_clean.txt', sep="\t", header=None)
    obligations_all = pd.read_csv('data/gdpr_recitals_sentences_clean.txt', sep="\t", header=None)
else:
    
    obligations_all = pd.read_csv('data/gdpr_articles_clean.txt', sep="\t", header=None)
    #obligations_all = pd.read_csv('data/gdpr_recitals.txt', sep="\t", header=None)
    
obligations_all.columns = ["Statement"]
print(len(obligations_all))
# Out:
# 169

# %%
import random
statements_all = obligations_all["Statement"].tolist()



def is_valid_output(json_output):
    required_fields = ["question", "answer"]
    for field in required_fields:
        if not json_output.get(field):
            return False
    return True

question_answers = []
if use_sentences:
    # shuffle sentences
    #random.shuffle(statements_all)
    #statements = statements_all[:50]
    statements = statements_all
else:
    statements = statements_all
    #statements = statements_all[:173]
current_article =''

for index,text in enumerate(statements):
    now = datetime.datetime.now()

    #if index==100:
    #    break
        
    print("%d %s" %(index,now.time()))
    print(text)

    
    if text.startswith("Article"):
        current_article = text.split(" ")[1]
    print(current_article)
    
    # skip certain lines in gdpr articles
    if text== '\n' or text == '' or text.startswith("Article") or text.startswith("CHAPTER") or text.startswith("Section"):
        continue
        
    retries = 3
    json_output = None
    while retries > 0:
        
        json_output = generate_question_answer_with_samples(text)
        if is_valid_output(json_output):
            break
        retries -= 1
    print(json_output)
    
    if json_output:
        #json_output["InputText"] = text  # Add the original text to the JSON output
        json_output["InputText"] = text.replace(u"\u2018", "'").replace(u"\u2019", "'")  # change unicode chars for quotes
        json_output["Article"] = current_article

        question_answers.append(json_output)

# Save the knowledge graph to a JSON file
#output_json_filename = "Output/obligation_question_answer_output.json"
if use_sentences:
    #output_json_filename = "Output/gdpr_recital_sentences_question_answer_output.json"
    output_json_filename = "Output/gdpr_articles_24_43_sentences_question_answer_one_shot_output.json"

    #output_json_filename = "Output/gdpr_articles_sentences_question_answer_one_shot_output.json"
else:    
    #output_json_filename = "Output/gdpr_recital_question_answer_output.json"
    output_json_filename = "Output/gdpr_articles_question_answer_one_shot_output.json"

with open(output_json_filename, 'w') as json_file:
    json.dump(question_answers, json_file, indent=4)

print(f"obligations question answer  saved to {output_json_filename}")

# %%
gdpr_articles_json_filename = 'Output/gdpr_articles_24_43_qa_output.json'

with open(gdpr_articles_json_filename) as json_file:
    article_json_data = json.load(json_file)
print(len(article_json_data))
# Out:
# 122

# %%
for record in article_json_data:
    print(record)
    print(record['Article'])
    break
# Out:
# {'question': 'What kind of measures should a controller implement to ensure and demonstrate compliance with Article 24?', 'answer': 'Appropriate technical and organisational measures.These measures shall be reviewed where necessary', 'InputText': 'Taking into account the nature, scope, context and purposes of processing as well as the risks of varying likelihood and severity for the rights and freedoms of natural persons, the controller shall implement appropriate technical and organisational measures to ensure and to be able to demonstrate that processing is performed in accordance with this Regulation.  Those measures shall be reviewed and updated where necessary.', 'Article': '24'}
# 24

# %%
print(article_json_data[0]['question'])
# Out:
# What kind of measures should a controller implement to ensure and demonstrate compliance with Article 24?

# %%
gdpr_recitals_json_filename = 'Output/gdpr_chapter4_recital_qa_correct_output.json'

with open(gdpr_recitals_json_filename) as json_file:
    recital_json_data = json.load(json_file)
print(len(recital_json_data))
# Out:
# 46

# %%
for record in recital_json_data:
    print(record['Recital'])

# %%
import chromadb

# %%
client = chromadb.Client()

if "articles" in [c.name for c in client.list_collections()]:
      
    client.delete_collection(name="articles")

collection = client.create_collection(name="articles")

# store each document in a vector embedding database
for i, article in enumerate(article_json_data):
    input_text = article['InputText']  
    response = ollama.embed(model="all-minilm", input=input_text)
    embeddings = response["embeddings"]
    collection.add(
    ids=[str(i)+":article:" + article['Article']],
    embeddings=embeddings,
    documents=[input_text]
  )

# %%
#if client.get_collection(name="recitals"):
if "recitals" in [c.name for c in client.list_collections()]:
    
    client.delete_collection(name="recitals")

recital_collection = client.create_collection(name="recitals")

# store each document in a vector embedding database
for i, recital in enumerate(recital_json_data):
    input_text = recital['InputText']  
    response = ollama.embed(model="all-minilm", input=input_text)
    embeddings = response["embeddings"]
    recital_collection.add(
    ids=[str(i)+":recital:" + recital['Recital']],
    embeddings=embeddings,
    documents=[input_text]
  )

# %%
sample_article_text = article_json_data[5]['InputText']
print(sample_article_text)
# Out:
# The arrangement referred to in paragraph 1 shall duly reflect the respective roles and relationships of the joint controllers vis-à-vis the data subjects.  The essence of the arrangement shall be made available to the data subject.

# %%
print(collection.count())
# Out:
# 122

# %%
print(recital_collection.count())
# Out:
# 46

# %%
# an example input
sample_recital_question = recital_json_data[34]['question']
sample_recital_answer = recital_json_data[34]['answer']
sample_recital_text = recital_json_data[34]['InputText']

print(sample_recital_question)
print(sample_recital_answer)
print(sample_recital_text)
# Out:
# When would a data protection impact assessment be required for monitoring publicly accessible areas?
# Especially when using optic-electronic devices or when the competent supervisory authority considers that the processing is likely to result in a high risk to the rights and freedoms of data subjects, in particular because they prevent data subjects from exercising a right or using a service or a contract, or because they are carried out systematically on a large scale.
# A data protection impact assessment is equally required for monitoring publicly accessible areas on a large scale, especially when using optic-electronic devices or for any other operations where the competent supervisory authority considers that the processing is likely to result in a high risk to the rights and freedoms of data subjects, in particular because they prevent data subjects from exercising a right or using a service or a contract, or because they are carried out systematically on a large scale.

# %%
for recital in recital_json_data:
    recital_text = recital['InputText']
    
    # generate an embedding for the input and retrieve the most relevant doc
    response = ollama.embed(
      model="all-minilm",
      input=recital_text
    )

    results = collection.query(
      query_embeddings=[response["embeddings"][0]],
      n_results=2
    )

    
    
    closest_dist = results['distances'][0][0]
    closest_id = results['ids'][0][0]
    if closest_dist < 0.3:
        print(recital)
        print("%3.3f" %(closest_dist))
        print(closest_id)
        data = results['documents'][0][0]
        print(data)

# %%
print(sample_recital_text)
# Out:
#  Where a controller or a processor not established in the Union is processing personal data of data subjects who are in the Union whose processing activities are related to the offering of goods or services, irrespective of whether a payment of the data subject is required, to such data subjects in the Union, or to the monitoring of their behaviour as far as their behaviour takes place within the Union, the controller or the processor should designate a representative, unless the processing is occasional, does not include processing, on a large scale, of special categories of personal data or the processing of personal data relating to criminal convictions and offences, and is unlikely to result in a risk to the rights and freedoms of natural persons, taking into account the nature, context, scope and purposes of the processing or if the controller is a public authority or body. The representative should act on behalf of the controller or the processor and may be addressed by any supervisory authority. The representative should be explicitly designated by a written mandate of the controller or of the processor to act on its behalf with regard to its obligations under this Regulation. The designation of such a representative does not affect the responsibility or liability of the controller or of the processor under this Regulation. Such a representative should perform its tasks according to the mandate received from the controller or processor, including cooperating with the competent supervisory authorities with regard to any action taken to ensure compliance with this Regulation. The designated representative should be subject to enforcement proceedings in the event of non-compliance by the controller or processor.

# %%
print(recital_json_data[0])
# Out:
# {'InputText': 'Taking into account the nature, scope, context and purposes of processing as well as the risks of varying likelihood and severity for the rights and freedoms of natural persons, the controller shall implement appropriate technical and organisational measures to ensure and to be able to demonstrate that processing is performed in accordance with this Regulation.  Those measures shall be reviewed and updated where necessary.', 'question': 'What kind of measures should a controller implement to ensure and demonstrate compliance with Article 24?', 'answer': 'Appropriate technical and organisational measures.These measures shall be reviewed where necessary', 'expanded_score': '0.3608', 'expanded': ['The controller shall maintain accurate and up-to-date records of processing activities, including information on the categories of personal data processed, the source of such data, and the recipients to whom it was disclosed', 'The controller shall provide adequate training to employees and any third-party processors involved in processing personal data to ensure they understand their roles and responsibilities under this Regulation', 'The controller shall establish a procedure for reporting and investigating data breaches or unauthorized access to personal data, and notify the competent supervisory authority and affected individuals without undue delay'], 'Article': '24'}

# %%
Experiment: Provide an answer to each recital utilising contextal data based on closest matching articles

# %%
use_recital_question =True

deep_dataset = []
for index,recital in enumerate(recital_json_data):
    print(index)
    recital_text = recital['InputText']
    recital_query= recital_text
    
    if use_recital_question:
        recital_query = recital['question']    
    
    # generate an embedding for the input and retrieve the most relevant doc
    response = ollama.embed(
      model="all-minilm",
      input=recital_query
    )

    results = collection.query(
      query_embeddings=[response["embeddings"][0]],
      n_results=3
    )

    closest_dist = results['distances'][0][0]

    if closest_dist < 100.0:
        #print(index)
   
        print("%3.3f" %(closest_dist))
        #print("closest document id %s" %(closest_id))
       
            
        closest_id = results['ids'][0][0]
        #data = results['documents'][0][0]
        # add all returned documents not just the first
        data = results['documents'][0]
        
        print("recital_text:")
        print(recital_text)
        #print("returned document")
        #print(data)
        
        recital_question = recital['question']
        recital_answer = recital['answer']
        print("recital question:")
        print(recital_question)
    
        print("recital answer:")
        print(recital_answer)
    
        print("response from LLM:")
        #generate a response combining the prompt and data we retrieved in step 2
        output = ollama.generate(
          model="llama3:8b",
          #prompt=f"Using this data: {data}. Respond to this prompt: {recital_question}"
          prompt=f"Using this contextual data: {data}.Provide a concise answer to the given query: {recital_question}"
     
        ) 
    
        print(output['response']) 
    
 
        retrieved_contexts = data

        test_case = LLMTestCase(input=recital_question, expected_output =recital_answer,actual_output=output['response'], retrieval_context= retrieved_contexts)
    
        deep_dataset.append(test_case)
    
        

deepeval_dataset = EvaluationDataset(test_cases=deep_dataset)
# Out:
# 0
# 0.976
# recital_text:
#  In order to ensure a consistent level of protection for natural persons throughout the Union and to prevent divergences hampering the free movement of personal data within the internal market, a Regulation is necessary to provide legal certainty and transparency for economic operators, including micro, small and medium-sized enterprises, and to provide natural persons in all Member States with the same level of legally enforceable rights and obligations and responsibilities for controllers and processors, to ensure consistent monitoring of the processing of personal data, and equivalent sanctions in all Member States as well as effective cooperation between the supervisory authorities of different Member States. The proper functioning of the internal market requires that the free movement of personal data within the Union is not restricted or prohibited for reasons connected with the protection of natural persons with regard to the processing of personal data. To take account of the specific situation of micro, small and medium-sized enterprises, this Regulation includes a derogation for organisations with fewer than 250 employees with regard to record-keeping. In addition, the Union institutions and bodies, and Member States and their supervisory authorities, are encouraged to take account of the specific needs of micro, small and medium-sized enterprises in the application of this Regulation. The notion of micro, small and medium-sized enterprises should draw from Article 2 of the Annex to Commission Recommendation 2003/361/EC (1).
# recital question:
# What is the primary objective of introducing a Regulation to ensure consistent protection for natural persons throughout the Union?
# recital answer:
# to provide legal certainty and transparency for economic operators, including micro, small and medium-sized enterprises and to provide natural persons in all Member states with the same legal of legally enforceable rights and obligations and responsibilities for controllers and processors, to ensure consistent monitoring of the processing of personal data, and equivalent sanctions in all Member States as well as effective cooperation between the supervisory authorities of different Member States.
# response from LLM:
# The primary objective of introducing this Regulation is to ensure that processing of personal data is performed in accordance with the Regulation, thereby ensuring consistent protection for natural persons throughout the European Union. This involves implementing technical and organisational measures to demonstrate compliance with the Regulation's requirements and to mitigate risks to individuals' rights and freedoms.
# 1
# 0.890
# recital_text:
# The proper functioning of the internal market requires that the free movement of personal data within the Union is not restricted or prohibited for reasons connected with the protection of natural persons with regard to the processing of personal data.
# recital question:
# What are the main objectives of ensuring the free movement of personal data in the EU?
# recital answer:
# The proper functioning of the internal market requires that the free movement of personal data within the Union is not restricted or prohibited for reasons connected with the protection of natural persons with regard to the processing of personal data.
# response from LLM:
# Based on the provided contextual data, the main objectives of ensuring the free movement of personal data in the EU are:
#
# 1. To process only necessary personal data for each specific purpose.
# 2. To limit the amount, extent, and duration of processing, storage, and accessibility of personal data.
# 3. To ensure that personal data are not made accessible without the individual's intervention to an indefinite number of natural persons.
#
# These objectives aim to protect the rights and freedoms of data subjects by minimizing the risk of unauthorized access or misuse of their personal data.
# 2
# 1.007
# recital_text:
# To take account of the specific situation of micro, small and medium-sized enterprises, this Regulation includes a derogation for organisations with fewer than 250 employees with regard to record-keeping.
# recital question:
# What is the exemption from record-keeping requirements for?
# recital answer:
# organisations with fewer than 250 employees
# response from LLM:
# According to the provided contextual data, the exemption from record-keeping requirements applies to enterprises or organisations employing fewer than 250 persons unless:
#
# 1. The processing they carry out is likely to result in a risk to the rights and freedoms of data subjects.
# 2. The processing is not occasional.
# 3. The processing includes special categories of data (Article 9) or personal data relating to criminal convictions and offences (Article 10).
#
# In other words, small-scale enterprises or organisations with fewer than 250 employees are exempt from record-keeping requirements unless their processing activities pose a significant risk to individuals' rights and freedoms or involve sensitive information.
# 3
# 0.793
# recital_text:
#  The principle of transparency requires that any information addressed to the public or to the data subject be concise, easily accessible and easy to understand, and that clear and plain language and, additionally, where appropriate, visualisation be used. Such information could be provided in electronic form, for example, when addressed to the public, through a website. This is of particular relevance in situations where the proliferation of actors and the technological complexity of practice make it difficult for the data subject to know and understand whether, by whom and for what purpose personal data relating to him or her are being collected, such as in the case of online advertising. Given that children merit specific protection, any information and communication, where processing is addressed to a child, should be in such a clear and plain language that the child can easily understand.
# recital question:
# What is the principle of transparency required for information addressed to the public or data subjects?
# recital answer:
# The principle of transparency requires that any information be concise, easily accessible, and easy to understand, using clear and plain language and additionally visualisation where appropriate.
# response from LLM:
# Based on the provided contextual data, the principle of transparency is not explicitly mentioned as a requirement for information addressed to the public or data subjects. However, it can be inferred that transparency is implied in the communication process.
#
# The Regulation requires controllers to provide information to data subjects in a way that is "equally effective" (Article 33) and that ensures "fair and transparent processing" (Recital 79). Additionally, the Regulation emphasizes the importance of providing accurate and easily accessible information to data subjects about their rights and the processing of their personal data.
#
# In this context, transparency can be understood as the duty to provide clear, concise, and easily understandable information to data subjects, allowing them to make informed decisions about their personal data.
# 4
# 0.745
# recital_text:
#  The responsibility and liability of the controller for any processing of personal data carried out by the controller or on the controller's behalf should be established. In particular, the controller should be obliged to implement appropriate and effective measures and be able to demonstrate the compliance of processing activities with this Regulation, including the effectiveness of the measures. Those measures should take into account the nature, scope, context and purposes of the processing and the risk to the rights and freedoms of natural persons.
# recital question:
# What kind of measures should a controller establish to demonstrate compliance with this Regulation?
# recital answer:
# Appropriate and effective measures and be able to demonstrate the compliance of processing activities within this Regulation. Also those measures should take into account the nature, scope, context and purposes of the processing and the risk to the rights and freedoms of natural persons.
# response from LLM:
# According to the provided data, a controller should establish:
#
# * Appropriate data protection policies
# * Technical and organisational measures taking into account the nature, scope, context, and purposes of processing, as well as the risks involved.
# * Reviewing and updating these measures where necessary.
#
# Additionally, adherence to approved codes of conduct or certification mechanisms can be used as an element to demonstrate compliance.
# 5
# 0.735
# recital_text:
#  The risk to the rights and freedoms of natural persons, of varying likelihood and severity, may result from personal data processing which could lead to physical, material or non-material damage, in particular: where the processing may give rise to discrimination, identity theft or fraud, financial loss, damage to the reputation, loss of confidentiality of personal data protected by professional secrecy, unauthorised reversal of pseudonymisation, or any other significant economic or social disadvantage; where data subjects might be deprived of their rights and freedoms or prevented from exercising control over their personal data; where personal data are processed which reveal racial or ethnic origin, political opinions, religion or philosophical beliefs, trade union membership, and the processing of genetic data, data concerning health or data concerning sex life or criminal convictions and offences or related security measures; where personal aspects are evaluated, in particular analysing or predicting aspects concerning performance at work, economic situation, health, personal preferences or interests, reliability or behaviour, location or movements, in order to create or use personal profiles; where personal data of vulnerable natural persons, in particular of children, are processed; or where processing involves a large amount of personal data and affects a large number of data subjects.
# recital question:
# What types of harm can result from personal data processing?
# recital answer:
# The risk to the rights and freedoms of natural persons may result in physical, material or non-material damage, including discrimination, identity theft or fraud, financial loss, damage to reputation, loss of confidentiality, unauthorised reversal of pseudonymisation, or any other significant economic or social disadvantage; where data subjects might be deprived of their rights and freedoms or prevented from exercising control over their personal data;  where personal data are processed which reveal racial or ethnic origin, political opinions, religion or philosophical beliefs, trade union membership, and the processing of genetic data, data concerning health or data concerning sex life or criminal convictions and offences or related security measures; where personal aspects are evaluated, in particular analysing or predicting aspects concerning performance at work, economic situation, health, personal preferences or interests, reliability or behaviour, location or movements, in order to create or use personal profiles; where personal data of vulnerable natural persons, in particular of children, are processed; or where processing involves a large amount of personal data and affects a large number of data subjects.
# response from LLM:
# According to the provided contextual data, high-risk personal data processing can result in harm that affects the rights and freedoms of natural persons, such as:
#
# * High risk of producing legal effects or significantly affecting individuals
# * Significant violations of privacy and personal aspects relating to individuals
# * Large-scale breaches of special categories of sensitive data (e.g., health records, criminal convictions)
# 6
# 0.822
# recital_text:
#  The likelihood and severity of the risk to the rights and freedoms of the data subject should be determined by reference to the nature, scope, context and purposes of the processing. Risk should be evaluated on the basis of an objective assessment, by which it is established whether data processing operations involve a risk or a high risk.
# recital question:
# How does one determine the likelihood and severity of the risk to the rights and freedoms of the data subject?
# recital answer:
# The likelihood and severity of the risk to the rights and freedoms of the data subject should be determined by reference to the nature, scope, context and purposes of the processing.
# response from LLM:
# According to the provided contextual data, the determination of the likelihood and severity of the risk to the rights and freedoms of the data subject is taken into account when considering:
#
# * The state of the art
# * The cost of implementation
# * The nature, scope, context, and purposes of processing
# * The risks posed by the processing
#
# This information helps assessors evaluate the potential risks to data subjects' rights and freedoms.
# 7
# 0.521
# recital_text:
#  Guidance on the implementation of appropriate measures and on the demonstration of compliance by the controller or the processor, especially as regards the identification of the risk related to the processing, their assessment in terms of origin, nature, likelihood and severity, and the identification of best practices to mitigate the risk, could be provided in particular by means of approved codes of conduct, approved certifications, guidelines provided by the Board or indications provided by a data protection officer. The Board may also issue guidelines on processing operations that are considered to be unlikely to result in a high risk to the rights and freedoms of natural persons and indicate what measures may be sufficient in such cases to address such risk.
# recital question:
# What types of guidance could be provided by the Board or data protection officer to help controllers and processors identify and mitigate risks related to processing?
# recital answer:
# Approved codes of conduct, approved certifications, guidelines provided by the Board, or indications provided by the the data protection officer
# response from LLM:
# Based on the contextual data, the following types of guidance could be provided by the Board or data protection officer to help controllers and processors identify and mitigate risks related to processing:
#
# * Consider the nature, scope, context, and purposes of processing operations when assessing risk.
# * Take into account the potential consequences of processing, such as breaches, non-compliance, or reputational damage.
# * Identify high-risk processing activities, such as sensitive data processing or international transfers.
# * Develop policies and procedures to mitigate risks, including:
# 	+ Data minimization: collect only necessary data.
# 	+ Purpose limitation: use data only for its intended purpose.
# 	+ Transparency: provide clear information about processing to data subjects.
# 	+ Confidentiality: protect sensitive data through encryption and access controls.
# 	+ Integrity: ensure accurate and complete data processing.
#
# By providing this guidance, the Board or data protection officer can help controllers and processors proactively identify and mitigate risks related to processing, ensuring compliance with data protection regulations.
# 8
# 0.752
# recital_text:
#  The protection of the rights and freedoms of natural persons with regard to the processing of personal data require that appropriate technical and organisational measures be taken to ensure that the requirements of this Regulation are met. In order to be able to demonstrate compliance with this Regulation, the controller should adopt internal policies and implement measures which meet in particular the principles of data protection by design and data protection by default. Such measures could consist, inter alia, of minimising the processing of personal data, pseudonymising personal data as soon as possible, transparency with regard to the functions and processing of personal data, enabling the data subject to monitor the data processing, enabling the controller to create and improve security features. When developing, designing, selecting and using applications, services and products that are based on the processing of personal data or process personal data to fulfil their task, producers of the products, services and applications should be encouraged to take into account the right to data protection when developing and designing such products, services and applications and, with due regard to the state of the art, to make sure that controllers and processors are able to fulfil their data protection obligations. The principles of data protection by design and by default should also be taken into consideration in the context of public tenders.
# recital question:
# What measures can a controller take to ensure compliance with the  Regulation?
# recital answer:
# The controller should adopt internal policies and implement measures which meet in particular the principles of data protection by design and data protection by default, such as minimising the processing of personal data, pseudonymising personal data as soon as possible, transparency with regard to the functions and processing of personal data, enabling the data subject to monitor the data processing, enabling the controller to create and improve security features.
# response from LLM:
# According to the provided text, a controller can take the following measures to ensure compliance with the Regulation:
#
# 1. Implement appropriate data protection policies.
# 2. Adhere to approved codes of conduct or certification mechanisms (Articles 40 and 42).
# 3. Implement technical and organisational measures that ensure processing is performed in accordance with the Regulation, taking into account the nature, scope, context, and purposes of processing, as well as risks to natural persons' rights and freedoms.
# 4. Review and update these measures as necessary.
#
# These measures can be used to demonstrate compliance with the controller's obligations under the Regulation.
# 9
# 0.776
# recital_text:
# When developing, designing, selecting and using applications, services and products that are based on the processing of personal data or process personal data to fulfil their task, producers of the products, services and applications should be encouraged to take into account the right to data protection when developing and designing such products, services and applications and, with due regard to the state of the art, to make sure that controllers and processors are able to fulfil their data protection obligations. The principles of data protection by design and by default should also be taken into consideration in the context of public tenders.
# recital question:
# When developing, designing, selecting and using applications, services and products that are based on the processing of personal data or process personal data to fulfil their task, what should the producers of the products, services and applications be encouraged to do?
# recital answer:
#  take into account the right to data protection when developing and designing such products, services and applications and, with due regard to the state of the art, to make sure that controllers and processors are able to fulfil their data protection obligations.
# response from LLM:
# Based on the provided GDPR context, the producers of products, services, and applications that process personal data should:
#
# * Carry out an assessment of the impact of processing operations on the protection of personal data before processing, if it is likely to result in a high risk to individuals' rights and freedoms.
# * Implement appropriate technical and organizational measures to ensure that only necessary personal data are processed, collected, stored, and accessible by default.
#
# In summary, they should prioritize data protection by design and default when developing, designing, selecting, and using applications, services, and products.
# 10
# 0.937
# recital_text:
#  The protection of the rights and freedoms of data subjects as well as the responsibility and liability of controllers and processors, also in relation to the monitoring by and measures of supervisory authorities, requires a clear allocation of the responsibilities under this Regulation, including where a controller determines the purposes and means of the processing jointly with other controllers or where a processing operation is carried out on behalf of a controller.
# recital question:
# What are the main reasons for allocating responsibilities under the Regulation?
# recital answer:
# The protection of the rights and freedoms of data subjects as well as the responsibility and liability of controllers and processors, also in relation to the monitoring by and measures of supervisory authorities
# response from LLM:
# The main reasons for allocating responsibilities under the General Data Protection Regulation (GDPR) are:
#
# 1. Encouraging codes of conduct to ensure proper application of the regulation, considering specific features and needs of different sectors and micro/small/medium-sized enterprises.
# 2. Ensuring consultation with supervisory authorities in the preparation of legislative or regulatory measures related to processing.
#
# These responsibilities aim to promote transparency, accountability, and cooperation between Member States, supervisory authorities, the Board, and the Commission to effectively regulate data protection in the EU.
# 11
# 0.510
# recital_text:
#  Where a controller or a processor not established in the Union is processing personal data of data subjects who are in the Union whose processing activities are related to the offering of goods or services, irrespective of whether a payment of the data subject is required, to such data subjects in the Union, or to the monitoring of their behaviour as far as their behaviour takes place within the Union, the controller or the processor should designate a representative, unless the processing is occasional, does not include processing, on a large scale, of special categories of personal data or the processing of personal data relating to criminal convictions and offences, and is unlikely to result in a risk to the rights and freedoms of natural persons, taking into account the nature, context, scope and purposes of the processing or if the controller is a public authority or body. The representative should act on behalf of the controller or the processor and may be addressed by any supervisory authority. The representative should be explicitly designated by a written mandate of the controller or of the processor to act on its behalf with regard to its obligations under this Regulation. The designation of such a representative does not affect the responsibility or liability of the controller or of the processor under this Regulation. Such a representative should perform its tasks according to the mandate received from the controller or processor, including cooperating with the competent supervisory authorities with regard to any action taken to ensure compliance with this Regulation. The designated representative should be subject to enforcement proceedings in the event of non-compliance by the controller or processor.
# recital question:
# When is it  necessary for a controller or processor to designate a representative?
# recital answer:
# in the case a controller or a processor not established in the Union is processing personal data of data subjects who are in the Union whose processing activities are related to the offering of goods or services, irrespective of whether a payment of the data subject is required, to such data subjects in the Union, or to the monitoring of their behaviour as far as their behaviour takes place within the Union
# response from LLM:
# According to the contextual data, it is necessary for a controller or processor to designate a representative when:
#
# 1. The controller or processor is not established in one of the Member States where the data subjects are located (Article 27(1)).
# 2. The controller or processor is not established in the Union, but processes personal data (Article 27(1) and Article 4).
#
# In other words, a representative must be designated when the controller or processor is outside the jurisdiction where the data subjects are located, or if they process personal data without being established in the Union.
# 12
# 0.546
# recital_text:
#  Where a controller or a processor not established in the Union is processing personal data of data subjects who are in the Union whose processing activities are related to the offering of goods or services, irrespective of whether a payment of the data subject is required, to such data subjects in the Union, or to the monitoring of their behaviour as far as their behaviour takes place within the Union, the controller or the processor should designate a representative, unless the processing is occasional, does not include processing, on a large scale, of special categories of personal data or the processing of personal data relating to criminal convictions and offences, and is unlikely to result in a risk to the rights and freedoms of natural persons, taking into account the nature, context, scope and purposes of the processing or if the controller is a public authority or body.
# recital question:
# When is it not necessary for a controller or processor to designate a representative?
# recital answer:
# The processing is occasional, does not include processing on a large scale, of special categories of personal data or the processing of personal data relating to criminal convictions and offences, and is unlikely to result in a risk to the rights and freedoms of natural persons, taking into account the nature, context, scope and purposes of the processing or if the controller is a public authority or body.
# response from LLM:
# According to Article 27(2) and (3), it is not necessary for a controller or processor to designate a representative in the following situations:
#
# * Occasional processing that does not include large-scale processing of special categories of data, nor personal data relating to criminal convictions and offences, and is unlikely to result in a risk to the rights and freedoms of natural persons.
# * Public authority or body.
# 13
# 0.678
# recital_text:
#  The representative should act on behalf of the controller or the processor and may be addressed by any supervisory authority. The representative should be explicitly designated by a written mandate of the controller or of the processor to act on its behalf with regard to its obligations under this Regulation. The designation of such a representative does not affect the responsibility or liability of the controller or of the processor under this Regulation. Such a representative should perform its tasks according to the mandate received from the controller or processor, including cooperating with the competent supervisory authorities with regard to any action taken to ensure compliance with this Regulation. The designated representative should be subject to enforcement proceedings in the event of non-compliance by the controller or processor.
# recital question:
# What is the obligations of the representative?
# recital answer:
# the representative should act on behalf of the controller or the processor and may be addressed by any supervisory authority. The representative should be explicitly designated by a written mandate of the controller or of the processor to act on its behalf with regard to its obligations under this Regulation. The designation of such a representative does not affect the responsibility or liability of the controller or of the processor under this Regulation. Such a representative should perform its tasks according to the mandate received from the controller or processor, including cooperating with the competent supervisory authorities with regard to any action taken to ensure compliance with this Regulation. The designated representative should be subject to enforcement proceedings in the event of non-compliance by the controller or processor.
# response from LLM:
# According to the provided context, the representative's obligations are:
#
# * To be established in one of the Member States where the data subjects are located
# * To be mandated by the controller or processor to be addressed on all issues related to processing
# * To ensure compliance with this Regulation by being a point of contact for supervisory authorities and data subjects
#
# In other words, the representative serves as an intermediary between the controller/processor and data subjects/supervisory authorities, facilitating communication and ensuring compliance with the Regulation.
# 14
# 0.680
# recital_text:
#  To ensure compliance with the requirements of this Regulation in respect of the processing to be carried out by the processor on behalf of the controller, when entrusting a processor with processing activities, the controller should use only processors providing sufficient guarantees, in particular in terms of expert knowledge, reliability and resources, to implement technical and organisational measures which will meet the requirements of this Regulation, including for the security of processing. The adherence of the processor to an approved code of conduct or an approved certification mechanism may be used as an element to demonstrate compliance with the obligations of the controller. The carrying-out of processing by a processor should be governed by a contract or other legal act under Union or Member State law, binding the processor to the controller, setting out the subject- matter and duration of the processing, the nature and purposes of the processing, the type of personal data and categories of data subjects, taking into account the specific tasks and responsibilities of the processor in the context of the processing to be carried out and the risk to the rights and freedoms of the data subject. The controller and processor may choose to use an individual contract or standard contractual clauses which are adopted either directly by the Commission or by a supervisory authority in accordance with the consistency mechanism and then adopted by the Commission. After the completion of the processing on behalf of the controller, the processor should, at the choice of the controller, return or delete the personal data, unless there is a requirement to store the personal data under Union or Member State law to which the processor is subject.
# recital question:
# What are some key factors a controller should consider when selecting a processor to ensure compliance with the Regulation?
# recital answer:
# The controller should use only processors providing sufficient guarantees, in particular in terms of expert knowledge, reliability and resources, to implement technical and organisational measures which will meet the requirements of this Regulation
# response from LLM:
# Based on the provided contextual data, the following are key factors a controller should consider when selecting a processor:
#
# 1. **Sufficient guarantees**: Ensure the processor provides adequate technical and organisational measures to meet the requirements of the Regulation.
# 2. **Compliance assistance**: Verify that the processor is willing to assist in ensuring compliance with obligations (Articles 32-36) based on the nature of processing and available information.
# 3. **Data protection obligations**: Impose data protection obligations on any subcontracted processors, providing sufficient guarantees for technical and organisational measures, and ensure accountability.
#
# By considering these factors, a controller can select a processor that meets the requirements of the Regulation and ensures the protection of individual rights.
# 15
# 0.402
# recital_text:
# The carrying-out of processing by a processor should be governed by a contract or other legal act under Union or Member State law, binding the processor to the controller, setting out the subject- matter and duration of the processing, the nature and purposes of the processing, the type of personal data and categories of data subjects, taking into account the specific tasks and responsibilities of the processor in the context of the processing to be carried out and the risk to the rights and freedoms of the data subject.
# recital question:
# What should a contract or other legal act governing processing by a processor contain?
# recital answer:
# The contract or legal act should set out the subject-matter and duration of the processing, the nature and purposes of the processing, the type of personal data and categories of data subjects, taking into account the specific tasks and responsibilities of the processor in the context of the processing to be carried out and the risk to the rights and freedoms of the data subject.
# response from LLM:
# A contract or other legal act governing processing by a processor should contain:
#
# 1. The subject-matter and duration of the processing
# 2. The nature and purpose of the processing
# 3. The type of personal data and categories of data subjects
# 4. The obligations and rights of the controller
#
# Additionally, it should also provide sufficient guarantees to implement appropriate technical and organisational measures to meet the requirements of the Regulation.
# 16
# 0.863
# recital_text:
# The controller and processor may choose to use an individual contract or standard contractual clauses which are adopted either directly by the Commission or by a supervisory authority in accordance with the consistency mechanism and then adopted by the Commission.
# recital question:
# What are the options for controllers and processors when it comes to implementing data transfer agreements?
# recital answer:
# The controller and processor may choose to use an individual contract or standard contractual clauses which are adopted either directly by the Commission or by a supervisory authority in accordance with the consistency mechanism and then adopted by the Commission.
# response from LLM:
# According to the provided contextual data, controllers and processors have two options for implementing data transfer agreements:
#
# 1. **Data protection certification mechanisms, seals or marks**: Controllers or processors that are not subject to this Regulation can demonstrate appropriate safeguards by obtaining approval for a certification mechanism, seal, or mark.
# 2. **Codes of conduct**: Controllers or processors that are not subject to this Regulation can adhere to codes of conduct approved under the GDPR, which provides general validity and ensures the protection of data subjects' rights.
#
# In both cases, controllers or processors must make binding and enforceable commitments via contractual or other legally binding instruments to apply the appropriate safeguards.
# 17
# 0.803
# recital_text:
# After the completion of the processing on behalf of the controller, the processor should, at the choice of the controller, return or delete the personal data, unless there is a requirement to store the personal data under Union or Member State law to which the processor is subject.
# recital question:
# What happens to personal data after processing is completed?
# recital answer:
# The processor should, at the choice of the controller, return or delete the personal data, unless there is a requirement to store the personal data under Union or Member State law to which the processor is subject.
# response from LLM:
# According to the provided context, after the end of services related to processing, the processor deletes or returns all personal data to the controller. Existing copies are also deleted unless Union or Member State law requires storage of the personal data.
# 18
# 0.652
# recital_text:
#  In order to demonstrate compliance with this Regulation, the controller or processor should maintain records of processing activities under its responsibility. Each controller and processor should be obliged to cooperate with the supervisory authority and make those records, on request, available to it, so that it might serve for monitoring those processing operations.
# recital question:
# What type of records do controllers or processors need to maintain to demonstrate compliance with this Regulation?
# recital answer:
# Records of processing activities under its responsibility
# response from LLM:
# According to the provided data, controllers and processors are required to maintain a record of all categories of processing activities, which should contain:
#
# * The name and contact details of:
# 	+ The processor (and its representative, if applicable)
# 	+ Each controller on behalf of whom the processor is acting
# 	+ The data protection officer (if applicable)
#
# These records need to be made available to the supervisory authority upon request.
# 19
# 0.579
# recital_text:
#  In order to maintain security and to prevent processing in infringement of this Regulation, the controller or processor should evaluate the risks inherent in the processing and implement measures to mitigate those risks, such as encryption. Those measures should ensure an appropriate level of security, including confidentiality, taking into account the state of the art and the costs of implementation in relation to the risks and the nature of the personal data to be protected. In assessing data security risk, consideration should be given to the risks that are presented by personal data processing, such as accidental or unlawful destruction, loss, alteration, unauthorised disclosure of, or access to, personal data transmitted, stored or otherwise processed which may in particular lead to physical, material or non-material damage.
# recital question:
# What measures can a controller or processor take to mitigate the risks inherent in processing personal data?
# recital answer:
# Measures such as encryption
# response from LLM:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[116], line 52
#      50 print("response from LLM:")
#      51 #generate a response combining the prompt and data we retrieved in step 2
# ---> 52 output = ollama.generate(
#      53   model="llama3:8b",
#      54   #prompt=f"Using this data: {data}. Respond to this prompt: {recital_question}"
#      55   prompt=f"Using this contextual data: {data}.Provide a concise answer to the given query: {recital_question}"
#      56
#      57 )
#      59 print(output['response'])
#      62 retrieved_contexts = data
#
# File ~/experiment/lib/python3.12/site-packages/ollama/_client.py:247, in Client.generate(self, model, prompt, suffix, system, template, context, stream, think, raw, format, images, options, keep_alive)
#     220 def generate(
#     221   self,
#     222   model: str = '',
#    (...)    235   keep_alive: Optional[Union[float, str]] = None,
#     236 ) -> Union[GenerateResponse, Iterator[GenerateResponse]]:
#     237   """
#     238   Create a response using the requested model.
#     239
#    (...)    244   Returns `GenerateResponse` if `stream` is `False`, otherwise returns a `GenerateResponse` generator.
#     245   """
# --> 247   return self._request(
#     248     GenerateResponse,
#     249     'POST',
#     250     '/api/generate',
#     251     json=GenerateRequest(
#     252       model=model,
#     253       prompt=prompt,
#     254       suffix=suffix,
#     255       system=system,
#     256       template=template,
#     257       context=context,
#     258       stream=stream,
#     259       think=think,
#     260       raw=raw,
#     261       format=format,
#     262       images=list(_copy_images(images)) if images else None,
#     263       options=options,
#     264       keep_alive=keep_alive,
#     265     ).model_dump(exclude_none=True),
#     266     stream=stream,
#     267   )
#
# File ~/experiment/lib/python3.12/site-packages/ollama/_client.py:180, in Client._request(self, cls, stream, *args, **kwargs)
#     176         yield cls(**part)
#     178   return inner()
# --> 180 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~/experiment/lib/python3.12/site-packages/ollama/_client.py:120, in Client._request_raw(self, *args, **kwargs)
#     118 def _request_raw(self, *args, **kwargs):
#     119   try:
# --> 120     r = self._client.request(*args, **kwargs)
#     121     r.raise_for_status()
#     122     return r
#
# File ~/experiment/lib/python3.12/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/experiment/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/experiment/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/experiment/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/experiment/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/experiment/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/experiment/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/experiment/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/experiment/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/experiment/lib/python3.12/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/experiment/lib/python3.12/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/experiment/lib/python3.12/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/experiment/lib/python3.12/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/experiment/lib/python3.12/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
for index,article in enumerate(article_json_data):
    print(index)
    article_text = article['InputText']
    
    article_question = article['question']
    article_answer = article['answer']

    # generate an embedding for the input and retrieve the most relevant doc
    response = ollama.embed(
      model="all-minilm",
      input=article_question
    )

    results = collection.query(
      query_embeddings=[response["embeddings"][0]],
      n_results=3
    )

    closest_dist = results['distances'][0][0]

    if closest_dist < 10.0:
        #print(index)
   
        print("closest distance in vector store:%3.3f" %(closest_dist))
        #print("closest document id %s" %(closest_id))
       
            
        closest_id = results['ids'][0][0]
        #data = results['documents'][0][0]
        # add all returned documents not just the first
        data = results['documents'][0]
        
        print("article_text:")
        print(article_text)
        #print("returned document")
        #print(data)
        
        print("article question:")
        print(article_question)
    
        print("article answer:")
        print(article_answer)
    
        print("response from LLM:")
        #generate a response combining the prompt and data we retrieved in step 2
        output = ollama.generate(
          model="llama3:8b",
          #prompt=f"Using this data: {data}. Respond to this prompt: {recital_question}"
          prompt=f"Using this contextual data: {data}.Provide a concise answer to the given query: {article_question}"
     
        ) 
    
        print(output['response']) 
    if index == 19:
        break
# Out:
# 0
# closest distance in vector store:0.669
# article_text:
# Taking into account the nature, scope, context and purposes of processing as well as the risks of varying likelihood and severity for the rights and freedoms of natural persons, the controller shall implement appropriate technical and organisational measures to ensure and to be able to demonstrate that processing is performed in accordance with this Regulation.  Those measures shall be reviewed and updated where necessary.
# article question:
# What kind of measures should a controller implement to ensure and demonstrate compliance with Article 24?
# article answer:
# Appropriate technical and organisational measures.These measures shall be reviewed where necessary
# response from LLM:
# According to the provided contextual data, a controller should implement "appropriate data protection policies" as referred to in paragraph 1. Additionally, adherence to approved codes of conduct (Article 40) or approved certification mechanisms (Article 42) may be used to demonstrate compliance with the obligations of the controller under Article 24.
# 1
# closest distance in vector store:0.836
# article_text:
# Where proportionate in relation to processing activities, the measures referred to in paragraph 1 shall include the implementation of appropriate data protection policies by the controller.  Adherence to approved codes of conduct as referred to in Article 40 or approved certification mechanisms as referred to in Article 42 may be used as an element by which to demonstrate compliance with the obligations of the controller.
# article question:
# What measures should a controller implement when proportionate to processing activities?
# article answer:
# The implementation of appropriate data protection policies
# response from LLM:
# According to the General Data Protection Regulation (GDPR), a controller should implement "appropriate technical and organisational measures" that are proportionate to the processing activities, taking into account the nature, scope, context, and purposes of processing, as well as the risks to natural persons' rights and freedoms. These measures should be reviewed and updated as necessary to ensure that processing is performed in accordance with the GDPR.
# 2
# closest distance in vector store:0.644
# article_text:
# Taking into account the state of the art, the cost of implementation and the nature, scope, context and purposes of processing as well as the risks of varying likelihood and severity for rights and freedoms of natural persons posed by the processing, the controller shall, both at the time of the determination of the means for processing and at the time of the processing itself, implement appropriate technical and organisational measures, such as pseudonymisation, which are designed to implement data-protection principles, such as data minimisation, in an effective manner and to integrate the necessary safeguards into the processing in order to meet the requirements of this Regulation and protect the rights of data subjects.
# article question:
# What measures should a controller take to ensure effective implementation of data protection principles?
# article answer:
# The controller shall implement appropriate technical and organisational measures, such as pseudonymisation, designed to implement data-protection principles, such as data minimisation, in an effective manner, and to integrate the necessary safeguards into the processing.
# response from LLM:
# According to the GDPR guidelines, a controller should take the following measures to ensure effective implementation of data protection principles:
#
# * Ensure the data protection officer (DPO) is involved in all issues related to personal data protection in a timely and proper manner.
# * Seek DPO advice when carrying out a Data Protection Impact Assessment (DPIA).
# * Ensure that any additional tasks or duties assigned to the DPO do not result in a conflict of interests with their primary role.
# 3
# closest distance in vector store:0.363
# article_text:
# The controller shall implement appropriate technical and organisational measures for ensuring that, by default, only personal data which are necessary for each specific purpose of the processing are processed.  That obligation applies to the amount of personal data collected, the extent of their processing, the period of their storage and their accessibility.  In particular, such measures shall ensure that by default personal data are not made accessible without the individual's intervention to an indefinite number of natural persons.
# article question:
# What measures should a controller implement to ensure only necessary personal data is processed?
# article answer:
# Appropriate technical and organisational measures for ensuring that, by default, only personal data which are necessary for each specific purpose of the processing are processed.
# response from LLM:
# According to the GDPR guidelines, a controller should implement technical and organizational measures that ensure:
#
# * Only necessary personal data are collected
# * Processing is limited to the extent required for each specific purpose
# * Data storage period is reasonable and justified by the purpose
# * Data accessibility is restricted to only those who need access, without individual's intervention
#
# In summary, controllers should implement measures to minimize data collection, processing, storage, and accessibility to ensure that only necessary personal data is processed.
# 4
# closest distance in vector store:0.216
# article_text:
# An approved certification mechanism pursuant to Article 42 may be used as an element to demonstrate compliance with the requirements set out in paragraphs 1 and 2 of this Article.
# article question:
# Can an approved certification mechanism be used to demonstrate compliance with Article 42 requirements?
# article answer:
# Yes, it may be used as an element to demonstrate compliance with the requirements set out in paragraphs 1 and 2.
# response from LLM:
# Yes, according to the provided contextual data, an approved certification mechanism may be used as an element to demonstrate compliance with the requirements set out in paragraphs 1 and 2 of this Article.
# 5
# closest distance in vector store:0.738
# article_text:
# The arrangement referred to in paragraph 1 shall duly reflect the respective roles and relationships of the joint controllers vis-à-vis the data subjects.  The essence of the arrangement shall be made available to the data subject.
# article question:
# What does the arrangement between joint controllers reflect?
# article answer:
# The respective roles and relationships of the joint controllers vis-à-vis the data subjects
# response from LLM:
# According to the provided text, the arrangement between joint controllers reflects "the respective roles and relationships" of the joint controllers vis-à-vis the data subjects.
# 6
# closest distance in vector store:0.586
# article_text:
# Irrespective of the terms of the arrangement referred to in paragraph 1, the data subject may exercise his or her rights under this Regulation in respect of and against each of the controllers.
# article question:
# Against whom may the data subjects exercise their rights under this Regulation?
# article answer:
# irrespective of the terms of the arrangement, the data subject may exercise his or her rights under this Regulation in respect of and against each of the controllers
# response from LLM:
# According to the provided contextual data, the data subjects may exercise their rights under this Regulation in respect of and against each of the controllers.
# 7
# closest distance in vector store:0.803
# article_text:
# Representatives of controllers or processors not established in the Union 1.  Where Article 3 (2) applies, the controller or the processor shall designate in writing a representative in the Union.  The obligation laid down in paragraph 1 of this Article shall not apply to: (a) processing which is occasional, does not include, on a large scale, processing of special categories of data as referred to in Article 9 (1) or processing of personal data relating to criminal convictions and offences referred to in Article 10, and is unlikely to result in a risk to the rights and freedoms of natural persons, taking into account the nature, context, scope and purposes of the processing; or (b) a public authority or body.
# article question:
# Under which conditions does the obligation to designate a representative in the Union not apply?
# article answer:
# Where the processing is occasional, does not include on a large scale processing of special categories of data or processing of personal data relating to criminal convictions and offences, and is unlikely to result in a risk to the rights and freedoms of natural persons, taking into account the nature, context, scope and purposes of the processing. It also does not apply to a public authority or body
# response from LLM:
# According to the provided text, the obligation to designate a representative in the Union does not apply under two conditions:
#
# 1. The processing is occasional, does not include large-scale processing of special categories of data or personal data related to criminal convictions and offences, and is unlikely to result in a risk to the rights and freedoms of natural persons.
# 2. The controller or processor is a public authority or body.
# 8
# closest distance in vector store:0.899
# article_text:
# The representative shall be established in one of the Member States where the data subjects, whose personal data are processed in relation to the offering of goods or services to them, or whose behaviour is monitored, are. The representative shall be mandated by the controller or processor to be addressed in addition to or instead of the controller or the processor by, in particular, supervisory authorities and data subjects, on all issues related to processing, for the purposes of ensuring compliance with this Regulation. The designation of a representative by the controller or processor shall be without prejudice to legal actions which could be initiated against the controller or the processor themselves.
# article question:
# What is the requirement for the establishment of a representative under Article 27?
# article answer:
# The representative shall be established in one of the Member States where the data subjects, whose personal data are processed in relation to the offering of goods or services to them, or whose behaviour is monitored, are.
# response from LLM:
# According to Article 27, the representative shall be established in one of the Member States where the data subjects are located, typically where the goods or services are offered or behavior monitored.
# 9
# closest distance in vector store:0.512
# article_text:
# Where processing is to be carried out on behalf of a controller, the controller shall use only processors providing sufficient guarantees to implement appropriate technical and organisational measures in such a manner that processing will meet the requirements of this Regulation and ensure the protection of the rights of the data subject.
# article question:
# What should a controller require from a processor use when processing data on their behalf?
# article answer:
# processors providing sufficient guarantees to implement appropriate technical and organisational measures in such a manner that processing will meet the requirements of this Regulation and ensure the protection of the rights of the data subject.
# response from LLM:
# A controller should require a processor to provide sufficient guarantees to implement appropriate technical and organisational measures that ensure the protection of the data subject's rights, in accordance with this Regulation.
# 10
# closest distance in vector store:0.603
# article_text:
# The processor shall not engage another processor without prior specific or general written authorisation of the controller.
# article question:
# What condition must be met before a processor can engage another processor?
# article answer:
# The processor shall not engage another processor without prior specific or general written authorisation of the controller.
# response from LLM:
# According to the provided contextual data, a processor can only engage another processor with prior specific or general written authorisation of the controller.
# 11
# closest distance in vector store:0.269
# article_text:
# In the case of general written authorisation, the processor shall inform the controller of any intended changes concerning the addition or replacement of other processors, thereby giving the controller the opportunity to object to such changes.
# article question:
# Why should a processor provide to a controller information regarding changes to added or replaced processors in the case of general written authorisation?
# article answer:
# To allow for the controller to object to such changes
# response from LLM:
# A processor should inform the controller of any intended changes concerning the addition or replacement of other processors, giving the controller an opportunity to object to such changes, to ensure that the controller can still exercise control over the processing of personal data and maintain compliance with GDPR requirements.
# 12
# closest distance in vector store:0.419
# article_text:
# Processing by a processor shall be governed by a contract or other legal act under Union or Member State law, that is binding on the processor with regard to the controller and that sets out the subject-matter and duration of the processing, the nature and purpose of the processing, the type of personal data and categories of data subjects and the obligations and rights of the controller.
# article question:
# What should a contract or other legal act under Union or Member State law governing processing by a processor include?
# article answer:
# The subject-matter and duration of the processing, the nature and purpose of the processing, the type of personal data and categories of data subjects, and the obligations and rights of the controller.
# response from LLM:
# According to the provided contextual data, a contract or other legal act under Union or Member State law governing processing by a processor should include:
#
# * Subject-matter and duration of the processing
# * Nature and purpose of the processing
# * Type of personal data and categories of data subjects
# * Obligations and rights of the controller
#
# These elements should be included in the contract or other legal act to ensure that the processor is bound by data protection obligations regarding the controller.
# 13
# closest distance in vector store:0.447
# article_text:
# the processor processes the personal data only on documented instructions from the controller, including with regard to transfers of personal data to a third country or an international organisation, unless required to do so by Union or Member State law to which the processor is subject; in such a case, the processor shall inform the controller of that legal requirement before processing, unless that law prohibits such information on important grounds of public interest;
# article question:
# What are the conditions under which a processor can transfer personal data to a third country or an international organisation?
# article answer:
# The processor processes the personal data only on documented instructions from the controller
# response from LLM:
# A processor can transfer personal data to a third country or international organization:
#
# * Only on documented instructions from the controller (Article 28(3))
# * Unless required by Union or Member State law to which the processor is subject (in such case, the processor shall inform the controller before processing)
# * In the case of transfers referred to in Article 49(1) second subparagraph, with suitable safeguards documented
# 14
# closest distance in vector store:0.470
# article_text:
# the processor ensures that persons authorised to process the personal data have committed themselves to confidentiality or are under an appropriate statutory obligation of confidentiality;
# article question:
# What measures does a processor take regarding authorized personnel handling personal data?
# article answer:
# The processor ensures that persons authorized to process the personal data have committed themselves to confidentiality or are under an appropriate statutory obligation of confidentiality
# response from LLM:
# According to the provided text, a processor takes the following measures regarding authorized personnel handling personal data:
#
# * Ensures that persons authorized to process the personal data have committed themselves to confidentiality or are under an appropriate statutory obligation of confidentiality.
# * Takes steps to ensure that any natural person acting under the authority of the controller or the processor who has access to personal data does not process them except on instructions from the controller, unless required by Union or Member State law.
# 15
# closest distance in vector store:0.596
# article_text:
# the processor takes all measures required pursuant to Article 32 ;
# article question:
# What are the measures that the processor is required to take?
# article answer:
# All measures required pursuant to Article 32
# response from LLM:
# According to Article 32, the processor takes all necessary measures required by that article. Additionally, the processor assists the controller in ensuring compliance with Articles 32-36 and provides sufficient guarantees to implement appropriate technical and organisational measures to meet the requirements of the Regulation.
# 16
# closest distance in vector store:0.365
# article_text:
# the processor taking into account the nature of the processing, assists the controller by appropriate technical and organisational measures, insofar as this is possible, for the fulfilment of the controller's obligation to respond to requests for exercising the data subject's rights laid down in Chapter III;
# article question:
# What does the processor need to do to assist the controller in responding to data subjects' rights requests?
# article answer:
# the processor needs to take appropriate technical and organisational measures, insofar as this is possible, for the fulfilment of the controller's obligation
# response from LLM:
# According to the provided context, the processor needs to take "appropriate technical and organisational measures" to assist the controller in responding to requests for exercising the data subject's rights laid down in Chapter III.
# 17
# closest distance in vector store:0.503
# article_text:
# the processor assists the controller in ensuring compliance with the obligations pursuant to Articles 32 to 36 taking into account the nature of processing and the information available to the processor;
# article question:
# What obligations does the processor ensure compliance with ?
# article answer:
# obligations pursuant to Articles 32 to 36 taking into account the nature of processing and the information available to the processor.
# response from LLM:
# According to the provided contextual data, the processor ensures compliance with the obligations pursuant to Articles 32 to 36 of the Regulation, taking into account the nature of processing and the information available to the processor.
# 18
# closest distance in vector store:0.504
# article_text:
# the processor at the choice of the controller, deletes or returns all the personal data to the controller after the end of the provision of services relating to processing, and deletes existing copies unless Union or Member State law requires storage of the personal data;
# article question:
# What is the processor's responsibility regarding personal data at the end of service provision?
# article answer:
# The processor, at the choice of the controller, deletes or returns all the personal data to the controller after the end of the provision of services relating to processing, and deletes existing copies unless Union or Member State law requires storage of the personal data.
# response from LLM:
# According to the given contextual data, the processor's responsibility regarding personal data at the end of service provision is:
#
# * To delete or return all personal data to the controller, and
# * To delete existing copies unless Union or Member State law requires storage of the personal data.
# 19
# closest distance in vector store:0.385
# article_text:
# the processor makes available to the controller all information necessary to demonstrate compliance with the obligations laid down in this Article and allow for and contribute to audits, including inspections, conducted by the controller or another auditor mandated by the controller.
# article question:
# Why does the processor need to make available to the controller all information necessary to demonstrate compliance with the obligations laid down in this article?
# article answer:
# to allow for and contribute to audits, including inspections,conducted by the controller or another auditor mandated by the controller
# response from LLM:
# The processor needs to make available to the controller all information necessary to demonstrate compliance with the obligations laid down in this article, so that the controller can perform audits and inspections, including conducting its own audits or mandating another auditor, and ensure that the processor is indeed compliant with the obligations.

# %%
# generate an embedding for the input and retrieve the most relevant doc as context to LLM query
response = ollama.embed(
      model="all-minilm",
      input=sample_recital_text
)

results = collection.query(
      query_embeddings=[response["embeddings"][0]],
      n_results=2
)

    
    
closest_dist = results['distances'][0][0]
closest_id = results['ids'][0][0]
if closest_dist < 10.0:
        print(sample_recital_text)
        print("closest distance:%3.3f" %(closest_dist))
        print("closest id:%s" %closest_id)
        #data = results['documents'][0][0]
        # return all documents
        data = results['documents'][0][0]
        
        print("closest documents:")
        print(data)

print("sample question and given answer") 
input =sample_recital_text
#input= sample_recital_question
#print(input)
#print(sample_recital_answer)

print(" response from LLM ")

#generate a response combining the prompt and data we retrieved in step 2
output = ollama.generate(
  model="llama3:8b",
  #prompt=f"Using this data: {data}. Respond to this prompt: {input}"
  #prompt=f"Using this contextual data: {data}.Provide a concise answer to the given query: {input}"
  #prompt=f"Using this contextual data: {data}, provide three additional concise obligations as one sentence only, where the obligation is not present in the original input text: {input}. Do not output any other text except the obligation. Output a maximum of three obligations. Each obligation should be a sentence starting with a capital letter and ending with a period"
  prompt=f"Using this contextual data only: {data}, provide three additional concise obligations as one sentence only, where the obligation is not present in the original input text: {input}. Do not output any other text except the obligation. Output a maximum of three obligations. The obligation should be in the contextual data {data}"
    
     
  
  #prompt=f"Using this contextual data: {data}.Provide additional information not present in the original context: {input}"
) 

print(output['response'])
# Out:
# A data protection impact assessment is equally required for monitoring publicly accessible areas on a large scale, especially when using optic-electronic devices or for any other operations where the competent supervisory authority considers that the processing is likely to result in a high risk to the rights and freedoms of data subjects, in particular because they prevent data subjects from exercising a right or using a service or a contract, or because they are carried out systematically on a large scale.
# closest distance:0.469
# closest id:60:article:35
# closest documents:
# A data protection impact assessment referred to in paragraph 1 shall in particular be required in the case of: (a) a systematic and extensive evaluation of personal aspects relating to natural persons which is based on automated processing, including profiling, and on which decisions are based that produce legal effects concerning the natural person or similarly significantly affect the natural person; (b) processing on a large scale of special categories of data referred to in Article 9 (1) or of personal data relating to criminal convictions and offences referred to in Article 10 ; or (c) a systematic monitoring of a publicly accessible area on a large scale.
# sample question and given answer
#  response from LLM
# Here are three additional concise obligations as one sentence only:
#
# * The data controller shall ensure that the data protection impact assessment is reviewed and updated at least every two years, or whenever there is a significant change in the processing activities.
# * In cases where the data processing affects vulnerable individuals, such as children or seniors, the data controller shall involve them in the decision-making process to minimize potential harm.
# * The data controller shall provide clear and concise information about the data protection impact assessment to the data subjects, including details on how their personal data will be processed and protected.

# %% [markdown]
# expand recitals using articles

# %%
import re

expanded_recitals= [] 

for index,recital in enumerate(recital_json_data):
    print(index)
    recital_text = recital['InputText']
    
    # generate an embedding for the input and retrieve the most relevant doc
    response = ollama.embed(
      model="all-minilm",
      input=recital_text
    )

    results = collection.query(
      query_embeddings=[response["embeddings"][0]],
      n_results=3
    )

    closest_dist = results['distances'][0][0]

   
    print("%3.3f" %(closest_dist))
       
            
    closest_id = results['ids'][0][0]
        #data = results['documents'][0][0]
        # add all returned documents not just the first
    data = results['documents'][0][0]
        
        #print("recital_text:")
    print(recital_text)
        #print("returned document")
    print(data)
        
    
    input= recital_text
    
    print("response from LLM:")
        #generate a response combining the prompt and data we retrieved in step 2
    output = ollama.generate(
          model="llama3:8b",
          prompt=f"Using this contextual data: {data}, provide three additional concise obligations as one sentence only, where the obligation is not present in the original input text: {input}. Do not output any other text except the obligation. Output a maximum of three obligations. Each obligation should be a sentence starting with a capital letter and ending with a period"  
     
        ) 

    
    other_obligations = []
    
    print(output['response']) 
    sentences = re.split(r' *[0-9\:\*\.\?!;] *', output['response'])

    print(sentences)
    
    for sentence in sentences:
        if not "concise obligation" in sentence:
            
            sentence = sentence.strip()
             
            if len(sentence) > 0:
                print(sentence)
                other_obligations.append(sentence)
        
    new_recital= {}
    new_recital['InputText'] = recital['InputText']
    new_recital['question'] = recital['question']
    new_recital['answer'] = recital['answer']
    new_recital['expanded_score'] = closest_dist
    new_recital['expanded'] = other_obligations
    new_recital['Recital'] = recital['Recital']
    expanded_recitals.append(new_recital)

output_json_filename = "Output/gdpr_chapter4_expanded_recitals.json"

with open(output_json_filename, 'w') as json_file:
    json.dump(expanded_recitals, json_file, indent=4)

print(f"expanded recitals saved to {output_json_filename}")

# %%
gdpr_expanded_recital_json_filename = 'Output/gdpr_chapter4_expanded_recitals.json'

with open(gdpr_expanded_recital_json_filename) as json_file:
    recital_json_data = json.load(json_file)
print(len(recital_json_data))
# Out:
# 46

# %%
expanded_articles= [] 

for index,article in enumerate(article_json_data):
    print(index)
    article_text = article['InputText']
    
    # generate an embedding for the input and retrieve the most relevant doc
    response = ollama.embed(
      model="all-minilm",
      input=article_text
    )

    results = recital_collection.query(
      query_embeddings=[response["embeddings"][0]],
      n_results=2
    )

    closest_dist = results['distances'][0][0]

   
    print("%3.3f" %(closest_dist))
       
            
    closest_id = results['ids'][0][0]
        #data = results['documents'][0][0]
        # add all returned documents not just the first
    data = results['documents'][0]
        
        #print("recital_text:")
    print(article_text)
        #print("returned document")
    print(data)
        
    
    input= article_text
    
    print("response from LLM:")
        #generate a response combining the prompt and data we retrieved in step 2
    output = ollama.generate(
          model="llama3:8b",
          #prompt=f"Using this contextual data: {data}, provide three additional concise obligations as one sentence only, where the obligation is not present in the original input text: {input}. Do not output any other text except the obligation. Output a maximum of three obligations. Each obligation should be a single sentence and should be contained in the contextual data {data}"  
          prompt=f"Using this contextual data: {data}, provide three additional concise obligations as one sentence only, where the obligation is not present in the original input text: {input}. Do not output any other text except the obligation. Output a maximum of three obligations. Each obligation should be a single sentence.  Each obligation should be contained explicitly  in the contextual data"  
     
        ) 
    
    print(output['response'])

    
    other_obligations = []
    
    print(output['response']) 
    sentences = re.split(r' *[0-9\:\*\.\?!;] *', output['response'])

    print(sentences)
    
    for sentence in sentences:
        if not "concise obligation" in sentence:
            
            sentence = sentence.strip()
             
            if len(sentence) > 0:
                print(sentence)
                other_obligations.append(sentence)
    new_article= {}
    new_article['InputText'] = article['InputText']
    new_article['question'] = article['question']
    new_article['answer'] = article['answer']
    new_article['expanded_score'] = f"%3.4f" %closest_dist
    new_article['expanded'] = other_obligations
    new_article['Article'] = article['Article']
    expanded_articles.append(new_article)

output_json_filename = "Output/gdpr_24_43_expanded_articles2.json"

with open(output_json_filename, 'w') as json_file:
    json.dump(expanded_articles, json_file, indent=4)

print(f"expanded recitals saved to {output_json_filename}")

# %%
gdpr_expanded_recital_json_filename = 'Output/gdpr_24_43_expanded_articles2.json'

with open(gdpr_expanded_recital_json_filename) as json_file:
    recital_json_data = json.load(json_file)
print(len(recital_json_data))
# Out:
# 122

# %% [markdown]
# use Langchain

# %%
from langchain_ollama import OllamaEmbeddings
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.vectorstores import InMemoryVectorStore

from langchain_core.documents import Document
from langchain_ollama import OllamaLLM

from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import PromptTemplate

# %%
embeddings = OllamaEmbeddings(
model='all-minilm',
)

# %%
vector_store = InMemoryVectorStore(embeddings)

# %%
documents= []
for index, article in enumerate(article_json_data):
   
    content = article["InputText"]
    identifier =  str(index+1)+":article:" + article['Article']
    
    document_1 = Document(id=identifier, page_content=content,metadata={"id": identifier})
    print(document_1.metadata)
    
    documents.append(document_1)
    
vector_store.add_documents(documents)


print(len(vector_store.store.items()))
# Out:
# {'id': '1:article:24'}
# {'id': '2:article:24'}
# {'id': '3:article:25'}
# {'id': '4:article:25'}
# {'id': '5:article:25'}
# {'id': '6:article:26'}
# {'id': '7:article:26'}
# {'id': '8:article:27'}
# {'id': '9:article:27'}
# {'id': '10:article:28'}
# {'id': '11:article:28'}
# {'id': '12:article:28'}
# {'id': '13:article:28'}
# {'id': '14:article:28'}
# {'id': '15:article:28'}
# {'id': '16:article:28'}
# {'id': '17:article:28'}
# {'id': '18:article:28'}
# {'id': '19:article:28'}
# {'id': '20:article:28'}
# {'id': '21:article:28'}
# {'id': '22:article:28'}
# {'id': '23:article:28'}
# {'id': '24:article:28'}
# {'id': '25:article:28'}
# {'id': '26:article:29'}
# {'id': '27:article:30'}
# {'id': '28:article:30'}
# {'id': '29:article:30'}
# {'id': '30:article:30'}
# {'id': '31:article:30'}
# {'id': '32:article:30'}
# {'id': '33:article:30'}
# {'id': '34:article:30'}
# {'id': '35:article:30'}
# {'id': '36:article:30'}
# {'id': '37:article:30'}
# {'id': '38:article:30'}
# {'id': '39:article:30'}
# {'id': '40:article:30'}
# {'id': '41:article:31'}
# {'id': '42:article:32'}
# {'id': '43:article:32'}
# {'id': '44:article:32'}
# {'id': '45:article:32'}
# {'id': '46:article:32'}
# {'id': '47:article:32'}
# {'id': '48:article:32'}
# {'id': '49:article:33'}
# {'id': '50:article:33'}
# {'id': '51:article:33'}
# {'id': '52:article:33'}
# {'id': '53:article:33'}
# {'id': '54:article:34'}
# {'id': '55:article:34'}
# {'id': '56:article:34'}
# {'id': '57:article:34'}
# {'id': '58:article:35'}
# {'id': '59:article:35'}
# {'id': '60:article:35'}
# {'id': '61:article:35'}
# {'id': '62:article:35'}
# {'id': '63:article:35'}
# {'id': '64:article:35'}
# {'id': '65:article:35'}
# {'id': '66:article:35'}
# {'id': '67:article:35'}
# {'id': '68:article:35'}
# {'id': '69:article:35'}
# {'id': '70:article:36'}
# {'id': '71:article:36'}
# {'id': '72:article:36'}
# {'id': '73:article:36'}
# {'id': '74:article:36'}
# {'id': '75:article:37'}
# {'id': '76:article:37'}
# {'id': '77:article:37'}
# {'id': '78:article:37'}
# {'id': '79:article:37'}
# {'id': '80:article:37'}
# {'id': '81:article:38'}
# {'id': '82:article:38'}
# {'id': '83:article:38'}
# {'id': '84:article:38'}
# {'id': '85:article:38'}
# {'id': '86:article:38'}
# {'id': '87:article:39'}
# {'id': '88:article:39'}
# {'id': '89:article:40'}
# {'id': '90:article:40'}
# {'id': '91:article:40'}
# {'id': '92:article:40'}
# {'id': '93:article:40'}
# {'id': '94:article:40'}
# {'id': '95:article:40'}
# {'id': '96:article:40'}
# {'id': '97:article:40'}
# {'id': '98:article:40'}
# {'id': '99:article:40'}
# {'id': '100:article:41'}
# {'id': '101:article:41'}
# {'id': '102:article:41'}
# {'id': '103:article:41'}
# {'id': '104:article:41'}
# {'id': '105:article:41'}
# {'id': '106:article:42'}
# {'id': '107:article:42'}
# {'id': '108:article:42'}
# {'id': '109:article:42'}
# {'id': '110:article:42'}
# {'id': '111:article:42'}
# {'id': '112:article:42'}
# {'id': '113:article:42'}
# {'id': '114:article:43'}
# {'id': '115:article:43'}
# {'id': '116:article:43'}
# {'id': '117:article:43'}
# {'id': '118:article:43'}
# {'id': '119:article:43'}
# {'id': '120:article:43'}
# {'id': '121:article:43'}
# {'id': '122:article:43'}
# 122

# %%
for index, (id, doc) in enumerate(vector_store.store.items()):
    print(id)
    print(doc['id'])
    
    print(doc['metadata'])
    break
# Out:
# 1:article:24
# 1:article:24
# {'id': '1:article:24'}

# %%
sample_recital_question = "What types of harm can result from personal data processing?"
 
input = sample_recital_question
# Use the vectorstore as a retriever
retriever = vector_store.as_retriever()

# Retrieve the most similar text
retrieved_documents = retriever.invoke(input)
print(len(retrieved_documents))
# Show the retrieved document's content

for doc in retrieved_documents:
    print(doc.id)
    print(doc.page_content)
    print(f'{doc.metadata}')
# Out:
# 4
# 58:article:35
# Where a type of processing in particular using new technologies, and taking into account the nature, scope, context and purposes of the processing, is likely to result in a high risk to the rights and freedoms of natural persons, the controller shall, prior to the processing, carry out an assessment of the impact of the envisaged processing operations on the protection of personal data.
# {'id': '58:article:35'}
# 55:article:34
# The communication to the data subject referred to in paragraph 1 of this Article shall describe in clear and plain language the nature of the personal data breach and contain at least the information and measures referred to in points (b) (c) and (d) of Article 33 (3)
# {'id': '55:article:34'}
# 61:article:35
# A data protection impact assessment referred to in paragraph 1 shall in particular be required in the case of: (a) a systematic and extensive evaluation of personal aspects relating to natural persons which is based on automated processing, including profiling, and on which decisions are based that produce legal effects concerning the natural person or similarly significantly affect the natural person; (b) processing on a large scale of special categories of data referred to in Article 9 (1) or of personal data relating to criminal convictions and offences referred to in Article 10 ; or (c) a systematic monitoring of a publicly accessible area on a large scale.
# {'id': '61:article:35'}
# 29:article:30
# The record  of processing activities shall contain a description of the categories of data subjects and of the categories of personal data;
# {'id': '29:article:30'}

# %%
results = vector_store.similarity_search_with_score(
    query=input, k=4
)
for doc, score in results:
    print(f"* [SIM={score:3f}] {doc.page_content} [{doc.metadata}]")
    print(doc.metadata)
# Out:
# * [SIM=0.886298] Representatives of controllers or processors not established in the Union 1.  Where Article 3 (2) applies, the controller or the processor shall designate in writing a representative in the Union.  The obligation laid down in paragraph 1 of this Article shall not apply to: (a) processing which is occasional, does not include, on a large scale, processing of special categories of data as referred to in Article 9 (1) or processing of personal data relating to criminal convictions and offences referred to in Article 10, and is unlikely to result in a risk to the rights and freedoms of natural persons, taking into account the nature, context, scope and purposes of the processing; or (b) a public authority or body. [{'id': '8:article:27'}]
# {'id': '8:article:27'}
# * [SIM=0.786815] The representative shall be established in one of the Member States where the data subjects, whose personal data are processed in relation to the offering of goods or services to them, or whose behaviour is monitored, are. The representative shall be mandated by the controller or processor to be addressed in addition to or instead of the controller or the processor by, in particular, supervisory authorities and data subjects, on all issues related to processing, for the purposes of ensuring compliance with this Regulation. The designation of a representative by the controller or processor shall be without prejudice to legal actions which could be initiated against the controller or the processor themselves. [{'id': '9:article:27'}]
# {'id': '9:article:27'}
# * [SIM=0.767030] Processing by a processor shall be governed by a contract or other legal act under Union or Member State law, that is binding on the processor with regard to the controller and that sets out the subject-matter and duration of the processing, the nature and purpose of the processing, the type of personal data and categories of data subjects and the obligations and rights of the controller. [{'id': '13:article:28'}]
# {'id': '13:article:28'}
# * [SIM=0.765732] Processing under the authority of the controller or processor. The processor and any person acting under the authority of the controller or of the processor, who has access to personal data, shall not process those data except on instructions from the controller, unless required to do so by Union or Member State law. [{'id': '26:article:29'}]
# {'id': '26:article:29'}

# %%
# need to specify search_kwargs or do not get a doc id or meta data (?)
retriever = vector_store.as_retriever(
    #search_type="mmr",
    #search_kwargs={"k": 2, "fetch_k": 2},
    search_kwargs={"k": 4},
)
retrieved_documents= retriever.invoke(input)

for doc in retrieved_documents:
    print(doc.id)
    print(doc.page_content)
    print(f'{doc.metadata}')
# Out:
# 1:article:24
# Taking into account the nature, scope, context and purposes of processing as well as the risks of varying likelihood and severity for the rights and freedoms of natural persons, the controller shall implement appropriate technical and organisational measures to ensure and to be able to demonstrate that processing is performed in accordance with this Regulation.  Those measures shall be reviewed and updated where necessary.
# {'id': '1:article:24'}
# 45:article:32
# Taking into account the state of the art, the costs of implementation and the nature, scope, context and purposes of processing as well as the risk of varying likelihood and severity for the rights and freedoms of natural persons, the controller and the processor shall implement appropriate technical and organisational measures to ensure a level of security appropriate to the risk, including inter alia as appropriate: a process for regularly testing, assessing and evaluating the effectiveness of technical and organisational measures for ensuring the security of the processing.
# {'id': '45:article:32'}
# 58:article:35
# Where a type of processing in particular using new technologies, and taking into account the nature, scope, context and purposes of the processing, is likely to result in a high risk to the rights and freedoms of natural persons, the controller shall, prior to the processing, carry out an assessment of the impact of the envisaged processing operations on the protection of personal data.
# {'id': '58:article:35'}
# 43:article:32
# Taking into account the state of the art, the costs of implementation and the nature, scope, context and purposes of processing as well as the risk of varying likelihood and severity for the rights and freedoms of natural persons, the controller and the processor shall implement appropriate technical and organisational measures to ensure a level of security appropriate to the risk, including inter alia as appropriate: the ability to ensure the ongoing confidentiality, integrity, availability and resilience of processing systems and services;
# {'id': '43:article:32'}

# %%
from typing import List

from langchain_core.documents import Document
from langchain_core.runnables import chain
# the following adds a score to the meta data by creating a retrieval function that is a wrapper to similariry search
# to allow for a similarity score to be recorded in the metadata. However was unable to get this to work  
# in the langchain

@chain
def wrapped_retriever(query: str) -> List[Document]:
    docs, scores = zip(*vector_store.similarity_search_with_score(query,k=4))
    for doc, score in zip(docs, scores):
        #print(doc.metadata)
        doc.metadata["score"] = score

    return docs

# %%
print(article_json_data[0])
# Out:
# {'question': 'What kind of measures should a controller implement to ensure and demonstrate compliance with Article 24?', 'answer': 'Appropriate technical and organisational measures.These measures shall be reviewed where necessary', 'InputText': 'Taking into account the nature, scope, context and purposes of processing as well as the risks of varying likelihood and severity for the rights and freedoms of natural persons, the controller shall implement appropriate technical and organisational measures to ensure and to be able to demonstrate that processing is performed in accordance with this Regulation.  Those measures shall be reviewed and updated where necessary.', 'Article': '24'}

# %%
input = article_json_data[0]['InputText']


retrieved_documents= wrapped_retriever.invoke(input)

for doc in retrieved_documents:
    print(doc.id)
    print(doc.page_content)
    print(f'{doc.metadata}')
# Out:
# 1:article:24
# Taking into account the nature, scope, context and purposes of processing as well as the risks of varying likelihood and severity for the rights and freedoms of natural persons, the controller shall implement appropriate technical and organisational measures to ensure and to be able to demonstrate that processing is performed in accordance with this Regulation.  Those measures shall be reviewed and updated where necessary.
# {'id': '1:article:24', 'score': 1.0}
# 45:article:32
# Taking into account the state of the art, the costs of implementation and the nature, scope, context and purposes of processing as well as the risk of varying likelihood and severity for the rights and freedoms of natural persons, the controller and the processor shall implement appropriate technical and organisational measures to ensure a level of security appropriate to the risk, including inter alia as appropriate: a process for regularly testing, assessing and evaluating the effectiveness of technical and organisational measures for ensuring the security of the processing.
# {'id': '45:article:32', 'score': 0.8051492948682792}
# 58:article:35
# Where a type of processing in particular using new technologies, and taking into account the nature, scope, context and purposes of the processing, is likely to result in a high risk to the rights and freedoms of natural persons, the controller shall, prior to the processing, carry out an assessment of the impact of the envisaged processing operations on the protection of personal data.
# {'id': '58:article:35', 'score': 0.7839263538789183}
# 43:article:32
# Taking into account the state of the art, the costs of implementation and the nature, scope, context and purposes of processing as well as the risk of varying likelihood and severity for the rights and freedoms of natural persons, the controller and the processor shall implement appropriate technical and organisational measures to ensure a level of security appropriate to the risk, including inter alia as appropriate: the ability to ensure the ongoing confidentiality, integrity, availability and resilience of processing systems and services;
# {'id': '43:article:32', 'score': 0.754204096569731}

# %%
sample_recital_question="What types of harms can result from personal data processing?"
system_prompt = (
    "Use only the given context to answer the question. "
    "Context: {context}"
)
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}"),
    ]
)
llm = OllamaLLM(model="llama3:8b")


question_answer_chain = create_stuff_documents_chain(llm, prompt)
# not able to use this wrapped retreiver in a chain 
#chain = create_retrieval_chain(wrapped_retriever, question_answer_chain)
chain = create_retrieval_chain(retriever, question_answer_chain)

print("sample query:")
print(sample_recital_question)

result = chain.invoke({"input": sample_recital_question})

context_docs = result['context']
for context_doc in context_docs:
    print(context_doc.id)
    print(context_doc.page_content)
    print(context_doc.metadata)
    
print(result['answer'])
# Out:
# sample query:
# What types of harms can result from personal data processing?
# 58:article:35
# Where a type of processing in particular using new technologies, and taking into account the nature, scope, context and purposes of the processing, is likely to result in a high risk to the rights and freedoms of natural persons, the controller shall, prior to the processing, carry out an assessment of the impact of the envisaged processing operations on the protection of personal data.
# {'id': '58:article:35'}
# 55:article:34
# The communication to the data subject referred to in paragraph 1 of this Article shall describe in clear and plain language the nature of the personal data breach and contain at least the information and measures referred to in points (b) (c) and (d) of Article 33 (3)
# {'id': '55:article:34'}
# 61:article:35
# A data protection impact assessment referred to in paragraph 1 shall in particular be required in the case of: (a) a systematic and extensive evaluation of personal aspects relating to natural persons which is based on automated processing, including profiling, and on which decisions are based that produce legal effects concerning the natural person or similarly significantly affect the natural person; (b) processing on a large scale of special categories of data referred to in Article 9 (1) or of personal data relating to criminal convictions and offences referred to in Article 10 ; or (c) a systematic monitoring of a publicly accessible area on a large scale.
# {'id': '61:article:35'}
# 29:article:30
# The record  of processing activities shall contain a description of the categories of data subjects and of the categories of personal data;
# {'id': '29:article:30'}
# Based on the given context, potential harm to natural persons' rights and freedoms that can result from personal data processing include:
#
# * A systematic and extensive evaluation of personal aspects relating to natural persons which is based on automated processing, including profiling, and on which decisions are based that produce legal effects concerning the natural person or similarly significantly affect the natural person.
# * Processing on a large scale of special categories of data referred to in Article 9 (1) or of personal data relating to criminal convictions and offences referred to in Article 10.
# * A systematic monitoring of a publicly accessible area on a large scale.
#
# These types of processing can potentially result in high risks to the rights and freedoms of natural persons, such as invasion of privacy, discrimination, or harm to reputation.

# %%
print(result)
# Out:
# {'input': 'What types of harm can result from personal data processing?', 'context': [Document(id='58:article:35', metadata={'id': '58:article:35'}, page_content='Where a type of processing in particular using new technologies, and taking into account the nature, scope, context and purposes of the processing, is likely to result in a high risk to the rights and freedoms of natural persons, the controller shall, prior to the processing, carry out an assessment of the impact of the envisaged processing operations on the protection of personal data.'), Document(id='55:article:34', metadata={'id': '55:article:34'}, page_content='The communication to the data subject referred to in paragraph 1 of this Article shall describe in clear and plain language the nature of the personal data breach and contain at least the information and measures referred to in points (b) (c) and (d) of Article 33 (3)'), Document(id='61:article:35', metadata={'id': '61:article:35'}, page_content='A data protection impact assessment referred to in paragraph 1 shall in particular be required in the case of: (a) a systematic and extensive evaluation of personal aspects relating to natural persons which is based on automated processing, including profiling, and on which decisions are based that produce legal effects concerning the natural person or similarly significantly affect the natural person; (b) processing on a large scale of special categories of data referred to in Article 9 (1) or of personal data relating to criminal convictions and offences referred to in Article 10 ; or (c) a systematic monitoring of a publicly accessible area on a large scale.'), Document(id='29:article:30', metadata={'id': '29:article:30'}, page_content='The record  of processing activities shall contain a description of the categories of data subjects and of the categories of personal data; ')], 'answer': 'According to the given context, high-risk personal data processing can result in "high risk to the rights and freedoms of natural persons".'}

# %%
for index,recital in enumerate(recital_json_data):
    print(index)
    recital_question = recital['question']
    recital_answer= recital['answer']
    print("query:")
    print(recital_question)
    print(recital_answer)

    result = chain.invoke({"input": recital_question})

    print("response")
    
    context_docs = result['context']
    for context_doc in context_docs:
        #print(context_doc.page_content)
        print(context_doc.metadata)
    
    
    print(result['answer'])

# %% [markdown]
# Langchain LCEL implementation

# %%
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)


system_prompt = (
    "Use only the given context to answer the following question. "
    "Context: {context}"
)
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}"),
    ]
)

prompt_text = """"
{context}

You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.
Question: {question}
Context: {context}
Answer:
"""


prompt = PromptTemplate.from_template(prompt_text)



llm = OllamaLLM(model="llama3:8b")



qa_chain = (
    {
        "context": retriever | format_docs,
        "question": RunnablePassthrough(),
    }
    | prompt
    | llm
    | StrOutputParser()
)

print("sample query:")
print(sample_recital_question)

#result = qa_chain.invoke({"input":sample_recital_question})
result = qa_chain.invoke(sample_recital_question)
    
print(result)
# Out:
# sample query:
# What kind of measures should a controller establish to demonstrate compliance with this Regulation?
# According to the provided context, a controller should establish technical and organisational measures that are proportionate to processing activities, including implementing appropriate data protection policies. Additionally, adherence to approved codes of conduct or certification mechanisms can be used as an element to demonstrate compliance with the regulation's obligations. These measures should be reviewed and updated as necessary to ensure and demonstrate compliance.

# %% [markdown]
# use knowledge graph to create a prompt

# %%
def generate_answer_based_on_kg_enhance_prompt(kg_row, article,use_question=True):
    
    article_text = article['InputText']
    
    article_question = article['question']
    article_answer = article['answer']

    query_text = article_text
    if use_question:
        query_text =article_question
    # generate an embedding for the input and retrieve the most relevant doc
    # if we use just the question the result will not be so close
    response = ollama.embed(
      model="all-minilm",
      input=query_text
      #input=article_text  
    )

    results = collection.query(
      query_embeddings=[response["embeddings"][0]],
      n_results=3
    )

    #print(results)
    
    closest_dist = results['distances'][0][0]

    if closest_dist < 10.0:
        #print(index)
   
        print("closest distance in vector store:%3.3f" %(closest_dist))
        #print("closest document id %s" %(closest_id))
       
            
        closest_id = results['ids'][0][0]
        #data = results['documents'][0][0]
        # add all returned documents not just the first
        data = results['documents'][0]
        
        print("article_text:")
        print(article_text)
        #print("returned document")
        #print(data)
        
        print("article question:")
        print(article_question)
    
        print("article answer:")
        print(article_answer)
    
        #Using this contextual data: {data} and the following reference knowledge graph, provide a concise answer to the given query: {article_question}
        #Using the following reference knowledge graph, provide a concise answer to the given query: {article_question}
        
        promptText = f"""
        Using this contextual data: {data} and the following reference knowledge graph, provide a concise answer to the given query: {article_question}
        
        Reference Knowledge Graph:
        Type: {kg_row['Type']}
        Actor: {kg_row['Actor']}
        Action: {kg_row['Action']}
        Reason: {kg_row['Reason']}
        Condition: {kg_row['Condition']}
        Modality: {kg_row['Modality']}
        Exception: {kg_row['Exception']}
        Violation: {kg_row['Violation']}
        Artifact: {kg_row['Artifact']}
        Presence: {kg_row['Presence']}
         """
        #generate a response combining the prompt and data we retrieved in step 2
        output = ollama.generate(
          model="llama3:8b",
          prompt=promptText
        )
        #print(promptText)

        print("response from LLM:")

        print(output['response'])

        return data,output['response']

# %%
def generate_answer_based_on_context(article,use_question=True):
    
    article_text = article['InputText']
    
    article_question = article['question']
    article_answer = article['answer']

    query_text = article_text
    if use_question:
        query_text =article_question
    # generate an embedding for the input and retrieve the most relevant doc
    # if we use just the question the result will not be so close
    response = ollama.embed(
      model="all-minilm",
      input=query_text
      #input=article_text  
    )

    results = collection.query(
      query_embeddings=[response["embeddings"][0]],
      n_results=3
    )

    #print(results)
    
    closest_dist = results['distances'][0][0]

    if closest_dist < 10.0:
        #print(index)
   
        print("closest distance in vector store:%3.3f" %(closest_dist))
        #print("closest document id %s" %(closest_id))
       
            
        closest_id = results['ids'][0][0]
        #data = results['documents'][0][0]
        # add all returned documents not just the first
        data = results['documents'][0]
        
        print("article_text:")
        print(article_text)
        #print("returned document")
        #print(data)
        
        print("article question:")
        print(article_question)
    
        print("article answer:")
        print(article_answer)
    
        #Using this contextual data: {data} and the following reference knowledge graph, provide a concise answer to the given query: {article_question}
        #Using the following reference knowledge graph, provide a concise answer to the given query: {article_question}
        
        promptText = f"""
        Using this contextual data: {data}  provide a concise answer to the given query: {article_question}
         """
        #generate a response combining the prompt and data we retrieved in step 2
        output = ollama.generate(
          model="llama3:8b",
          prompt=promptText
        )
        #print(promptText)

        print("response from LLM:")

        print(output['response'])

        return data,output['response']

# %% [raw]
# find the article that matches the article question and use its associated kg within the prompt without any context

# %%
def generate_answer_based_on_related_kg_enhance_prompt(kg_rows, article):
    
    article_text = article['InputText']
    
    article_question = article['question']
    article_answer = article['answer']

    # generate an embedding for the input and retrieve the most relevant doc
    response = ollama.embed(
      model="all-minilm",
      input=article_question
    )

    results = collection.query(
      query_embeddings=[response["embeddings"][0]],
      n_results=3
    )

    
    closest_dist = results['distances'][0][0]

    print("closest distance in vector store:%3.3f" %(closest_dist))
        #print("closest document id %s" %(closest_id))
       
            
    closest_id = results['ids'][0][0]
    print("closest article in vector store:%s" %closest_id)
        #data = results['documents'][0][0]
        # add all returned documents not just the first
    data = results['documents'][0]
        
    print("article_text:")
    print(article_text)
    # find the article index of the closest embedding and use corresponding knowedge graph
    article_index = int(closest_id.split(":")[0])

    #print(article_index)
    # use kg associated with closest matchin article
    kg_row = kg_rows[article_index]
        #print("returned document")
        #print(data)
        
    print("article question:")
    print(article_question)
    
    print("article answer:")
    print(article_answer)
    
    
#Using this contextual data: {data} and the following reference knowledge graph, provide a concise answer to the given query: {article_question}
        
    promptText = f"""
        Using this contextual data: {data} and the following reference knowledge graph, provide a concise answer to the given query {article_question}
        
        Reference Knowledge Graph:
        Type: {kg_row['Type']}
        Actor: {kg_row['Actor']}
        Action: {kg_row['Action']}
        Reason: {kg_row['Reason']}
        Condition: {kg_row['Condition']}
        Modality: {kg_row['Modality']}
        Exception: {kg_row['Exception']}
        Violation: {kg_row['Violation']}
        Artifact: {kg_row['Artifact']}
        Presence: {kg_row['Presence']}
         """
    #print(promptText)

    print("response from LLM:")
    
    #generate a response combining the prompt and data we retrieved in step 2
    output = ollama.generate(
          model="llama3:8b",
          prompt=promptText
        )
        
    print(output['response'])
        
    return data, output['response']

# %%
kg_data = pd.read_excel("Output/gdpr_articles_24_43_kg_output_corrected.xlsx")
# one more entry in the following txt as noticed as indvidual sentence at the end of recital 86 with no qa but seems an obligation
#data = pd.read_excel("Output/gdpr_chapter4_recital_kg_output_corrected.xlsx")

statements_all = kg_data["InputText"].tolist()
print(len(statements_all))



    # Iterate over each row and generate the improved statement
for index,(kg_row,article_data) in enumerate(zip(kg_data.iterrows(),article_json_data)):

        print(index)
        #print(article_data)
        kg_row = kg_row[1]
        #print(kg_row)
        generate_answer_based_on_kg_enhance_prompt(kg_row,article_data)

        if index==19:
            break

# %%
kg_data = pd.read_excel("Output/gdpr_articles_24_43_kg_output_corrected.xlsx")
# one more entry in the following txt as noticed as indvidual sentence at the end of recital 86 with no qa but seems an obligation
#data = pd.read_excel("Output/gdpr_chapter4_recital_kg_output_corrected.xlsx")

statements_all = kg_data["InputText"].tolist()
print(len(statements_all))

kg_list = [] 
for kg_row in kg_data.iterrows():
    kg_row = kg_row[1]
    kg_list.append(kg_row)
  
for index,article_data in enumerate(article_json_data):

        print(index)
        generate_answer_based_on_related_kg_enhance_prompt(kg_list,article_data)

        if index==19:
            break

# %% [raw]
# Experiment: find recital in recital_collection best matching recital question . Use its corresponding kg to enhance query allowing for article collection data or not

# %%
kg_data = pd.read_excel("Output/gdpr_chapter4_recital_kg_output_corrected.xlsx")
# one more entry in the following txt as noticed as indvidual sentence at the end of recital 86 with no qa but seems an obligation
#data = pd.read_excel("Output/gdpr_chapter4_recital_kg_output_corrected.xlsx")

statements_all = kg_data["InputText"].tolist()
print(len(statements_all))


kg_list = [] 
for kg_row in kg_data.iterrows():
    kg_row = kg_row[1]
    kg_list.append(kg_row)
  

deep_dataset= []
    # Iterate over each row and generate the improved statement
for index,recital_data in enumerate(recital_json_data):


        recital_query= recital_data['question']
    
        recital_question= recital_data['question']
        recital_answer= recital_data['answer']
    
        print(index)
       
        # generate an embedding for the input and retrieve the most relevant recital entry
        response = ollama.embed(
          model="all-minilm",
          input=recital_query
        )

        # find the recital that matches the recital question . This may not be the recital that was the same one

        results = recital_collection.query(
          query_embeddings=[response["embeddings"][0]],
          n_results=2
        )

        closest_dist = results['distances'][0][0]

   
        #print("%3.3f" %(closest_dist))

        closest_id = results['ids'][0][0]
        #print("closest recital in vector store:%s" %closest_id)
        #data = results['documents'][0][0]
        
        recital_index = int(closest_id.split(":")[0])

        #print(recital_index)
        kg_row = kg_list[recital_index]


        retrieved_contexts,response = generate_answer_based_on_kg_enhance_prompt(kg_row,recital_data)


    
        retrieved_contexts = data

        test_case = LLMTestCase(input=recital_question, expected_output =recital_answer,actual_output=response, retrieval_context= retrieved_contexts)
    
        deep_dataset.append(test_case)
 
        

  
deepeval_dataset = EvaluationDataset(test_cases=deep_dataset)

# %%
knowledge graph document store based on knowedge graph embeddings

# %% [raw]
# Experiment find the knowledge graph within article knowledge graphs closest to given recital query and use that in query if close , otherwise do not use knowledge graph to answer query

# %%
import json
client = chromadb.Client()


#kg_data = pd.read_excel("Output/gdpr_chapter4_recital_kg_output_corrected.xlsx")
# one more entry in the following txt as noticed as indvidual sentence at the end of recital 86 with no qa but seems an obligation
#kg_data = pd.read_excel("Output/gdpr_chapter4_recital_kg_output_corrected.xlsx")

kg_data = pd.read_excel("Output/gdpr_articles_24_43_kg_output_corrected.xlsx")

statements_all = kg_data["InputText"].tolist()
print(len(statements_all))


kg_list = [] 
for kg_row in kg_data.iterrows():
    kg_row = kg_row[1]
    kg_list.append(kg_row)
    
if "kg_articles" in [c.name for c in client.list_collections()]:
      
    client.delete_collection(name="kg_articles")

kg_article_collection = client.create_collection(name="kg_articles")

# store each kg as a vector embedding database
for i, article in enumerate(article_json_data):
    
    input_text = kg_list[i]

    doc_dict = input_text.to_dict()
    #print(doc_dict)
    input_text=json.dumps(doc_dict)
    
    #print(input_text)
    response = ollama.embed(model="all-minilm", input=input_text)
    embeddings = response["embeddings"]
    kg_article_collection.add(
    ids=[str(i)+":article:" + article['Article']],
    embeddings=embeddings,
    documents=[input_text]   
  )

print(kg_article_collection.count())
# Out:
# 122
# 122

# %%
'''
recital_list= []    
recital_data = pd.read_excel("Output/gdpr_chapter4_recital_kg_output_corrected.xlsx")

for recital_row in recital_data.iterrows():
    recital_row = recital_row[1]
    recital_list.append(recital_row)
    
recital_row =kg_list[0]
recital_row= recital_list[4] 
#print(recital_row)
'''

distance_below_threshold =0
deep_dataset = []
for index in range(len(recital_json_data)):
    print(index)
       
    recital_query = recital_json_data[index]['question']
    
    recital_question = recital_json_data[index]['question']
    
    recital_answer = recital_json_data[index]['answer']
    
    query = {}
    #query['InputText'] = recital_row['question']
    query['InputText'] = recital_query
    query['Type'] =''  
    query['Action'] =''
    
    query['Condition'] =''                                                     
    query['Modality'] =''                        
    query['Actor'] =''                                                         
    query['Reason'] =''        
    query['Artifact'] =''      
    query['Violation'] =''                                                
    query['Exception'] =''                                                
    query['Presence'] =''                                                 
    query['Time'] =''                                                     
    query['Sanction'] =''                                                 
    query['Situation'] =''
    query_data = json.dumps(query)
    recital_query= query_data
    #recital_query = json.dumps(recital_row.to_dict())
    #print(recital_query)
    response = ollama.embed(
              model="all-minilm",
              input=recital_query
            )
    
    results = kg_article_collection.query(
              query_embeddings=[response["embeddings"][0]],
              n_results=1
            )
    distance = float(results['distances'][0][0])
    print("kg distance:%f" %distance)

    if distance < 1.0:
    
    #if distance < 0.5:
       
        article_kg = results['documents'][0][0]
        article_kg=json.loads(article_kg)
        print("article kg")
        print(article_kg)
        distance_below_threshold+=1   
        
        data,response= generate_answer_based_on_kg_enhance_prompt(article_kg,recital_json_data[index])
    else:
        data,response = generate_answer_based_on_context(recital_json_data[index])
        
    
    retrieved_contexts = data

    test_case = LLMTestCase(input=recital_question, expected_output =recital_answer,actual_output=response, retrieval_context= retrieved_contexts)
    
    deep_dataset.append(test_case)
 
        
        
print("number using knowledge graph %d" %(distance_below_threshold))

  
deepeval_dataset = EvaluationDataset(test_cases=deep_dataset)
# Out:
# 0
# kg distance:0.682028
# article kg
# {'InputText': 'The data protection officer shall be bound by secrecy or confidentiality concerning the performance of his or her tasks, in accordance with Union or Member State law. ', 'Type': 'Obligation', 'Action': 'be bound by secrecy or confidentiality concerning the performance of his or her tasks', 'Condition': ' ', 'Modality': 'shall', 'Actor': 'data protection officer', 'Reason': nan, 'Artifact': '[Union or Member State law]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.976
# article_text:
#  In order to ensure a consistent level of protection for natural persons throughout the Union and to prevent divergences hampering the free movement of personal data within the internal market, a Regulation is necessary to provide legal certainty and transparency for economic operators, including micro, small and medium-sized enterprises, and to provide natural persons in all Member States with the same level of legally enforceable rights and obligations and responsibilities for controllers and processors, to ensure consistent monitoring of the processing of personal data, and equivalent sanctions in all Member States as well as effective cooperation between the supervisory authorities of different Member States. The proper functioning of the internal market requires that the free movement of personal data within the Union is not restricted or prohibited for reasons connected with the protection of natural persons with regard to the processing of personal data. To take account of the specific situation of micro, small and medium-sized enterprises, this Regulation includes a derogation for organisations with fewer than 250 employees with regard to record-keeping. In addition, the Union institutions and bodies, and Member States and their supervisory authorities, are encouraged to take account of the specific needs of micro, small and medium-sized enterprises in the application of this Regulation. The notion of micro, small and medium-sized enterprises should draw from Article 2 of the Annex to Commission Recommendation 2003/361/EC (1).
# article question:
# What is the primary objective of introducing a Regulation to ensure consistent protection for natural persons throughout the Union?
# article answer:
# to provide legal certainty and transparency for economic operators, including micro, small and medium-sized enterprises and to provide natural persons in all Member states with the same legal of legally enforceable rights and obligations and responsibilities for controllers and processors, to ensure consistent monitoring of the processing of personal data, and equivalent sanctions in all Member States as well as effective cooperation between the supervisory authorities of different Member States.
# response from LLM:
# Based on the provided contextual data, the primary objective of introducing a Regulation to ensure consistent protection for natural persons throughout the Union is to implement appropriate technical and organisational measures to ensure that processing is performed in accordance with the Regulation. This is stated in the first sentence: "The controller shall implement appropriate technical and organisational measures to ensure and to be able to demonstrate that processing is performed in accordance with this Regulation."
# 1
# kg distance:0.693040
# article kg
# {'InputText': 'The record  of processing activities shall contain the categories of recipients to whom the personal data have been or will be disclosed including recipients in third countries or international organisations; ', 'Type': 'Obligation', 'Action': 'contain the categories of recipients to whom the personal data have been or will be disclosed including recipients in third countries or international organisations', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[the record]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.890
# article_text:
# The proper functioning of the internal market requires that the free movement of personal data within the Union is not restricted or prohibited for reasons connected with the protection of natural persons with regard to the processing of personal data.
# article question:
# What are the main objectives of ensuring the free movement of personal data in the EU?
# article answer:
# The proper functioning of the internal market requires that the free movement of personal data within the Union is not restricted or prohibited for reasons connected with the protection of natural persons with regard to the processing of personal data.
# response from LLM:
# Based on the given contextual data, the main objectives of ensuring the free movement of personal data in the EU are:
#
# 1. To process only necessary personal data for each specific purpose.
# 2. To limit access to personal data without individual's intervention.
# 3. To implement technical and organisational measures to ensure the security and integrity of personal data.
#
# These objectives aim to protect individuals' rights and freedoms by ensuring that their personal data is processed in a responsible and transparent manner.
# 2
# kg distance:0.529882
# article kg
# {'InputText': 'The records referred to in paragraphs 1 and 2 shall be in writing, including in electronic form.', 'Type': 'Obligation', 'Action': 'be in writing, including in electronic form', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[paragraphs 1 and 2]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:1.007
# article_text:
# To take account of the specific situation of micro, small and medium-sized enterprises, this Regulation includes a derogation for organisations with fewer than 250 employees with regard to record-keeping.
# article question:
# What is the exemption from record-keeping requirements for?
# article answer:
# organisations with fewer than 250 employees
# response from LLM:
# According to the given contextual data and reference knowledge graph, the exemption from record-keeping requirements is for an enterprise or organization employing fewer than 250 persons unless:
#
# * The processing carried out is likely to result in a risk to the rights and freedoms of data subjects.
# * The processing is not occasional.
# * The processing includes special categories of data as referred to in Article 9 (1) or personal data relating to criminal convictions and offences referred to in Article 10.
# 3
# kg distance:0.622084
# article kg
# {'InputText': 'This Article shall not apply to processing carried out by public authorities and bodies.', 'Type': 'Obligation', 'Action': 'processing carried out by public authorities and bodies', 'Condition': nan, 'Modality': 'shall', 'Actor': 'public authorities and bodies', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.793
# article_text:
#  The principle of transparency requires that any information addressed to the public or to the data subject be concise, easily accessible and easy to understand, and that clear and plain language and, additionally, where appropriate, visualisation be used. Such information could be provided in electronic form, for example, when addressed to the public, through a website. This is of particular relevance in situations where the proliferation of actors and the technological complexity of practice make it difficult for the data subject to know and understand whether, by whom and for what purpose personal data relating to him or her are being collected, such as in the case of online advertising. Given that children merit specific protection, any information and communication, where processing is addressed to a child, should be in such a clear and plain language that the child can easily understand.
# article question:
# What is the principle of transparency required for information addressed to the public or data subjects?
# article answer:
# The principle of transparency requires that any information be concise, easily accessible, and easy to understand, using clear and plain language and additionally visualisation where appropriate.
# response from LLM:
# According to the given contextual data, the principle of transparency required for information addressed to the public or data subjects is not explicitly stated. However, based on the provided text, we can infer that the condition (a) in paragraph 1 states that "the communication to the data subject referred to in paragraph 1 shall not be required if...". This implies that some level of transparency may be necessary for informing data subjects.
#
# In a broader context, taking into account the reference knowledge graph and the provided text, we can argue that the principle of transparency is implied as part of the obligation to "provide information to the public and to data subjects" (point (e) in paragraph 2). This suggests that controllers should provide clear and understandable information about their processing activities to both the general public and affected data subjects.
# 4
# kg distance:0.499621
# article kg
# {'InputText': 'Where appropriate, the controller shall seek the views of data subjects or their representatives on the intended processing, without prejudice to the protection of commercial or public interests or the security of processing operations. ', 'Type': 'Obligation', 'Action': 'seek the views of data subjects or their representatives on the intended processing', 'Condition': 'where appropriate', 'Modality': 'shall', 'Actor': 'controller', 'Reason': ' ', 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.745
# article_text:
#  The responsibility and liability of the controller for any processing of personal data carried out by the controller or on the controller's behalf should be established. In particular, the controller should be obliged to implement appropriate and effective measures and be able to demonstrate the compliance of processing activities with this Regulation, including the effectiveness of the measures. Those measures should take into account the nature, scope, context and purposes of the processing and the risk to the rights and freedoms of natural persons.
# article question:
# What kind of measures should a controller establish to demonstrate compliance with this Regulation?
# article answer:
# Appropriate and effective measures and be able to demonstrate the compliance of processing activities within this Regulation. Also those measures should take into account the nature, scope, context and purposes of the processing and the risk to the rights and freedoms of natural persons.
# response from LLM:
# According to the given contextual data, a controller should establish:
#
# * Appropriate data protection policies by implementing measures referred to in paragraph 1.
# * Technical and organisational measures that ensure and demonstrate processing is performed in accordance with this Regulation, taking into account the nature, scope, context, and purposes of processing.
#
# Additionally, adherence to approved codes of conduct or certification mechanisms can be used as an element to demonstrate compliance.
# 5
# kg distance:0.518332
# article kg
# {'InputText': 'The record  of processing activities shall contain a description of the categories of data subjects and of the categories of personal data; ', 'Type': 'Obligation', 'Action': 'contain a description of the categories of data subjects and of the categories of personal data', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[the record]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.735
# article_text:
#  The risk to the rights and freedoms of natural persons, of varying likelihood and severity, may result from personal data processing which could lead to physical, material or non-material damage, in particular: where the processing may give rise to discrimination, identity theft or fraud, financial loss, damage to the reputation, loss of confidentiality of personal data protected by professional secrecy, unauthorised reversal of pseudonymisation, or any other significant economic or social disadvantage; where data subjects might be deprived of their rights and freedoms or prevented from exercising control over their personal data; where personal data are processed which reveal racial or ethnic origin, political opinions, religion or philosophical beliefs, trade union membership, and the processing of genetic data, data concerning health or data concerning sex life or criminal convictions and offences or related security measures; where personal aspects are evaluated, in particular analysing or predicting aspects concerning performance at work, economic situation, health, personal preferences or interests, reliability or behaviour, location or movements, in order to create or use personal profiles; where personal data of vulnerable natural persons, in particular of children, are processed; or where processing involves a large amount of personal data and affects a large number of data subjects.
# article question:
# What types of harm can result from personal data processing?
# article answer:
# The risk to the rights and freedoms of natural persons may result in physical, material or non-material damage, including discrimination, identity theft or fraud, financial loss, damage to reputation, loss of confidentiality, unauthorised reversal of pseudonymisation, or any other significant economic or social disadvantage; where data subjects might be deprived of their rights and freedoms or prevented from exercising control over their personal data;  where personal data are processed which reveal racial or ethnic origin, political opinions, religion or philosophical beliefs, trade union membership, and the processing of genetic data, data concerning health or data concerning sex life or criminal convictions and offences or related security measures; where personal aspects are evaluated, in particular analysing or predicting aspects concerning performance at work, economic situation, health, personal preferences or interests, reliability or behaviour, location or movements, in order to create or use personal profiles; where personal data of vulnerable natural persons, in particular of children, are processed; or where processing involves a large amount of personal data and affects a large number of data subjects.
# response from LLM:
# According to the provided contextual data, the types of harm that can result from personal data processing are:
#
# * A high risk to the rights and freedoms of natural persons.
#
# This is based on Article 35(1) which states that if a type of processing is likely to result in a high risk to the rights and freedoms of natural persons, the controller shall carry out an assessment of the impact of the envisaged processing operations on the protection of personal data.
#
# Note that the reference knowledge graph provided does not directly relate to this question.
# 6
# kg distance:0.647901
# article kg
# {'InputText': 'In assessing the appropriate level of security account shall be taken in particular of the risks that are presented by processing, in particular from accidental or unlawful destruction, loss, alteration, unauthorised disclosure of, or access to personal data transmitted, stored or otherwise processed.', 'Type': 'Obligation', 'Action': 'assessing the appropriate level of security account shall be taken in particular of the risks that are presented by processing, in particular from accidental or unlawful destruction, loss, alteration, unauthorised disclosure of, or access to personal data transmitted, stored or otherwise processed.', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': ' ', 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.822
# article_text:
#  The likelihood and severity of the risk to the rights and freedoms of the data subject should be determined by reference to the nature, scope, context and purposes of the processing. Risk should be evaluated on the basis of an objective assessment, by which it is established whether data processing operations involve a risk or a high risk.
# article question:
# How does one determine the likelihood and severity of the risk to the rights and freedoms of the data subject?
# article answer:
# The likelihood and severity of the risk to the rights and freedoms of the data subject should be determined by reference to the nature, scope, context and purposes of the processing.
# response from LLM:
# Based on the contextual data and reference knowledge graph, one determines the likelihood and severity of the risk to the rights and freedoms of the data subject by taking into account:
#
# * The state of the art
# * The cost of implementation
# * The nature, scope, context, and purposes of processing
# * The risks posed by the processing
#
# This assessment considers potential risks from accidental or unlawful destruction, loss, alteration, unauthorized disclosure, or access to personal data.
# 7
# kg distance:0.460305
# article kg
# {'InputText': 'The controller shall consult the supervisory authority prior to processing where a data protection impact assessment under Article 35 indicates that the processing would result in a high risk in the absence of measures taken by the controller to mitigate the risk.', 'Type': 'Obligation', 'Action': ' consult the supervisory authority prior to processing where a data protection impact assessment under Article 35 indicates that the processing would result in a high risk in the absence of measures taken by the controller to mitigate the risk.', 'Condition': ' ', 'Modality': 'shall', 'Actor': 'controller', 'Reason': nan, 'Artifact': '[Article 35]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.521
# article_text:
#  Guidance on the implementation of appropriate measures and on the demonstration of compliance by the controller or the processor, especially as regards the identification of the risk related to the processing, their assessment in terms of origin, nature, likelihood and severity, and the identification of best practices to mitigate the risk, could be provided in particular by means of approved codes of conduct, approved certifications, guidelines provided by the Board or indications provided by a data protection officer. The Board may also issue guidelines on processing operations that are considered to be unlikely to result in a high risk to the rights and freedoms of natural persons and indicate what measures may be sufficient in such cases to address such risk.
# article question:
# What types of guidance could be provided by the Board or data protection officer to help controllers and processors identify and mitigate risks related to processing?
# article answer:
# Approved codes of conduct, approved certifications, guidelines provided by the Board, or indications provided by the the data protection officer
# response from LLM:
# Based on the provided contextual data and reference knowledge graph, the types of guidance that could be provided by the Board or data protection officer to help controllers and processors identify and mitigate risks related to processing are:
#
# * Conduct a data protection impact assessment under Article 35 to identify high-risk processing operations.
# * Consult the supervisory authority prior to processing when a data protection impact assessment indicates a high risk in the absence of measures taken by the controller to mitigate the risk.
#
# Additionally, the data protection officer may provide guidance on how to take into account the nature, scope, context, and purposes of processing operations when assessing risks, as mentioned in the third contextual statement.
# 8
# kg distance:0.490047
# article kg
# {'InputText': 'Where appropriate, the controller shall seek the views of data subjects or their representatives on the intended processing, without prejudice to the protection of commercial or public interests or the security of processing operations. ', 'Type': 'Obligation', 'Action': 'seek the views of data subjects or their representatives on the intended processing', 'Condition': 'where appropriate', 'Modality': 'shall', 'Actor': 'controller', 'Reason': ' ', 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.752
# article_text:
#  The protection of the rights and freedoms of natural persons with regard to the processing of personal data require that appropriate technical and organisational measures be taken to ensure that the requirements of this Regulation are met. In order to be able to demonstrate compliance with this Regulation, the controller should adopt internal policies and implement measures which meet in particular the principles of data protection by design and data protection by default. Such measures could consist, inter alia, of minimising the processing of personal data, pseudonymising personal data as soon as possible, transparency with regard to the functions and processing of personal data, enabling the data subject to monitor the data processing, enabling the controller to create and improve security features. When developing, designing, selecting and using applications, services and products that are based on the processing of personal data or process personal data to fulfil their task, producers of the products, services and applications should be encouraged to take into account the right to data protection when developing and designing such products, services and applications and, with due regard to the state of the art, to make sure that controllers and processors are able to fulfil their data protection obligations. The principles of data protection by design and by default should also be taken into consideration in the context of public tenders.
# article question:
# What measures can a controller take to ensure compliance with the  Regulation?
# article answer:
# The controller should adopt internal policies and implement measures which meet in particular the principles of data protection by design and data protection by default, such as minimising the processing of personal data, pseudonymising personal data as soon as possible, transparency with regard to the functions and processing of personal data, enabling the data subject to monitor the data processing, enabling the controller to create and improve security features.
# response from LLM:
# Based on the contextual data and reference knowledge graph, a controller can take the following measures to ensure compliance with the Regulation:
#
# 1. Implementing appropriate data protection policies.
# 2. Adhering to approved codes of conduct or certification mechanisms.
# 3. Implementing technical and organisational measures that are reviewed and updated as necessary.
#
# Additionally, the Regulation suggests that controllers should demonstrate their compliance by being able to show that processing is performed in accordance with the Regulation.
# 9
# kg distance:0.660962
# article kg
# {'InputText': 'Where a type of processing in particular using new technologies, and taking into account the nature, scope, context and purposes of the processing, is likely to result in a high risk to the rights and freedoms of natural persons, the controller shall, prior to the processing, carry out an assessment of the impact of the envisaged processing operations on the protection of personal data.', 'Type': 'Obligation', 'Action': 'carry out an assessment of the impact of the envisaged processing operations on the protection of personal data', 'Condition': 'Where a type of processing in particular using new technologies, and taking into account the nature, scope, context and purposes of the processing, is likely to result in a high risk to the rights and freedoms of natural persons', 'Modality': 'shall', 'Actor': 'controller', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.776
# article_text:
# When developing, designing, selecting and using applications, services and products that are based on the processing of personal data or process personal data to fulfil their task, producers of the products, services and applications should be encouraged to take into account the right to data protection when developing and designing such products, services and applications and, with due regard to the state of the art, to make sure that controllers and processors are able to fulfil their data protection obligations. The principles of data protection by design and by default should also be taken into consideration in the context of public tenders.
# article question:
# When developing, designing, selecting and using applications, services and products that are based on the processing of personal data or process personal data to fulfil their task, what should the producers of the products, services and applications be encouraged to do?
# article answer:
#  take into account the right to data protection when developing and designing such products, services and applications and, with due regard to the state of the art, to make sure that controllers and processors are able to fulfil their data protection obligations.
# response from LLM:
# Based on the provided contextual data and reference knowledge graph, when developing, designing, selecting, and using applications, services, and products that process personal data or process personal data to fulfill their task, producers of these products should be encouraged to carry out an assessment of the impact of the envisaged processing operations on the protection of personal data. This obligation applies where a type of processing in particular using new technologies is likely to result in a high risk to the rights and freedoms of natural persons.
# 10
# kg distance:0.587491
# article kg
# {'InputText': 'Where the opinion referred to in paragraph 7 confirms that the draft code, amendment or extension complies with this Regulation, or, in the situation referred to in paragraph 3, provides appropriate safeguards, the Board shall submit its opinion to the Commission.', 'Type': 'Obligation', 'Action': 'submit its opinion to the Commission', 'Condition': 'Where the opinion referred to in paragraph 7 confirms that the draft code, amendment or extension complies with this Regulation, or, in the situation referred to in paragraph 3, provides appropriate safeguards', 'Modality': 'shall', 'Actor': 'The Board', 'Reason': ' ', 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.937
# article_text:
#  The protection of the rights and freedoms of data subjects as well as the responsibility and liability of controllers and processors, also in relation to the monitoring by and measures of supervisory authorities, requires a clear allocation of the responsibilities under this Regulation, including where a controller determines the purposes and means of the processing jointly with other controllers or where a processing operation is carried out on behalf of a controller.
# article question:
# What are the main reasons for allocating responsibilities under the Regulation?
# article answer:
# The protection of the rights and freedoms of data subjects as well as the responsibility and liability of controllers and processors, also in relation to the monitoring by and measures of supervisory authorities
# response from LLM:
# Based on the provided contextual data and reference knowledge graph, the main reasons for allocating responsibilities under the Regulation are:
#
# 1. Encouraging codes of conduct to contribute to the proper application of the Regulation.
# 2. Providing a framework for processing in specific sectors and catering to the needs of micro, small, and medium-sized enterprises.
# 3. Facilitating consultation and prior authorisation with the supervisory authority for certain types of processing.
#
# These reasons are reflected in the obligations outlined in the reference knowledge graph, such as the Board's duty to submit its opinion to the Commission where necessary.
# 11
# kg distance:0.563195
# article kg
# {'InputText': 'The processor shall not engage another processor without prior specific or general written authorisation of the controller.', 'Type': 'Obligation', 'Action': 'engage another processor', 'Condition': nan, 'Modality': 'shall', 'Actor': 'processor', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.510
# article_text:
#  Where a controller or a processor not established in the Union is processing personal data of data subjects who are in the Union whose processing activities are related to the offering of goods or services, irrespective of whether a payment of the data subject is required, to such data subjects in the Union, or to the monitoring of their behaviour as far as their behaviour takes place within the Union, the controller or the processor should designate a representative, unless the processing is occasional, does not include processing, on a large scale, of special categories of personal data or the processing of personal data relating to criminal convictions and offences, and is unlikely to result in a risk to the rights and freedoms of natural persons, taking into account the nature, context, scope and purposes of the processing or if the controller is a public authority or body. The representative should act on behalf of the controller or the processor and may be addressed by any supervisory authority. The representative should be explicitly designated by a written mandate of the controller or of the processor to act on its behalf with regard to its obligations under this Regulation. The designation of such a representative does not affect the responsibility or liability of the controller or of the processor under this Regulation. Such a representative should perform its tasks according to the mandate received from the controller or processor, including cooperating with the competent supervisory authorities with regard to any action taken to ensure compliance with this Regulation. The designated representative should be subject to enforcement proceedings in the event of non-compliance by the controller or processor.
# article question:
# When is it  necessary for a controller or processor to designate a representative?
# article answer:
# in the case a controller or a processor not established in the Union is processing personal data of data subjects who are in the Union whose processing activities are related to the offering of goods or services, irrespective of whether a payment of the data subject is required, to such data subjects in the Union, or to the monitoring of their behaviour as far as their behaviour takes place within the Union
# response from LLM:
# Based on the provided contextual data and reference knowledge graph, it is necessary for a controller or processor to designate a representative when:
#
# * The representative shall be established in one of the Member States where the data subjects are located (Article 27(1)).
# * The controller or processor is not established in the Union (Article 27(1), paragraph 2).
#
# In other words, a controller or processor must designate a representative if they are not based in the European Union, or if the data subjects whose personal data they process are located in the EU.
# 12
# kg distance:0.561249
# article kg
# {'InputText': 'The processor shall not engage another processor without prior specific or general written authorisation of the controller.', 'Type': 'Obligation', 'Action': 'engage another processor', 'Condition': nan, 'Modality': 'shall', 'Actor': 'processor', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.546
# article_text:
#  Where a controller or a processor not established in the Union is processing personal data of data subjects who are in the Union whose processing activities are related to the offering of goods or services, irrespective of whether a payment of the data subject is required, to such data subjects in the Union, or to the monitoring of their behaviour as far as their behaviour takes place within the Union, the controller or the processor should designate a representative, unless the processing is occasional, does not include processing, on a large scale, of special categories of personal data or the processing of personal data relating to criminal convictions and offences, and is unlikely to result in a risk to the rights and freedoms of natural persons, taking into account the nature, context, scope and purposes of the processing or if the controller is a public authority or body.
# article question:
# When is it not necessary for a controller or processor to designate a representative?
# article answer:
# The processing is occasional, does not include processing on a large scale, of special categories of personal data or the processing of personal data relating to criminal convictions and offences, and is unlikely to result in a risk to the rights and freedoms of natural persons, taking into account the nature, context, scope and purposes of the processing or if the controller is a public authority or body.
# response from LLM:
# Based on the provided contextual data, it is not necessary for a controller or processor to designate a representative in the following situations:
#
# 1. Occasional processing that does not include, on a large scale, processing of special categories of data or processing of personal data relating to criminal convictions and offences, and is unlikely to result in a risk to the rights and freedoms of natural persons.
# 2. A public authority or body.
#
# These exceptions are mentioned in Article 27(1) of the Regulation.
# 13
# kg distance:0.532520
# article kg
# {'InputText': 'The record  of processing activities shall contain the purposes of the processing; ', 'Type': 'Obligation', 'Action': 'contain the purposes of the processing', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[the record]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.678
# article_text:
#  The representative should act on behalf of the controller or the processor and may be addressed by any supervisory authority. The representative should be explicitly designated by a written mandate of the controller or of the processor to act on its behalf with regard to its obligations under this Regulation. The designation of such a representative does not affect the responsibility or liability of the controller or of the processor under this Regulation. Such a representative should perform its tasks according to the mandate received from the controller or processor, including cooperating with the competent supervisory authorities with regard to any action taken to ensure compliance with this Regulation. The designated representative should be subject to enforcement proceedings in the event of non-compliance by the controller or processor.
# article question:
# What is the obligations of the representative?
# article answer:
# the representative should act on behalf of the controller or the processor and may be addressed by any supervisory authority. The representative should be explicitly designated by a written mandate of the controller or of the processor to act on its behalf with regard to its obligations under this Regulation. The designation of such a representative does not affect the responsibility or liability of the controller or of the processor under this Regulation. Such a representative should perform its tasks according to the mandate received from the controller or processor, including cooperating with the competent supervisory authorities with regard to any action taken to ensure compliance with this Regulation. The designated representative should be subject to enforcement proceedings in the event of non-compliance by the controller or processor.
# response from LLM:
# According to the provided contextual data, the representative's obligations are:
#
# * To be established in one of the Member States where the data subjects are located.
# * To be mandated by the controller or processor to be addressed on all issues related to processing, for ensuring compliance with this Regulation.
#
# Additionally, the representative shall contain the purposes of the processing (as per the reference knowledge graph).
# 14
# kg distance:0.480503
# article kg
# {'InputText': 'Where processing is to be carried out on behalf of a controller, the controller shall use only processors providing sufficient guarantees to implement appropriate technical and organisational measures in such a manner that processing will meet the requirements of this Regulation and ensure the protection of the rights of the data subject.', 'Type': 'Obligation', 'Action': 'use only processors providing sufficient guarantees to implement appropriate technical and organisational measures in such a manner that processing will meet the requirements of this Regulation and ensure the protection of the rights of the data subject.', 'Condition': 'Where processing is to be carried out on behalf of a controller', 'Modality': 'shall', 'Actor': 'controller', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.680
# article_text:
#  To ensure compliance with the requirements of this Regulation in respect of the processing to be carried out by the processor on behalf of the controller, when entrusting a processor with processing activities, the controller should use only processors providing sufficient guarantees, in particular in terms of expert knowledge, reliability and resources, to implement technical and organisational measures which will meet the requirements of this Regulation, including for the security of processing. The adherence of the processor to an approved code of conduct or an approved certification mechanism may be used as an element to demonstrate compliance with the obligations of the controller. The carrying-out of processing by a processor should be governed by a contract or other legal act under Union or Member State law, binding the processor to the controller, setting out the subject- matter and duration of the processing, the nature and purposes of the processing, the type of personal data and categories of data subjects, taking into account the specific tasks and responsibilities of the processor in the context of the processing to be carried out and the risk to the rights and freedoms of the data subject. The controller and processor may choose to use an individual contract or standard contractual clauses which are adopted either directly by the Commission or by a supervisory authority in accordance with the consistency mechanism and then adopted by the Commission. After the completion of the processing on behalf of the controller, the processor should, at the choice of the controller, return or delete the personal data, unless there is a requirement to store the personal data under Union or Member State law to which the processor is subject.
# article question:
# What are some key factors a controller should consider when selecting a processor to ensure compliance with the Regulation?
# article answer:
# The controller should use only processors providing sufficient guarantees, in particular in terms of expert knowledge, reliability and resources, to implement technical and organisational measures which will meet the requirements of this Regulation
# response from LLM:
# Based on the given contextual data and reference knowledge graph, some key factors a controller should consider when selecting a processor to ensure compliance with the Regulation are:
#
# 1. **Sufficient guarantees**: The processor must provide sufficient guarantees to implement appropriate technical and organisational measures.
# 2. **Meeting requirements of this Regulation**: The processor's measures must ensure that processing meets the requirements of the General Data Protection Regulation (GDPR).
# 3. **Protection of data subject rights**: The processor must ensure the protection of the rights of the data subjects, as required by the GDPR.
#
# These factors are crucial for a controller to consider when selecting a processor to ensure compliance with the GDPR and protect personal data.
# 15
# kg distance:0.528257
# article kg
# {'InputText': " Each processor and, where applicable, the processor's representative shall maintain a record of all categories of processing activities carried out on behalf of a controller, containing: the categories of processing carried out on behalf of each controller; ", 'Type': 'Obligation', 'Action': 'maintain a record of all categories of processing activities carried out on behalf of a controller', 'Condition': 'where applicable', 'Modality': 'shall', 'Actor': 'processor and processor’s representative', 'Reason': ' ', 'Artifact': ' ', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.402
# article_text:
# The carrying-out of processing by a processor should be governed by a contract or other legal act under Union or Member State law, binding the processor to the controller, setting out the subject- matter and duration of the processing, the nature and purposes of the processing, the type of personal data and categories of data subjects, taking into account the specific tasks and responsibilities of the processor in the context of the processing to be carried out and the risk to the rights and freedoms of the data subject.
# article question:
# What should a contract or other legal act governing processing by a processor contain?
# article answer:
# The contract or legal act should set out the subject-matter and duration of the processing, the nature and purposes of the processing, the type of personal data and categories of data subjects, taking into account the specific tasks and responsibilities of the processor in the context of the processing to be carried out and the risk to the rights and freedoms of the data subject.
# response from LLM:
# According to the given contextual data, a contract or other legal act governing processing by a processor should contain:
#
# * The subject-matter and duration of the processing
# * The nature and purpose of the processing
# * The type of personal data and categories of data subjects
# * The obligations and rights of the controller
#
# These requirements are mentioned in paragraph 3.
# 16
# kg distance:0.569275
# article kg
# {'InputText': 'Where processing is to be carried out on behalf of a controller, the controller shall use only processors providing sufficient guarantees to implement appropriate technical and organisational measures in such a manner that processing will meet the requirements of this Regulation and ensure the protection of the rights of the data subject.', 'Type': 'Obligation', 'Action': 'use only processors providing sufficient guarantees to implement appropriate technical and organisational measures in such a manner that processing will meet the requirements of this Regulation and ensure the protection of the rights of the data subject.', 'Condition': 'Where processing is to be carried out on behalf of a controller', 'Modality': 'shall', 'Actor': 'controller', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.863
# article_text:
# The controller and processor may choose to use an individual contract or standard contractual clauses which are adopted either directly by the Commission or by a supervisory authority in accordance with the consistency mechanism and then adopted by the Commission.
# article question:
# What are the options for controllers and processors when it comes to implementing data transfer agreements?
# article answer:
# The controller and processor may choose to use an individual contract or standard contractual clauses which are adopted either directly by the Commission or by a supervisory authority in accordance with the consistency mechanism and then adopted by the Commission.
# response from LLM:
# Based on the provided contextual data and reference knowledge graph, controllers have two options for implementing data transfer agreements:
#
# 1. **Use only processors providing sufficient guarantees**: When processing is carried out on their behalf, controllers must use only processors that can provide sufficient guarantees to implement appropriate technical and organisational measures.
# 2. **Establish data protection certification mechanisms, seals or marks approved pursuant to paragraph 5 of this Article**: Controllers not subject to the Regulation may establish data protection certification mechanisms, seals, or marks to demonstrate the existence of appropriate safeguards for personal data transfers to third countries or international organisations.
#
# Additionally, codes of conduct approved under paragraph 5 of this Article can also be used by controllers and processors not subject to the Regulation to provide appropriate safeguards for such data transfers.
# 17
# kg distance:0.591004
# article kg
# {'InputText': 'The record  of processing activities shall contain a description of the categories of data subjects and of the categories of personal data; ', 'Type': 'Obligation', 'Action': 'contain a description of the categories of data subjects and of the categories of personal data', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[the record]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.803
# article_text:
# After the completion of the processing on behalf of the controller, the processor should, at the choice of the controller, return or delete the personal data, unless there is a requirement to store the personal data under Union or Member State law to which the processor is subject.
# article question:
# What happens to personal data after processing is completed?
# article answer:
# The processor should, at the choice of the controller, return or delete the personal data, unless there is a requirement to store the personal data under Union or Member State law to which the processor is subject.
# response from LLM:
# According to the given contextual data, after processing is completed, "the processor at the choice of the controller, deletes or returns all the personal data to the controller after the end of the provision of services relating to processing, and deletes existing copies unless Union or Member State law requires storage of the personal data."
# 18
# kg distance:0.460889
# article kg
# ...
# closest distance in vector store:0.770
# article_text:
#  The supervisory authority should respond to the request for consultation within a specified period. However, the absence of a reaction of the supervisory authority within that period should be without prejudice to any intervention of the supervisory authority in accordance with its tasks and powers laid down in this Regulation, including the power to prohibit processing operations. As part of that consultation process, the outcome of a data protection impact assessment carried out with regard to the processing at issue may be submitted to the supervisory authority, in particular the measures envisaged to mitigate the risk to the rights and freedoms of natural persons.
# article question:
# How should the supervisory authority respond to the request for a consultation?
# article answer:
# The supervisory authority should respond to the request for consultation within a certain period. However the absence of a response should be without prejudice to any intervention of the supervisory authority
# response from LLM:
# According to the given contextual data, when the supervisory authority is of the opinion that the intended processing would infringe this Regulation, it shall:
#
# * Provide written advice to the controller and, where applicable, the processor within a period of up to eight weeks of receipt of the request for consultation.
# * May use any of its powers referred to in Article 58.
#
# Additionally, if the request for consultation is complex, the supervisory authority may extend this period by six weeks, informing the controller and, where applicable, the processor of the extension within one month of receipt of the request, together with the reasons for the delay.
# 39
# kg distance:0.442821
# article kg
# {'InputText': 'Compliance with approved codes of conduct referred to in Article 40 by the relevant controllers or processors shall be taken into due account in assessing the impact of the processing operations performed by such controllers or processors, in particular for the purposes of a data protection impact assessment. ', 'Type': 'Obligation', 'Action': 'taken into due account in assessing the impact of the processing operations performed by such controllers or processors, in particular for the purposes of a data protection impact assessment', 'Condition': ' ', 'Modality': 'shall', 'Actor': 'controllers or processors', 'Reason': 'for the purposes of a data protection impact assessment. ', 'Artifact': '[article 40]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.527
# article_text:
#  The processor should assist the controller, where necessary and upon request, in ensuring compliance with the obligations deriving from the carrying out of data protection impact assessments and from prior consultation of the supervisory authority.
# article question:
# What is the processor's role in assisting the controller with data protection impact assessments?
# article answer:
# The processor should assist the controller, where necessary and upon request, in ensuring compliance with the obligations deriving from the carrying out of data protection impact assessments
# response from LLM:
# Based on the provided contextual data and reference knowledge graph, the processor's role in assisting the controller with data protection impact assessments is to take into due account the data processing operations performed by the controller when assessing the impact of those operations. This obligation is specified in Article 40 of the reference knowledge graph.
# 40
# kg distance:0.416386
# article kg
# {'InputText': 'Member States shall consult the supervisory authority during the preparation of a proposal for a legislative measure to be adopted by a national parliament, or of a regulatory measure based on such a legislative measure, which relates to processing.', 'Type': 'Obligation', 'Action': 'consult the supervisory authority during the preparation of a proposal for a legislative measure to be adopted by a national parliament, or of a regulatory measure based on such a legislative measure', 'Condition': ' ', 'Modality': 'shall', 'Actor': 'Member States', 'Reason': ' ', 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.553
# article_text:
#  A consultation of the supervisory authority should also take place in the course of the preparation of a legislative or regulatory measure which provides for the processing of personal data, in order to ensure compliance of the intended processing with this Regulation and in particular to mitigate the risk involved for the data subject.
# article question:
# What is the purpose of consulting the supervisory authority when preparing a legislative or regulatory measure that involves personal data processing?
# article answer:
# To ensure compliance with this Regulation and mitigate the risk involved for the data subject
# response from LLM:
# The purpose of consulting the supervisory authority when preparing a legislative or regulatory measure that involves personal data processing is to provide the authority with relevant information about the intended processing, such as the purposes and means of processing, measures to protect data subjects' rights and freedoms, and contact details of the data protection officer. This consultation aims to ensure that the proposed measure complies with relevant data protection regulations and safeguards the rights of individuals whose personal data will be processed.
# 41
# kg distance:0.490879
# article kg
# {'InputText': 'A group of undertakings may appoint a single data protection officier provided that a data protection officer is easily accessible from each establishment.', 'Type': 'Obligation', 'Action': 'appoint a single data protection officer', 'Condition': 'provided that a data protection officer is easily accessible from each establishment.', 'Modality': 'may', 'Actor': 'A group of undertakings', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.815
# article_text:
#  Where the processing is carried out by a public authority, except for courts or independent judicial authorities when acting in their judicial capacity, where, in the private sector, processing is carried out by a controller whose core activities consist of processing operations that require regular and systematic monitoring of the data subjects on a large scale, or where the core activities of the controller or the processor consist of processing on a large scale of special categories of personal data and data relating to criminal convictions and offences, a person with expert knowledge of data protection law and practices should assist the controller or processor to monitor internal compliance with this Regulation. In the private sector, the core activities of a controller relate to its primary activities and do not relate to the processing of personal data as ancillary activities. The necessary level of expert knowledge should be determined in particular according to the data processing operations carried out and the protection required for the personal data processed by the controller or the processor. Such data protection officers, whether or not they are an employee of the controller, should be in a position to perform their duties and tasks in an independent manner.
# article question:
# what type of entities require assistance from a person with expert knowledge of data protection law and practices?
# article answer:
# a public authority, except for courts or independent judicial authorities when acting in their judicial capacity; the private sector, where processing is carried out by a controller whose core activities consist of processing operations that require regular and systematic monitoring of the data subjects on a large scale, or where the core activities of the controller or the processor consist of processing on a large scale of special categories of personal data and data relating to criminal convictions and offences
# response from LLM:
# According to the contextual data, a group of undertakings requires assistance from a person with expert knowledge of data protection law and practices.
# 42
# kg distance:0.702026
# article kg
# {'InputText': 'The record  of processing activities shall contain a description of the categories of data subjects and of the categories of personal data; ', 'Type': 'Obligation', 'Action': 'contain a description of the categories of data subjects and of the categories of personal data', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[the record]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:1.317
# article_text:
# The necessary level of expert knowledge should be determined in particular according to the data processing operations carried out and the protection required for the personal data processed by the controller or the processor.
# article question:
# What factors determine the necessary level of expert knowledge?
# article answer:
# The necessary level of expert knowledge should be determined in particular according to the data processing operations carried out and the protection required for the personal data processed by the controller or the processor.
# response from LLM:
# According to the provided contextual data, the necessary level of expert knowledge for a Data Protection Officer (DPO) is determined by their professional qualities and "expert knowledge of data protection law and practices". This suggests that the DPO must possess specialized knowledge in the field of data protection law and practices to effectively fulfill their tasks.
# 43
# kg distance:0.463291
# article kg
# {'InputText': 'In cases other than those referred to in paragraph 1, the controller or processor or associations and other bodies representing categories of controllers or processors may or, where required by Union or Member State law shall, designate a data protection officer.  The data protection officer may act for such associations and other bodies representing controllers or processors.', 'Type': 'Obligation', 'Action': 'designate a data protection officer; act for such associations and other bodies representing controllers or processors.', 'Condition': 'in cases other than those referred to in paragraph 1', 'Modality': 'may', 'Actor': 'controller or processor or associations and other bodies representing categories of controllers or processors; Data Protection officer', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.613
# article_text:
#  Associations or other bodies representing categories of controllers or processors should be encouraged to draw up codes of conduct, within the limits of this Regulation, so as to facilitate the effective application of this Regulation, taking account of the specific characteristics of the processing carried out in certain sectors and the specific needs of micro, small and medium enterprises. In particular, such codes of conduct could calibrate the obligations of controllers and processors, taking into account the risk likely to result from the processing for the rights and freedoms of natural persons.
# article question:
# What are associations or other bodies representing categories of controllers or processors encouraged to do under this Regulation?
# article answer:
# draw up codes of conduct, within the limits of this Regulation
# response from LLM:
# According to the provided contextual data, associations and other bodies representing categories of controllers or processors are encouraged to:
#
# * Maintain a record of all categories of processing activities carried out on behalf of each controller.
# * The record should contain:
# 	+ Categories of processing carried out on behalf of each controller.
# 	+ Name and contact details of the processor or processors and of each controller on behalf of which the processor is acting, as well as the data protection officer (where applicable).
# 	+ A general description of the technical and organisational security measures referred to in Article 32(1) (where possible).
#
# These obligations are mentioned in the contextual data provided.
# 44
# kg distance:0.689364
# article kg
# {'InputText': 'The record  of processing activities shall contain a description of the categories of data subjects and of the categories of personal data; ', 'Type': 'Obligation', 'Action': 'contain a description of the categories of data subjects and of the categories of personal data', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[the record]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.873
# article_text:
#  When drawing up a code of conduct, or when amending or extending such a code, associations and other bodies representing categories of controllers or processors should consult relevant stakeholders, including data subjects where feasible, and have regard to submissions received and views expressed in response to such consultations.
# article question:
# What steps should associations and other bodies take when drawing up a code of conduct, or amending or extending one?
# article answer:
# Associations and other bodies should consult relevant stakeholders, including data subjects where feasible, and have regard to submissions received and views expressed in response to such consultations.
# response from LLM:
# Based on the contextual data, when drawing up a code of conduct, or amending or extending one, associations and other bodies should:
#
# * Submit the draft code, amendment or extension to the supervisory authority which is competent pursuant to Article 55.
# * Provide an opinion from the supervisory authority on whether the draft code, amendment or extension complies with this Regulation.
#
# This information can be found in the first paragraph of the contextual data.
# 45
# kg distance:0.485666
# article kg
# {'InputText': 'The Board shall collate all certification mechanisms and data protection seals and marks in a register and shall make them publicly available by any appropriate means.', 'Type': 'Obligation', 'Action': 'collate all certification mechanisms and data protection seals and marks in a register and make them publicly available by any appropriate means', 'Condition': nan, 'Modality': 'shall', 'Actor': 'The Board', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.481
# article_text:
# In order to enhance transparency and compliance with this Regulation, the establishment of certification mechanisms and data protection seals and marks should be encouraged, allowing data subjects to quickly assess the level of data protection of relevant products and services.
# article question:
# What is the goal of encouraging certification mechanisms and data protection seals and marks in the context of this Regulation?
# article answer:
# To enhance transparency and compliance with this Regulation
# response from LLM:
# The goal of encouraging certification mechanisms and data protection seals and marks is to demonstrate compliance with this Regulation for processing operations by controllers and processors.
# number using knowledge graph 46

# %% [raw]
# Experiment similar to the previous experiment but we allow for 3 query templates (InputText, Action, Reason) rather than just use InputText

# %%
def get_closest_match_kg(recital_question):
    
    fields = ['InputText', 'Action','Reason', 'all']
    article_kgs = []
    distances = []
    article_kg_set = set()
    print(recital_question)
    for field in fields:
        print(field)
        query = {}
        #query['InputText'] = recital_row['question']
        query['InputText'] = ''
        query['Type'] =''  
        query['Action'] =''
        
        query['Condition'] =''                                                     
        query['Modality'] =''                        
        query['Actor'] =''                                                         
        query['Reason'] =''        
        query['Artifact'] =''      
        query['Violation'] =''                                                
        query['Exception'] =''                                                
        query['Presence'] =''                                                 
        query['Time'] =''                                                     
        query['Sanction'] =''                                                 
        query['Situation'] =''

        if field == all:
            query[field[0]] = recital_question
            query[field[1]] = recital_question
            query[field[2]] = recital_question

        else:
            query[field] = recital_question
        
        query_data = json.dumps(query)
        recital_query= query_data
        #recital_query = json.dumps(recital_row.to_dict())
        #print(recital_query)
        response = ollama.embed(
                  model="all-minilm",
                  input=recital_query
                )
        
        results = kg_article_collection.query(
                  query_embeddings=[response["embeddings"][0]],
                  n_results=1
                )
        distance = float(results['distances'][0][0])
        print("kg distance:%f" %distance)
        distances.append(distance)
        article_kg = results['documents'][0][0]
        # need to add this as a string
        article_kg_set.add(article_kg)
       
        article_kg=json.loads(article_kg)
        article_kgs.append(article_kg)
        #print("article kg")
        #print(article_kg)
    low_dist = np.min(distances)
    lowest  = np.argmin(distances)
    print("lOWEST DISTANCE field:%s" %(fields[lowest]))
    print(" number unique kgs:%d" %len(article_kg_set))
    '''
    for index,article in enumerate(article_kg_set):
        article=json.loads(article)
            
        print(article)
        if index == 0:
            composite=article
        else:
            composite['InputText'] = composite['InputText'] +" " +article['InputText']
            composite['Action'] = composite['Action'] +" " +article['Action']
          
    print("composite")
    print(composite)
    '''
           
    return low_dist,article_kgs[lowest]

# %%
for index in range(len(recital_json_data)):
    print(index)
    recital_query = recital_json_data[index]['question']
    distance,article_kg= get_closest_match_kg(recital_query)

# %%
deep_dataset = []

distance_below_threshold = 0
for index in range(len(recital_json_data)):
    print(index)
    recital_query = recital_json_data[index]['question']
    distance,article_kg= get_closest_match_kg(recital_query)

    
    recital_query = recital_json_data[index]['question']
    
    recital_question = recital_json_data[index]['question']
    
    recital_answer = recital_json_data[index]['answer']
    print("kg distance:%f" %distance)

    # use 0.5 as threshold for evaluation
    if distance < 1.0:
       
        print("article kg")
        print(article_kg)
        distance_below_threshold += 1
       
        data,response= generate_answer_based_on_kg_enhance_prompt(article_kg,recital_json_data[index])
    else:
        data,response = generate_answer_based_on_context(recital_json_data[index])
        
    
    retrieved_contexts = data

    test_case = LLMTestCase(input=recital_question, expected_output =recital_answer,actual_output=response, retrieval_context= retrieved_contexts)
    
    deep_dataset.append(test_case)
    
        
print("number using knowledge graph %d" %(distance_below_threshold))
  
deepeval_dataset = EvaluationDataset(test_cases=deep_dataset)
# Out:
# 0
# What is the primary objective of introducing a Regulation to ensure consistent protection for natural persons throughout the Union?
# InputText
# kg distance:0.682028
# Action
# kg distance:0.731787
# Reason
# kg distance:0.716642
# all
# kg distance:0.772929
# lOWEST DISTANCE field:InputText
#  number unique kgs:1
# {'InputText': 'The data protection officer shall be bound by secrecy or confidentiality concerning the performance of his or her tasks, in accordance with Union or Member State law. ', 'Type': 'Obligation', 'Action': 'be bound by secrecy or confidentiality concerning the performance of his or her tasks', 'Condition': ' ', 'Modality': 'shall', 'Actor': 'data protection officer', 'Reason': nan, 'Artifact': '[Union or Member State law]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# composite
# {'InputText': 'The data protection officer shall be bound by secrecy or confidentiality concerning the performance of his or her tasks, in accordance with Union or Member State law. ', 'Type': 'Obligation', 'Action': 'be bound by secrecy or confidentiality concerning the performance of his or her tasks', 'Condition': ' ', 'Modality': 'shall', 'Actor': 'data protection officer', 'Reason': nan, 'Artifact': '[Union or Member State law]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# kg distance:0.682028
# article kg
# {'InputText': 'The data protection officer shall be bound by secrecy or confidentiality concerning the performance of his or her tasks, in accordance with Union or Member State law. ', 'Type': 'Obligation', 'Action': 'be bound by secrecy or confidentiality concerning the performance of his or her tasks', 'Condition': ' ', 'Modality': 'shall', 'Actor': 'data protection officer', 'Reason': nan, 'Artifact': '[Union or Member State law]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.976
# article_text:
#  In order to ensure a consistent level of protection for natural persons throughout the Union and to prevent divergences hampering the free movement of personal data within the internal market, a Regulation is necessary to provide legal certainty and transparency for economic operators, including micro, small and medium-sized enterprises, and to provide natural persons in all Member States with the same level of legally enforceable rights and obligations and responsibilities for controllers and processors, to ensure consistent monitoring of the processing of personal data, and equivalent sanctions in all Member States as well as effective cooperation between the supervisory authorities of different Member States. The proper functioning of the internal market requires that the free movement of personal data within the Union is not restricted or prohibited for reasons connected with the protection of natural persons with regard to the processing of personal data. To take account of the specific situation of micro, small and medium-sized enterprises, this Regulation includes a derogation for organisations with fewer than 250 employees with regard to record-keeping. In addition, the Union institutions and bodies, and Member States and their supervisory authorities, are encouraged to take account of the specific needs of micro, small and medium-sized enterprises in the application of this Regulation. The notion of micro, small and medium-sized enterprises should draw from Article 2 of the Annex to Commission Recommendation 2003/361/EC (1).
# article question:
# What is the primary objective of introducing a Regulation to ensure consistent protection for natural persons throughout the Union?
# article answer:
# to provide legal certainty and transparency for economic operators, including micro, small and medium-sized enterprises and to provide natural persons in all Member states with the same legal of legally enforceable rights and obligations and responsibilities for controllers and processors, to ensure consistent monitoring of the processing of personal data, and equivalent sanctions in all Member States as well as effective cooperation between the supervisory authorities of different Member States.
# response from LLM:
# The primary objective of introducing a Regulation to ensure consistent protection for natural persons throughout the Union is to implement "technical and organisational measures" (Article 32) that guarantee processing is performed in accordance with the Regulation, thereby ensuring the rights and freedoms of individuals are protected from risks of varying likelihood and severity.
# 1
# What are the main objectives of ensuring the free movement of personal data in the EU?
# InputText
# kg distance:0.693040
# Action
# kg distance:0.723033
# Reason
# kg distance:0.708845
# all
# kg distance:0.813697
# lOWEST DISTANCE field:InputText
#  number unique kgs:2
# {'InputText': 'The communication to the data subject referred to in paragraph 1 of this Article shall describe in clear and plain language the nature of the personal data breach and contain at least the information and measures referred to in points (b) (c) and (d) of Article 33 (3)', 'Type': 'Obligation', 'Action': 'describe in clear and plain language the nature of the personal data breach', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[paragraph 1, Article 33(3)]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# {'InputText': 'The record  of processing activities shall contain the categories of recipients to whom the personal data have been or will be disclosed including recipients in third countries or international organisations; ', 'Type': 'Obligation', 'Action': 'contain the categories of recipients to whom the personal data have been or will be disclosed including recipients in third countries or international organisations', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[the record]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# composite
# {'InputText': 'The communication to the data subject referred to in paragraph 1 of this Article shall describe in clear and plain language the nature of the personal data breach and contain at least the information and measures referred to in points (b) (c) and (d) of Article 33 (3) The record  of processing activities shall contain the categories of recipients to whom the personal data have been or will be disclosed including recipients in third countries or international organisations; ', 'Type': 'Obligation', 'Action': 'describe in clear and plain language the nature of the personal data breach contain the categories of recipients to whom the personal data have been or will be disclosed including recipients in third countries or international organisations', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[paragraph 1, Article 33(3)]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# kg distance:0.693040
# article kg
# {'InputText': 'The record  of processing activities shall contain the categories of recipients to whom the personal data have been or will be disclosed including recipients in third countries or international organisations; ', 'Type': 'Obligation', 'Action': 'contain the categories of recipients to whom the personal data have been or will be disclosed including recipients in third countries or international organisations', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[the record]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.890
# article_text:
# The proper functioning of the internal market requires that the free movement of personal data within the Union is not restricted or prohibited for reasons connected with the protection of natural persons with regard to the processing of personal data.
# article question:
# What are the main objectives of ensuring the free movement of personal data in the EU?
# article answer:
# The proper functioning of the internal market requires that the free movement of personal data within the Union is not restricted or prohibited for reasons connected with the protection of natural persons with regard to the processing of personal data.
# response from LLM:
# Based on the given contextual data and reference knowledge graph, the main objectives of ensuring the free movement of personal data in the EU are:
#
# 1. To process only necessary personal data for each specific purpose.
# 2. To limit access to personal data without individual's intervention.
#
# These objectives aim to ensure that personal data is processed in a way that respects individuals' rights and freedoms, while also facilitating the free flow of such data within the EU.
# 2
# What is the exemption from record-keeping requirements for?
# InputText
# kg distance:0.529882
# Action
# kg distance:0.629321
# Reason
# kg distance:0.594213
# all
# kg distance:0.662292
# lOWEST DISTANCE field:InputText
#  number unique kgs:2
# {'InputText': 'An approved certification mechanism pursuant to Article 42 may be used as an element to demonstrate compliance with the requirements set out in paragraphs 1 and 2 of this Article.', 'Type': 'Obligation', 'Action': 'be used as an element to demonstrate compliance', 'Condition': ' ', 'Modality': 'may', 'Actor': nan, 'Reason': ' ', 'Artifact': '[Article 42, paragraphs1 and 2 of this article]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# {'InputText': 'The records referred to in paragraphs 1 and 2 shall be in writing, including in electronic form.', 'Type': 'Obligation', 'Action': 'be in writing, including in electronic form', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[paragraphs 1 and 2]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# composite
# {'InputText': 'An approved certification mechanism pursuant to Article 42 may be used as an element to demonstrate compliance with the requirements set out in paragraphs 1 and 2 of this Article. The records referred to in paragraphs 1 and 2 shall be in writing, including in electronic form.', 'Type': 'Obligation', 'Action': 'be used as an element to demonstrate compliance be in writing, including in electronic form', 'Condition': ' ', 'Modality': 'may', 'Actor': nan, 'Reason': ' ', 'Artifact': '[Article 42, paragraphs1 and 2 of this article]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# kg distance:0.529882
# article kg
# {'InputText': 'The records referred to in paragraphs 1 and 2 shall be in writing, including in electronic form.', 'Type': 'Obligation', 'Action': 'be in writing, including in electronic form', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[paragraphs 1 and 2]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:1.007
# article_text:
# To take account of the specific situation of micro, small and medium-sized enterprises, this Regulation includes a derogation for organisations with fewer than 250 employees with regard to record-keeping.
# article question:
# What is the exemption from record-keeping requirements for?
# article answer:
# organisations with fewer than 250 employees
# response from LLM:
# Based on the given contextual data and reference knowledge graph, the exemption from record-keeping requirements is for an enterprise or organisation employing fewer than 250 persons, unless the processing carries out meets one of the following conditions:
#
# * The processing is likely to result in a risk to the rights and freedoms of data subjects.
# * The processing is not occasional.
# * The processing includes special categories of data as referred to in Article 9 (1) or personal data relating to criminal convictions and offences referred to in Article 10.
#
# This exemption is mentioned in paragraphs 1 and 2.
# 3
# What is the principle of transparency required for information addressed to the public or data subjects?
# InputText
# kg distance:0.622084
# Action
# kg distance:0.755697
# Reason
# kg distance:0.758778
# all
# kg distance:0.858857
# lOWEST DISTANCE field:InputText
#  number unique kgs:1
# {'InputText': 'This Article shall not apply to processing carried out by public authorities and bodies.', 'Type': 'Obligation', 'Action': 'processing carried out by public authorities and bodies', 'Condition': nan, 'Modality': 'shall', 'Actor': 'public authorities and bodies', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# composite
# {'InputText': 'This Article shall not apply to processing carried out by public authorities and bodies.', 'Type': 'Obligation', 'Action': 'processing carried out by public authorities and bodies', 'Condition': nan, 'Modality': 'shall', 'Actor': 'public authorities and bodies', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# kg distance:0.622084
# article kg
# {'InputText': 'This Article shall not apply to processing carried out by public authorities and bodies.', 'Type': 'Obligation', 'Action': 'processing carried out by public authorities and bodies', 'Condition': nan, 'Modality': 'shall', 'Actor': 'public authorities and bodies', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.793
# article_text:
#  The principle of transparency requires that any information addressed to the public or to the data subject be concise, easily accessible and easy to understand, and that clear and plain language and, additionally, where appropriate, visualisation be used. Such information could be provided in electronic form, for example, when addressed to the public, through a website. This is of particular relevance in situations where the proliferation of actors and the technological complexity of practice make it difficult for the data subject to know and understand whether, by whom and for what purpose personal data relating to him or her are being collected, such as in the case of online advertising. Given that children merit specific protection, any information and communication, where processing is addressed to a child, should be in such a clear and plain language that the child can easily understand.
# article question:
# What is the principle of transparency required for information addressed to the public or data subjects?
# article answer:
# The principle of transparency requires that any information be concise, easily accessible, and easy to understand, using clear and plain language and additionally visualisation where appropriate.
# response from LLM:
# According to the given data, the principle of transparency required for information addressed to the public or data subjects is "fair and transparent processing", which is mentioned in Article 4(b) as one of the purposes that associations and other bodies representing categories of controllers or processors may specify codes of conduct for. This principle is also implicitly referenced in the last paragraph, where it is stated that controllers shall implement appropriate technical and organisational measures to meet the requirements of this Regulation and protect the rights of data subjects, implying that transparency is a necessary aspect of these measures.
# 4
# What kind of measures should a controller establish to demonstrate compliance with this Regulation?
# InputText
# kg distance:0.499621
# Action
# kg distance:0.503308
# Reason
# kg distance:0.492974
# all
# kg distance:0.488808
# lOWEST DISTANCE field:all
#  number unique kgs:2
# {'InputText': 'Where appropriate, the controller shall seek the views of data subjects or their representatives on the intended processing, without prejudice to the protection of commercial or public interests or the security of processing operations. ', 'Type': 'Obligation', 'Action': 'seek the views of data subjects or their representatives on the intended processing', 'Condition': 'where appropriate', 'Modality': 'shall', 'Actor': 'controller', 'Reason': ' ', 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# {'InputText': 'Where proportionate in relation to processing activities, the measures referred to in paragraph 1 shall include the implementation of appropriate data protection policies by the controller.  Adherence to approved codes of conduct as referred to in Article 40 or approved certification mechanisms as referred to in Article 42 may be used as an element by which to demonstrate compliance with the obligations of the controller.', 'Type': 'Obligation', 'Action': 'include the implementation of appropriate data protection policies', 'Condition': 'Where proportionate in relation to processing activities', 'Modality': 'shall', 'Actor': 'controller', 'Reason': nan, 'Artifact': '[Paragraph 1,Article 40, Article 42]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# composite
# {'InputText': 'Where appropriate, the controller shall seek the views of data subjects or their representatives on the intended processing, without prejudice to the protection of commercial or public interests or the security of processing operations.  Where proportionate in relation to processing activities, the measures referred to in paragraph 1 shall include the implementation of appropriate data protection policies by the controller.  Adherence to approved codes of conduct as referred to in Article 40 or approved certification mechanisms as referred to in Article 42 may be used as an element by which to demonstrate compliance with the obligations of the controller.', 'Type': 'Obligation', 'Action': 'seek the views of data subjects or their representatives on the intended processing include the implementation of appropriate data protection policies', 'Condition': 'where appropriate', 'Modality': 'shall', 'Actor': 'controller', 'Reason': ' ', 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# kg distance:0.488808
# article kg
# {'InputText': 'Where proportionate in relation to processing activities, the measures referred to in paragraph 1 shall include the implementation of appropriate data protection policies by the controller.  Adherence to approved codes of conduct as referred to in Article 40 or approved certification mechanisms as referred to in Article 42 may be used as an element by which to demonstrate compliance with the obligations of the controller.', 'Type': 'Obligation', 'Action': 'include the implementation of appropriate data protection policies', 'Condition': 'Where proportionate in relation to processing activities', 'Modality': 'shall', 'Actor': 'controller', 'Reason': nan, 'Artifact': '[Paragraph 1,Article 40, Article 42]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.745
# article_text:
#  The responsibility and liability of the controller for any processing of personal data carried out by the controller or on the controller's behalf should be established. In particular, the controller should be obliged to implement appropriate and effective measures and be able to demonstrate the compliance of processing activities with this Regulation, including the effectiveness of the measures. Those measures should take into account the nature, scope, context and purposes of the processing and the risk to the rights and freedoms of natural persons.
# article question:
# What kind of measures should a controller establish to demonstrate compliance with this Regulation?
# article answer:
# Appropriate and effective measures and be able to demonstrate the compliance of processing activities within this Regulation. Also those measures should take into account the nature, scope, context and purposes of the processing and the risk to the rights and freedoms of natural persons.
# response from LLM:
# Based on the given contextual data and reference knowledge graph, a controller should establish measures that include the implementation of appropriate data protection policies, adherence to approved codes of conduct as referred to in Article 40 or approved certification mechanisms as referred to in Article 42. These measures shall be proportionate in relation to processing activities.
# 5
# What types of harm can result from personal data processing?
# InputText
# kg distance:0.518332
# Action
# kg distance:0.539640
# Reason
# kg distance:0.532705
# all
# kg distance:0.629543
# lOWEST DISTANCE field:InputText
#  number unique kgs:1
# {'InputText': 'The record  of processing activities shall contain a description of the categories of data subjects and of the categories of personal data; ', 'Type': 'Obligation', 'Action': 'contain a description of the categories of data subjects and of the categories of personal data', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[the record]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# composite
# {'InputText': 'The record  of processing activities shall contain a description of the categories of data subjects and of the categories of personal data; ', 'Type': 'Obligation', 'Action': 'contain a description of the categories of data subjects and of the categories of personal data', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[the record]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# kg distance:0.518332
# article kg
# {'InputText': 'The record  of processing activities shall contain a description of the categories of data subjects and of the categories of personal data; ', 'Type': 'Obligation', 'Action': 'contain a description of the categories of data subjects and of the categories of personal data', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[the record]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.735
# article_text:
#  The risk to the rights and freedoms of natural persons, of varying likelihood and severity, may result from personal data processing which could lead to physical, material or non-material damage, in particular: where the processing may give rise to discrimination, identity theft or fraud, financial loss, damage to the reputation, loss of confidentiality of personal data protected by professional secrecy, unauthorised reversal of pseudonymisation, or any other significant economic or social disadvantage; where data subjects might be deprived of their rights and freedoms or prevented from exercising control over their personal data; where personal data are processed which reveal racial or ethnic origin, political opinions, religion or philosophical beliefs, trade union membership, and the processing of genetic data, data concerning health or data concerning sex life or criminal convictions and offences or related security measures; where personal aspects are evaluated, in particular analysing or predicting aspects concerning performance at work, economic situation, health, personal preferences or interests, reliability or behaviour, location or movements, in order to create or use personal profiles; where personal data of vulnerable natural persons, in particular of children, are processed; or where processing involves a large amount of personal data and affects a large number of data subjects.
# article question:
# What types of harm can result from personal data processing?
# article answer:
# The risk to the rights and freedoms of natural persons may result in physical, material or non-material damage, including discrimination, identity theft or fraud, financial loss, damage to reputation, loss of confidentiality, unauthorised reversal of pseudonymisation, or any other significant economic or social disadvantage; where data subjects might be deprived of their rights and freedoms or prevented from exercising control over their personal data;  where personal data are processed which reveal racial or ethnic origin, political opinions, religion or philosophical beliefs, trade union membership, and the processing of genetic data, data concerning health or data concerning sex life or criminal convictions and offences or related security measures; where personal aspects are evaluated, in particular analysing or predicting aspects concerning performance at work, economic situation, health, personal preferences or interests, reliability or behaviour, location or movements, in order to create or use personal profiles; where personal data of vulnerable natural persons, in particular of children, are processed; or where processing involves a large amount of personal data and affects a large number of data subjects.
# response from LLM:
# Based on the provided contextual data, it is likely that high-risk processing operations could result in harm to the rights and freedoms of natural persons. The types of harm mentioned include:
#
# 1. Decisions producing legal effects or significantly affecting individuals.
# 2. The production of legal effects concerning the natural person.
#
# These harms are specifically highlighted as potential consequences of certain types of personal data processing, such as systematic evaluations based on automated processing (including profiling) and large-scale processing of special categories of data.
# 6
# How does one determine the likelihood and severity of the risk to the rights and freedoms of the data subject?
# InputText
# kg distance:0.647901
# Action
# kg distance:0.723062
# Reason
# kg distance:0.705885
# all
# kg distance:0.718986
# lOWEST DISTANCE field:InputText
#  number unique kgs:1
# {'InputText': 'In assessing the appropriate level of security account shall be taken in particular of the risks that are presented by processing, in particular from accidental or unlawful destruction, loss, alteration, unauthorised disclosure of, or access to personal data transmitted, stored or otherwise processed.', 'Type': 'Obligation', 'Action': 'assessing the appropriate level of security account shall be taken in particular of the risks that are presented by processing, in particular from accidental or unlawful destruction, loss, alteration, unauthorised disclosure of, or access to personal data transmitted, stored or otherwise processed.', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': ' ', 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# composite
# {'InputText': 'In assessing the appropriate level of security account shall be taken in particular of the risks that are presented by processing, in particular from accidental or unlawful destruction, loss, alteration, unauthorised disclosure of, or access to personal data transmitted, stored or otherwise processed.', 'Type': 'Obligation', 'Action': 'assessing the appropriate level of security account shall be taken in particular of the risks that are presented by processing, in particular from accidental or unlawful destruction, loss, alteration, unauthorised disclosure of, or access to personal data transmitted, stored or otherwise processed.', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': ' ', 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# kg distance:0.647901
# article kg
# {'InputText': 'In assessing the appropriate level of security account shall be taken in particular of the risks that are presented by processing, in particular from accidental or unlawful destruction, loss, alteration, unauthorised disclosure of, or access to personal data transmitted, stored or otherwise processed.', 'Type': 'Obligation', 'Action': 'assessing the appropriate level of security account shall be taken in particular of the risks that are presented by processing, in particular from accidental or unlawful destruction, loss, alteration, unauthorised disclosure of, or access to personal data transmitted, stored or otherwise processed.', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': ' ', 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.822
# article_text:
#  The likelihood and severity of the risk to the rights and freedoms of the data subject should be determined by reference to the nature, scope, context and purposes of the processing. Risk should be evaluated on the basis of an objective assessment, by which it is established whether data processing operations involve a risk or a high risk.
# article question:
# How does one determine the likelihood and severity of the risk to the rights and freedoms of the data subject?
# article answer:
# The likelihood and severity of the risk to the rights and freedoms of the data subject should be determined by reference to the nature, scope, context and purposes of the processing.
# response from LLM:
# According to the provided contextual data and reference knowledge graph, determining the likelihood and severity of the risk to the rights and freedoms of a data subject involves considering factors such as:
#
# * The state of the art
# * The cost of implementation
# * The nature, scope, context, and purposes of processing
# * The risks posed by the processing, including those of varying likelihood and severity
#
# These factors are taken into account when assessing the appropriate level of security measures to be implemented.
# 7
# What types of guidance could be provided by the Board or data protection officer to help controllers and processors identify and mitigate risks related to processing?
# InputText
# kg distance:0.460305
# Action
# kg distance:0.457607
# Reason
# kg distance:0.466932
# all
# kg distance:0.510940
# lOWEST DISTANCE field:Action
#  number unique kgs:2
# {'InputText': 'The controller shall consult the supervisory authority prior to processing where a data protection impact assessment under Article 35 indicates that the processing would result in a high risk in the absence of measures taken by the controller to mitigate the risk.', 'Type': 'Obligation', 'Action': ' consult the supervisory authority prior to processing where a data protection impact assessment under Article 35 indicates that the processing would result in a high risk in the absence of measures taken by the controller to mitigate the risk.', 'Condition': ' ', 'Modality': 'shall', 'Actor': 'controller', 'Reason': nan, 'Artifact': '[Article 35]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# {'InputText': 'Where necessary, the controller shall carry out a review to assess if processing is performed in accordance with the data protection impact assessment at least when there is a change of the risk represented by processing operations.', 'Type': 'Obligation', 'Action': 'carry out a review to assess if processing is performed in accordance with the data protection impact assessment at least when there is a change of the risk represented by processing operations', 'Condition': 'when there is a change of the risk represented by processing operations.', 'Modality': 'shall', 'Actor': 'the controller', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# composite
# {'InputText': 'The controller shall consult the supervisory authority prior to processing where a data protection impact assessment under Article 35 indicates that the processing would result in a high risk in the absence of measures taken by the controller to mitigate the risk. Where necessary, the controller shall carry out a review to assess if processing is performed in accordance with the data protection impact assessment at least when there is a change of the risk represented by processing operations.', 'Type': 'Obligation', 'Action': ' consult the supervisory authority prior to processing where a data protection impact assessment under Article 35 indicates that the processing would result in a high risk in the absence of measures taken by the controller to mitigate the risk. carry out a review to assess if processing is performed in accordance with the data protection impact assessment at least when there is a change of the risk represented by processing operations', 'Condition': ' ', 'Modality': 'shall', 'Actor': 'controller', 'Reason': nan, 'Artifact': '[Article 35]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# kg distance:0.457607
# article kg
# {'InputText': 'Where necessary, the controller shall carry out a review to assess if processing is performed in accordance with the data protection impact assessment at least when there is a change of the risk represented by processing operations.', 'Type': 'Obligation', 'Action': 'carry out a review to assess if processing is performed in accordance with the data protection impact assessment at least when there is a change of the risk represented by processing operations', 'Condition': 'when there is a change of the risk represented by processing operations.', 'Modality': 'shall', 'Actor': 'the controller', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.521
# article_text:
#  Guidance on the implementation of appropriate measures and on the demonstration of compliance by the controller or the processor, especially as regards the identification of the risk related to the processing, their assessment in terms of origin, nature, likelihood and severity, and the identification of best practices to mitigate the risk, could be provided in particular by means of approved codes of conduct, approved certifications, guidelines provided by the Board or indications provided by a data protection officer. The Board may also issue guidelines on processing operations that are considered to be unlikely to result in a high risk to the rights and freedoms of natural persons and indicate what measures may be sufficient in such cases to address such risk.
# article question:
# What types of guidance could be provided by the Board or data protection officer to help controllers and processors identify and mitigate risks related to processing?
# article answer:
# Approved codes of conduct, approved certifications, guidelines provided by the Board, or indications provided by the the data protection officer
# response from LLM:
# Based on the provided contextual data and reference knowledge graph, it appears that the data protection officer could provide guidance to controllers and processors on identifying and mitigating risks related to processing. Specifically:
#
# 1. The data protection officer could help identify potential conflicts of interest by reviewing tasks and duties assigned to them and ensuring they do not compromise their independence.
# 2. They could provide input on risk assessments, considering factors such as the nature, scope, context, and purposes of processing operations, to help controllers and processors make informed decisions about processing.
# 3. The data protection officer could offer guidance on performing regular reviews to assess compliance with data protection impact assessments, especially in cases where there is a change in risk represented by processing operations.
#
# By providing this guidance, the data protection officer can support controllers and processors in fulfilling their obligations under the General Data Protection Regulation (GDPR) regarding data protection and privacy.
# 8
# What measures can a controller take to ensure compliance with the  Regulation?
# InputText
# kg distance:0.490047
# Action
# kg distance:0.510534
# Reason
# kg distance:0.495569
# all
# kg distance:0.511225
# lOWEST DISTANCE field:InputText
#  number unique kgs:2
# {'InputText': 'Where appropriate, the controller shall seek the views of data subjects or their representatives on the intended processing, without prejudice to the protection of commercial or public interests or the security of processing operations. ', 'Type': 'Obligation', 'Action': 'seek the views of data subjects or their representatives on the intended processing', 'Condition': 'where appropriate', 'Modality': 'shall', 'Actor': 'controller', 'Reason': ' ', 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# {'InputText': 'Where proportionate in relation to processing activities, the measures referred to in paragraph 1 shall include the implementation of appropriate data protection policies by the controller.  Adherence to approved codes of conduct as referred to in Article 40 or approved certification mechanisms as referred to in Article 42 may be used as an element by which to demonstrate compliance with the obligations of the controller.', 'Type': 'Obligation', 'Action': 'include the implementation of appropriate data protection policies', 'Condition': 'Where proportionate in relation to processing activities', 'Modality': 'shall', 'Actor': 'controller', 'Reason': nan, 'Artifact': '[Paragraph 1,Article 40, Article 42]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# composite
# {'InputText': 'Where appropriate, the controller shall seek the views of data subjects or their representatives on the intended processing, without prejudice to the protection of commercial or public interests or the security of processing operations.  Where proportionate in relation to processing activities, the measures referred to in paragraph 1 shall include the implementation of appropriate data protection policies by the controller.  Adherence to approved codes of conduct as referred to in Article 40 or approved certification mechanisms as referred to in Article 42 may be used as an element by which to demonstrate compliance with the obligations of the controller.', 'Type': 'Obligation', 'Action': 'seek the views of data subjects or their representatives on the intended processing include the implementation of appropriate data protection policies', 'Condition': 'where appropriate', 'Modality': 'shall', 'Actor': 'controller', 'Reason': ' ', 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# kg distance:0.490047
# article kg
# {'InputText': 'Where appropriate, the controller shall seek the views of data subjects or their representatives on the intended processing, without prejudice to the protection of commercial or public interests or the security of processing operations. ', 'Type': 'Obligation', 'Action': 'seek the views of data subjects or their representatives on the intended processing', 'Condition': 'where appropriate', 'Modality': 'shall', 'Actor': 'controller', 'Reason': ' ', 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.752
# article_text:
#  The protection of the rights and freedoms of natural persons with regard to the processing of personal data require that appropriate technical and organisational measures be taken to ensure that the requirements of this Regulation are met. In order to be able to demonstrate compliance with this Regulation, the controller should adopt internal policies and implement measures which meet in particular the principles of data protection by design and data protection by default. Such measures could consist, inter alia, of minimising the processing of personal data, pseudonymising personal data as soon as possible, transparency with regard to the functions and processing of personal data, enabling the data subject to monitor the data processing, enabling the controller to create and improve security features. When developing, designing, selecting and using applications, services and products that are based on the processing of personal data or process personal data to fulfil their task, producers of the products, services and applications should be encouraged to take into account the right to data protection when developing and designing such products, services and applications and, with due regard to the state of the art, to make sure that controllers and processors are able to fulfil their data protection obligations. The principles of data protection by design and by default should also be taken into consideration in the context of public tenders.
# article question:
# What measures can a controller take to ensure compliance with the  Regulation?
# article answer:
# The controller should adopt internal policies and implement measures which meet in particular the principles of data protection by design and data protection by default, such as minimising the processing of personal data, pseudonymising personal data as soon as possible, transparency with regard to the functions and processing of personal data, enabling the data subject to monitor the data processing, enabling the controller to create and improve security features.
# response from LLM:
# Based on the provided contextual data and reference knowledge graph, a controller can take the following measures to ensure compliance with the Regulation:
#
# 1. Implementing appropriate data protection policies.
# 2. Adhering to approved codes of conduct (Article 40) or certification mechanisms (Article 42).
# 3. Reviewing and updating technical and organisational measures regularly, considering factors such as the nature, scope, context, and purposes of processing, as well as risks to individuals' rights and freedoms.
#
# These measures aim to ensure that processing is performed in accordance with the Regulation and enable the controller to demonstrate compliance.
# 9
# When developing, designing, selecting and using applications, services and products that are based on the processing of personal data or process personal data to fulfil their task, what should the producers of the products, services and applications be encouraged to do?
# InputText
# kg distance:0.660962
# Action
# kg distance:0.670725
# Reason
# kg distance:0.663674
# all
# kg distance:0.674197
# lOWEST DISTANCE field:InputText
#  number unique kgs:1
# {'InputText': 'Where a type of processing in particular using new technologies, and taking into account the nature, scope, context and purposes of the processing, is likely to result in a high risk to the rights and freedoms of natural persons, the controller shall, prior to the processing, carry out an assessment of the impact of the envisaged processing operations on the protection of personal data.', 'Type': 'Obligation', 'Action': 'carry out an assessment of the impact of the envisaged processing operations on the protection of personal data', 'Condition': 'Where a type of processing in particular using new technologies, and taking into account the nature, scope, context and purposes of the processing, is likely to result in a high risk to the rights and freedoms of natural persons', 'Modality': 'shall', 'Actor': 'controller', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# composite
# {'InputText': 'Where a type of processing in particular using new technologies, and taking into account the nature, scope, context and purposes of the processing, is likely to result in a high risk to the rights and freedoms of natural persons, the controller shall, prior to the processing, carry out an assessment of the impact of the envisaged processing operations on the protection of personal data.', 'Type': 'Obligation', 'Action': 'carry out an assessment of the impact of the envisaged processing operations on the protection of personal data', 'Condition': 'Where a type of processing in particular using new technologies, and taking into account the nature, scope, context and purposes of the processing, is likely to result in a high risk to the rights and freedoms of natural persons', 'Modality': 'shall', 'Actor': 'controller', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# kg distance:0.660962
# article kg
# {'InputText': 'Where a type of processing in particular using new technologies, and taking into account the nature, scope, context and purposes of the processing, is likely to result in a high risk to the rights and freedoms of natural persons, the controller shall, prior to the processing, carry out an assessment of the impact of the envisaged processing operations on the protection of personal data.', 'Type': 'Obligation', 'Action': 'carry out an assessment of the impact of the envisaged processing operations on the protection of personal data', 'Condition': 'Where a type of processing in particular using new technologies, and taking into account the nature, scope, context and purposes of the processing, is likely to result in a high risk to the rights and freedoms of natural persons', 'Modality': 'shall', 'Actor': 'controller', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.776
# article_text:
# When developing, designing, selecting and using applications, services and products that are based on the processing of personal data or process personal data to fulfil their task, producers of the products, services and applications should be encouraged to take into account the right to data protection when developing and designing such products, services and applications and, with due regard to the state of the art, to make sure that controllers and processors are able to fulfil their data protection obligations. The principles of data protection by design and by default should also be taken into consideration in the context of public tenders.
# article question:
# When developing, designing, selecting and using applications, services and products that are based on the processing of personal data or process personal data to fulfil their task, what should the producers of the products, services and applications be encouraged to do?
# article answer:
#  take into account the right to data protection when developing and designing such products, services and applications and, with due regard to the state of the art, to make sure that controllers and processors are able to fulfil their data protection obligations.
# response from LLM:
# According to the reference knowledge graph, the producers of products, services, and applications that process personal data should be encouraged to **carry out an assessment of the impact of the envisaged processing operations on the protection of personal data** when developing, designing, selecting, or using such applications, services, and products. This obligation applies where a type of processing is likely to result in a high risk to the rights and freedoms of natural persons.
# 10
# What are the main reasons for allocating responsibilities under the Regulation?
# InputText
# kg distance:0.587491
# Action
# kg distance:0.647484
# Reason
# kg distance:0.633522
# all
# kg distance:0.673627
# lOWEST DISTANCE field:InputText
#  number unique kgs:3
# ...
# kg distance:0.702026
# article kg
# {'InputText': 'The record  of processing activities shall contain a description of the categories of data subjects and of the categories of personal data; ', 'Type': 'Obligation', 'Action': 'contain a description of the categories of data subjects and of the categories of personal data', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[the record]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:1.317
# article_text:
# The necessary level of expert knowledge should be determined in particular according to the data processing operations carried out and the protection required for the personal data processed by the controller or the processor.
# article question:
# What factors determine the necessary level of expert knowledge?
# article answer:
# The necessary level of expert knowledge should be determined in particular according to the data processing operations carried out and the protection required for the personal data processed by the controller or the processor.
# response from LLM:
# Based on the given contextual data, the necessary level of expert knowledge for a Data Protection Officer (DPO) is determined by "expert knowledge of data protection law and practices". This factor is explicitly mentioned in the first sentence of the text as one of the professional qualities required to designate a DPO.
# 43
# What are associations or other bodies representing categories of controllers or processors encouraged to do under this Regulation?
# InputText
# kg distance:0.463291
# Action
# kg distance:0.464947
# Reason
# kg distance:0.454307
# all
# kg distance:0.487911
# lOWEST DISTANCE field:Reason
#  number unique kgs:1
# {'InputText': 'In cases other than those referred to in paragraph 1, the controller or processor or associations and other bodies representing categories of controllers or processors may or, where required by Union or Member State law shall, designate a data protection officer.  The data protection officer may act for such associations and other bodies representing controllers or processors.', 'Type': 'Obligation', 'Action': 'designate a data protection officer; act for such associations and other bodies representing controllers or processors.', 'Condition': 'in cases other than those referred to in paragraph 1', 'Modality': 'may', 'Actor': 'controller or processor or associations and other bodies representing categories of controllers or processors; Data Protection officer', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# composite
# {'InputText': 'In cases other than those referred to in paragraph 1, the controller or processor or associations and other bodies representing categories of controllers or processors may or, where required by Union or Member State law shall, designate a data protection officer.  The data protection officer may act for such associations and other bodies representing controllers or processors.', 'Type': 'Obligation', 'Action': 'designate a data protection officer; act for such associations and other bodies representing controllers or processors.', 'Condition': 'in cases other than those referred to in paragraph 1', 'Modality': 'may', 'Actor': 'controller or processor or associations and other bodies representing categories of controllers or processors; Data Protection officer', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# kg distance:0.454307
# article kg
# {'InputText': 'In cases other than those referred to in paragraph 1, the controller or processor or associations and other bodies representing categories of controllers or processors may or, where required by Union or Member State law shall, designate a data protection officer.  The data protection officer may act for such associations and other bodies representing controllers or processors.', 'Type': 'Obligation', 'Action': 'designate a data protection officer; act for such associations and other bodies representing controllers or processors.', 'Condition': 'in cases other than those referred to in paragraph 1', 'Modality': 'may', 'Actor': 'controller or processor or associations and other bodies representing categories of controllers or processors; Data Protection officer', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.613
# article_text:
#  Associations or other bodies representing categories of controllers or processors should be encouraged to draw up codes of conduct, within the limits of this Regulation, so as to facilitate the effective application of this Regulation, taking account of the specific characteristics of the processing carried out in certain sectors and the specific needs of micro, small and medium enterprises. In particular, such codes of conduct could calibrate the obligations of controllers and processors, taking into account the risk likely to result from the processing for the rights and freedoms of natural persons.
# article question:
# What are associations or other bodies representing categories of controllers or processors encouraged to do under this Regulation?
# article answer:
# draw up codes of conduct, within the limits of this Regulation
# response from LLM:
# According to the given context, associations and other bodies representing categories of controllers or processors are encouraged to "act for such associations and other bodies representing controllers or processors." This means that they should take on a representative role, likely by maintaining records of processing activities carried out on behalf of controllers or processors.
# 44
# What steps should associations and other bodies take when drawing up a code of conduct, or amending or extending one?
# InputText
# kg distance:0.689364
# Action
# kg distance:0.725363
# Reason
# kg distance:0.714540
# all
# kg distance:0.745099
# lOWEST DISTANCE field:InputText
#  number unique kgs:3
# {'InputText': 'The Board shall collate all approved codes of conduct, amendments and extensions in a register and shall make them publicly available by way of appropriate means.', 'Type': 'Obligation', 'Action': 'collate all approved codes of conduct, amendments and extensions and shall make them publicly available by way of appropriate means.', 'Condition': nan, 'Modality': 'shall', 'Actor': 'The Board', 'Reason': nan, 'Artifact': '[register]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# {'InputText': 'The Commission shall ensure appropriate publicity for the approved codes which have been decided as having general validity in accordance with paragraph 9.', 'Type': 'Obligation', 'Action': 'ensure appropriate publicity for the approved codes which have been decided as having general validity in accordance with paragraph 9.', 'Condition': ' ', 'Modality': 'shall', 'Actor': 'Commission', 'Reason': ' ', 'Artifact': '[paragraph 9]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# {'InputText': 'The record  of processing activities shall contain a description of the categories of data subjects and of the categories of personal data; ', 'Type': 'Obligation', 'Action': 'contain a description of the categories of data subjects and of the categories of personal data', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[the record]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# composite
# {'InputText': 'The Board shall collate all approved codes of conduct, amendments and extensions in a register and shall make them publicly available by way of appropriate means. The Commission shall ensure appropriate publicity for the approved codes which have been decided as having general validity in accordance with paragraph 9. The record  of processing activities shall contain a description of the categories of data subjects and of the categories of personal data; ', 'Type': 'Obligation', 'Action': 'collate all approved codes of conduct, amendments and extensions and shall make them publicly available by way of appropriate means. ensure appropriate publicity for the approved codes which have been decided as having general validity in accordance with paragraph 9. contain a description of the categories of data subjects and of the categories of personal data', 'Condition': nan, 'Modality': 'shall', 'Actor': 'The Board', 'Reason': nan, 'Artifact': '[register]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# kg distance:0.689364
# article kg
# {'InputText': 'The record  of processing activities shall contain a description of the categories of data subjects and of the categories of personal data; ', 'Type': 'Obligation', 'Action': 'contain a description of the categories of data subjects and of the categories of personal data', 'Condition': nan, 'Modality': 'shall', 'Actor': ' ', 'Reason': nan, 'Artifact': '[the record]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.873
# article_text:
#  When drawing up a code of conduct, or when amending or extending such a code, associations and other bodies representing categories of controllers or processors should consult relevant stakeholders, including data subjects where feasible, and have regard to submissions received and views expressed in response to such consultations.
# article question:
# What steps should associations and other bodies take when drawing up a code of conduct, or amending or extending one?
# article answer:
# Associations and other bodies should consult relevant stakeholders, including data subjects where feasible, and have regard to submissions received and views expressed in response to such consultations.
# response from LLM:
# According to the provided contextual data, associations and other bodies should submit a draft code, amendment or extension to the supervisory authority competent pursuant to Article 55. The supervisory authority shall then provide an opinion on whether the draft complies with this Regulation and approve it if it finds that it provides sufficient appropriate safeguards.
# 45
# What is the goal of encouraging certification mechanisms and data protection seals and marks in the context of this Regulation?
# InputText
# kg distance:0.485666
# Action
# kg distance:0.518499
# Reason
# kg distance:0.519964
# all
# kg distance:0.535171
# lOWEST DISTANCE field:InputText
#  number unique kgs:3
# {'InputText': 'The Board shall collate all certification mechanisms and data protection seals and marks in a register and shall make them publicly available by any appropriate means.', 'Type': 'Obligation', 'Action': 'collate all certification mechanisms and data protection seals and marks in a register and make them publicly available by any appropriate means', 'Condition': nan, 'Modality': 'shall', 'Actor': 'The Board', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# {'InputText': 'The Commission shall be empowered to adopt delegated acts in accordance with Article 92 for the purpose of specifying the requirements to be taken into account for the data protection certification mechanisms referred to in Article 42 (1) ', 'Type': 'Obligation', 'Action': 'be empowered to adopt delegated acts in accordance with Article 92 ', 'Condition': ' ', 'Modality': 'shall', 'Actor': 'The Commission', 'Reason': 'for the purpose of specifying the requirements to be taken into account for the data protection certification mechanisms', 'Artifact': '[Article 92, Article 42(1)]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# {'InputText': 'The Commission may adopt implementing acts laying down technical standards for certification mechanisms and data protection seals and marks, and mechanisms to promote and recognise those certification mechanisms, seals and marks.  Those implementing acts shall be adopted in accordance with the examination procedure referred to in Article 93 (2)', 'Type': 'Obligation', 'Action': 'adopt implementing acts laying down technical standards for certification mechanisms and data protection seals and marks, and mechanisms to promote and recognise those certification mechanisms, seals and marks', 'Condition': nan, 'Modality': 'may', 'Actor': 'The Commission', 'Reason': nan, 'Artifact': '[Article 93 (2)]', 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# composite
# {'InputText': 'The Board shall collate all certification mechanisms and data protection seals and marks in a register and shall make them publicly available by any appropriate means. The Commission shall be empowered to adopt delegated acts in accordance with Article 92 for the purpose of specifying the requirements to be taken into account for the data protection certification mechanisms referred to in Article 42 (1)  The Commission may adopt implementing acts laying down technical standards for certification mechanisms and data protection seals and marks, and mechanisms to promote and recognise those certification mechanisms, seals and marks.  Those implementing acts shall be adopted in accordance with the examination procedure referred to in Article 93 (2)', 'Type': 'Obligation', 'Action': 'collate all certification mechanisms and data protection seals and marks in a register and make them publicly available by any appropriate means be empowered to adopt delegated acts in accordance with Article 92  adopt implementing acts laying down technical standards for certification mechanisms and data protection seals and marks, and mechanisms to promote and recognise those certification mechanisms, seals and marks', 'Condition': nan, 'Modality': 'shall', 'Actor': 'The Board', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# kg distance:0.485666
# article kg
# {'InputText': 'The Board shall collate all certification mechanisms and data protection seals and marks in a register and shall make them publicly available by any appropriate means.', 'Type': 'Obligation', 'Action': 'collate all certification mechanisms and data protection seals and marks in a register and make them publicly available by any appropriate means', 'Condition': nan, 'Modality': 'shall', 'Actor': 'The Board', 'Reason': nan, 'Artifact': nan, 'Violation': nan, 'Exception': nan, 'Presence': nan, 'Time': nan, 'Sanction': nan, 'Situation': nan}
# closest distance in vector store:0.481
# article_text:
# In order to enhance transparency and compliance with this Regulation, the establishment of certification mechanisms and data protection seals and marks should be encouraged, allowing data subjects to quickly assess the level of data protection of relevant products and services.
# article question:
# What is the goal of encouraging certification mechanisms and data protection seals and marks in the context of this Regulation?
# article answer:
# To enhance transparency and compliance with this Regulation
# response from LLM:
# According to the provided contextual data, the goal of encouraging certification mechanisms and data protection seals and marks is to demonstrate compliance with this Regulation of processing operations by controllers and processors.
# number using knowledge graph 46

# %%
Experiment find article closest matching recital query and utilise the kg associated with that given article to enhance query

# %%
kg_data = pd.read_excel("Output/gdpr_articles_24_43_kg_output_corrected.xlsx")
# one more entry in the following txt as noticed as indvidual sentence at the end of recital 86 with no qa but seems an obligation
#data = pd.read_excel("Output/gdpr_chapter4_recital_kg_output_corrected.xlsx")

statements_all = kg_data["InputText"].tolist()
print(len(statements_all))

kg_list = [] 
for kg_row in kg_data.iterrows():
    kg_row = kg_row[1]
    kg_list.append(kg_row)


deep_dataset= []
    # Iterate over each row and generate the improved statement
for index,recital_data in enumerate(recital_json_data):


        recital_query= recital_data['question']
    
        recital_question= recital_data['question']
        recital_answer= recital_data['answer']
    
        print(index)
       
        retrieved_contexts,response = generate_answer_based_on_related_kg_enhance_prompt(kg_list,recital_data)

    
        retrieved_contexts = data

        test_case = LLMTestCase(input=recital_question, expected_output =recital_answer,actual_output=response, retrieval_context= retrieved_contexts)
    
        deep_dataset.append(test_case)
 
        

  
deepeval_dataset = EvaluationDataset(test_cases=deep_dataset)
# Out:
# 122
# 0
# closest distance in vector store:0.976
# closest article in vector store:0:article:24
# article_text:
#  In order to ensure a consistent level of protection for natural persons throughout the Union and to prevent divergences hampering the free movement of personal data within the internal market, a Regulation is necessary to provide legal certainty and transparency for economic operators, including micro, small and medium-sized enterprises, and to provide natural persons in all Member States with the same level of legally enforceable rights and obligations and responsibilities for controllers and processors, to ensure consistent monitoring of the processing of personal data, and equivalent sanctions in all Member States as well as effective cooperation between the supervisory authorities of different Member States. The proper functioning of the internal market requires that the free movement of personal data within the Union is not restricted or prohibited for reasons connected with the protection of natural persons with regard to the processing of personal data. To take account of the specific situation of micro, small and medium-sized enterprises, this Regulation includes a derogation for organisations with fewer than 250 employees with regard to record-keeping. In addition, the Union institutions and bodies, and Member States and their supervisory authorities, are encouraged to take account of the specific needs of micro, small and medium-sized enterprises in the application of this Regulation. The notion of micro, small and medium-sized enterprises should draw from Article 2 of the Annex to Commission Recommendation 2003/361/EC (1).
# article question:
# What is the primary objective of introducing a Regulation to ensure consistent protection for natural persons throughout the Union?
# article answer:
# to provide legal certainty and transparency for economic operators, including micro, small and medium-sized enterprises and to provide natural persons in all Member states with the same legal of legally enforceable rights and obligations and responsibilities for controllers and processors, to ensure consistent monitoring of the processing of personal data, and equivalent sanctions in all Member States as well as effective cooperation between the supervisory authorities of different Member States.
# response from LLM:
# Based on the given contextual data and reference knowledge graph, the primary objective of introducing a Regulation to ensure consistent protection for natural persons throughout the Union is to **ensure that processing is performed in accordance with this Regulation**.
# 1
# closest distance in vector store:0.890
# closest article in vector store:3:article:25
# article_text:
# The proper functioning of the internal market requires that the free movement of personal data within the Union is not restricted or prohibited for reasons connected with the protection of natural persons with regard to the processing of personal data.
# article question:
# What are the main objectives of ensuring the free movement of personal data in the EU?
# article answer:
# The proper functioning of the internal market requires that the free movement of personal data within the Union is not restricted or prohibited for reasons connected with the protection of natural persons with regard to the processing of personal data.
# response from LLM:
# Based on the given contextual data and reference knowledge graph, the main objectives of ensuring the free movement of personal data in the EU are:
#
# * To ensure that only necessary personal data is processed for each specific purpose.
# * To prevent unnecessary accessibility of personal data to an indefinite number of natural persons without individual intervention.
#
# In other words, the objective is to implement measures that minimize the risk of unauthorized access or processing of personal data.
# 2
# closest distance in vector store:1.007
# closest article in vector store:39:article:30
# article_text:
# To take account of the specific situation of micro, small and medium-sized enterprises, this Regulation includes a derogation for organisations with fewer than 250 employees with regard to record-keeping.
# article question:
# What is the exemption from record-keeping requirements for?
# article answer:
# organisations with fewer than 250 employees
# response from LLM:
# The exemption from record-keeping requirements is for an enterprise or organisation employing fewer than 250 persons unless the processing it carries out is likely to result in a risk to the rights and freedoms of data subjects, the processing is not occasional, or the processing includes special categories of data as referred to in Article 9 (1) or personal data relating to criminal convictions and offences referred to in Article 10.
# 3
# closest distance in vector store:0.793
# closest article in vector store:55:article:34
# article_text:
#  The principle of transparency requires that any information addressed to the public or to the data subject be concise, easily accessible and easy to understand, and that clear and plain language and, additionally, where appropriate, visualisation be used. Such information could be provided in electronic form, for example, when addressed to the public, through a website. This is of particular relevance in situations where the proliferation of actors and the technological complexity of practice make it difficult for the data subject to know and understand whether, by whom and for what purpose personal data relating to him or her are being collected, such as in the case of online advertising. Given that children merit specific protection, any information and communication, where processing is addressed to a child, should be in such a clear and plain language that the child can easily understand.
# article question:
# What is the principle of transparency required for information addressed to the public or data subjects?
# article answer:
# The principle of transparency requires that any information be concise, easily accessible, and easy to understand, using clear and plain language and additionally visualisation where appropriate.
# response from LLM:
# According to the reference knowledge graph, there is no explicit principle of transparency required for information addressed to the public or data subjects. The obligation only mentions that if certain conditions are met (e.g., appropriate technical and organisational measures have been implemented), the communication to the data subject may not be required, and instead, a public communication or similar measure shall be used to inform data subjects in an equally effective manner.
# 4
# closest distance in vector store:0.745
# closest article in vector store:1:article:24
# article_text:
#  The responsibility and liability of the controller for any processing of personal data carried out by the controller or on the controller's behalf should be established. In particular, the controller should be obliged to implement appropriate and effective measures and be able to demonstrate the compliance of processing activities with this Regulation, including the effectiveness of the measures. Those measures should take into account the nature, scope, context and purposes of the processing and the risk to the rights and freedoms of natural persons.
# article question:
# What kind of measures should a controller establish to demonstrate compliance with this Regulation?
# article answer:
# Appropriate and effective measures and be able to demonstrate the compliance of processing activities within this Regulation. Also those measures should take into account the nature, scope, context and purposes of the processing and the risk to the rights and freedoms of natural persons.
# response from LLM:
# According to the provided contextual data and reference knowledge graph, a controller should establish:
#
# * Implementation of appropriate data protection policies (as an element to demonstrate compliance with paragraph 1)
# * Adherence to approved codes of conduct as referred to in Article 40 or approved certification mechanisms as referred to in Article 42 (as an element to demonstrate compliance with the obligations of the controller)
#
# These measures should be taken into account when considering the nature, scope, context, and purposes of processing, as well as the risks for the rights and freedoms of natural persons.
# 5
# closest distance in vector store:0.735
# closest article in vector store:57:article:35
# article_text:
#  The risk to the rights and freedoms of natural persons, of varying likelihood and severity, may result from personal data processing which could lead to physical, material or non-material damage, in particular: where the processing may give rise to discrimination, identity theft or fraud, financial loss, damage to the reputation, loss of confidentiality of personal data protected by professional secrecy, unauthorised reversal of pseudonymisation, or any other significant economic or social disadvantage; where data subjects might be deprived of their rights and freedoms or prevented from exercising control over their personal data; where personal data are processed which reveal racial or ethnic origin, political opinions, religion or philosophical beliefs, trade union membership, and the processing of genetic data, data concerning health or data concerning sex life or criminal convictions and offences or related security measures; where personal aspects are evaluated, in particular analysing or predicting aspects concerning performance at work, economic situation, health, personal preferences or interests, reliability or behaviour, location or movements, in order to create or use personal profiles; where personal data of vulnerable natural persons, in particular of children, are processed; or where processing involves a large amount of personal data and affects a large number of data subjects.
# article question:
# What types of harm can result from personal data processing?
# article answer:
# The risk to the rights and freedoms of natural persons may result in physical, material or non-material damage, including discrimination, identity theft or fraud, financial loss, damage to reputation, loss of confidentiality, unauthorised reversal of pseudonymisation, or any other significant economic or social disadvantage; where data subjects might be deprived of their rights and freedoms or prevented from exercising control over their personal data;  where personal data are processed which reveal racial or ethnic origin, political opinions, religion or philosophical beliefs, trade union membership, and the processing of genetic data, data concerning health or data concerning sex life or criminal convictions and offences or related security measures; where personal aspects are evaluated, in particular analysing or predicting aspects concerning performance at work, economic situation, health, personal preferences or interests, reliability or behaviour, location or movements, in order to create or use personal profiles; where personal data of vulnerable natural persons, in particular of children, are processed; or where processing involves a large amount of personal data and affects a large number of data subjects.
# response from LLM:
# According to the reference knowledge graph, personal data processing that can result in harm includes:
#
# * A systematic and extensive evaluation of personal aspects relating to natural persons which is based on automated processing, including profiling, and on which decisions are based that produce legal effects concerning the natural person or similarly significantly affect the natural person.
# * Processing on a large scale of special categories of data referred to in Article 9 (1) or of personal data relating to criminal convictions and offences referred to in Article 10.
# * A systematic monitoring of a publicly accessible area on a large scale.
#
# These types of processing can result in a high risk to the rights and freedoms of natural persons, which is why controllers are obligated to carry out an assessment of the impact of these processing operations on the protection of personal data.
# 6
# closest distance in vector store:0.822
# closest article in vector store:64:article:35
# article_text:
#  The likelihood and severity of the risk to the rights and freedoms of the data subject should be determined by reference to the nature, scope, context and purposes of the processing. Risk should be evaluated on the basis of an objective assessment, by which it is established whether data processing operations involve a risk or a high risk.
# article question:
# How does one determine the likelihood and severity of the risk to the rights and freedoms of the data subject?
# article answer:
# The likelihood and severity of the risk to the rights and freedoms of the data subject should be determined by reference to the nature, scope, context and purposes of the processing.
# response from LLM:
# Based on the provided contextual data, the likelihood and severity of the risk to the rights and freedoms of the data subject are determined through:
#
# 1. An assessment of the risks to the rights and freedoms of data subjects referred to in paragraph 1 (mentioned in clause (c) of the obligation).
# 2. Considering the state of the art, the cost of implementation, and the nature, scope, context, and purposes of processing.
# 3. Evaluating the risks posed by the processing, taking into account their likelihood and severity.
#
# This determination is intended to ensure the protection of personal data and demonstrate compliance with the Regulation, while considering the rights and legitimate interests of data subjects and other persons concerned.
# 7
# closest distance in vector store:0.521
# closest article in vector store:85:article:38
# article_text:
#  Guidance on the implementation of appropriate measures and on the demonstration of compliance by the controller or the processor, especially as regards the identification of the risk related to the processing, their assessment in terms of origin, nature, likelihood and severity, and the identification of best practices to mitigate the risk, could be provided in particular by means of approved codes of conduct, approved certifications, guidelines provided by the Board or indications provided by a data protection officer. The Board may also issue guidelines on processing operations that are considered to be unlikely to result in a high risk to the rights and freedoms of natural persons and indicate what measures may be sufficient in such cases to address such risk.
# article question:
# What types of guidance could be provided by the Board or data protection officer to help controllers and processors identify and mitigate risks related to processing?
# article answer:
# Approved codes of conduct, approved certifications, guidelines provided by the Board, or indications provided by the the data protection officer
# response from LLM:
# Based on the contextual data, the guidance that could be provided by the Board or Data Protection Officer to help controllers and processors identify and mitigate risks related to processing is:
#
# * The Data Protection Officer (DPO) should take into account the nature, scope, context, and purposes of processing operations when performing their tasks.
# * Controllers and processors should ensure that any additional tasks and duties assigned to the DPO do not result in a conflict of interests.
#
# By following these guidelines, controllers and processors can better identify potential risks related to processing and take measures to mitigate them.
# 8
# closest distance in vector store:0.752
# closest article in vector store:1:article:24
# article_text:
#  The protection of the rights and freedoms of natural persons with regard to the processing of personal data require that appropriate technical and organisational measures be taken to ensure that the requirements of this Regulation are met. In order to be able to demonstrate compliance with this Regulation, the controller should adopt internal policies and implement measures which meet in particular the principles of data protection by design and data protection by default. Such measures could consist, inter alia, of minimising the processing of personal data, pseudonymising personal data as soon as possible, transparency with regard to the functions and processing of personal data, enabling the data subject to monitor the data processing, enabling the controller to create and improve security features. When developing, designing, selecting and using applications, services and products that are based on the processing of personal data or process personal data to fulfil their task, producers of the products, services and applications should be encouraged to take into account the right to data protection when developing and designing such products, services and applications and, with due regard to the state of the art, to make sure that controllers and processors are able to fulfil their data protection obligations. The principles of data protection by design and by default should also be taken into consideration in the context of public tenders.
# article question:
# What measures can a controller take to ensure compliance with the  Regulation?
# article answer:
# The controller should adopt internal policies and implement measures which meet in particular the principles of data protection by design and data protection by default, such as minimising the processing of personal data, pseudonymising personal data as soon as possible, transparency with regard to the functions and processing of personal data, enabling the data subject to monitor the data processing, enabling the controller to create and improve security features.
# response from LLM:
# According to the given contextual data and reference knowledge graph, a controller can take the following measures to ensure compliance with the Regulation:
#
# 1. Implement appropriate data protection policies.
# 2. Adhere to approved codes of conduct (as referred to in Article 40) or approved certification mechanisms (as referred to in Article 42).
# 3. Implement technical and organisational measures to ensure processing is performed in accordance with the Regulation, taking into account the nature, scope, context and purposes of processing as well as the risks involved.
# 4. Review and update these measures where necessary.
#
# These measures are outlined in the provided contextual data and are applicable when the controller's actions are proportionate in relation to processing activities, as specified in Paragraph 1.
# 9
# closest distance in vector store:0.776
# closest article in vector store:57:article:35
# article_text:
# When developing, designing, selecting and using applications, services and products that are based on the processing of personal data or process personal data to fulfil their task, producers of the products, services and applications should be encouraged to take into account the right to data protection when developing and designing such products, services and applications and, with due regard to the state of the art, to make sure that controllers and processors are able to fulfil their data protection obligations. The principles of data protection by design and by default should also be taken into consideration in the context of public tenders.
# article question:
# When developing, designing, selecting and using applications, services and products that are based on the processing of personal data or process personal data to fulfil their task, what should the producers of the products, services and applications be encouraged to do?
# article answer:
#  take into account the right to data protection when developing and designing such products, services and applications and, with due regard to the state of the art, to make sure that controllers and processors are able to fulfil their data protection obligations.
# response from LLM:
# Based on the provided contextual data and reference knowledge graph, when developing, designing, selecting and using applications, services and products that process personal data or use it to fulfill their task, the producers of these products, services and applications should be encouraged to:
#
# **Carry out an assessment of the impact of the envisaged processing operations on the protection of personal data**, where a type of processing in particular using new technologies is likely to result in a high risk to the rights and freedoms of natural persons.
#
# In other words, producers should perform an impact assessment prior to processing personal data if it involves new technologies that may pose a significant risk to individuals' rights and freedoms.
# 10
# closest distance in vector store:0.937
# closest article in vector store:88:article:40
# article_text:
#  The protection of the rights and freedoms of data subjects as well as the responsibility and liability of controllers and processors, also in relation to the monitoring by and measures of supervisory authorities, requires a clear allocation of the responsibilities under this Regulation, including where a controller determines the purposes and means of the processing jointly with other controllers or where a processing operation is carried out on behalf of a controller.
# article question:
# What are the main reasons for allocating responsibilities under the Regulation?
# article answer:
# The protection of the rights and freedoms of data subjects as well as the responsibility and liability of controllers and processors, also in relation to the monitoring by and measures of supervisory authorities
# response from LLM:
# According to the provided contextual data and reference knowledge graph, the main reasons for allocating responsibilities under the Regulation are:
#
# * To contribute to the proper application of this Regulation
# * Taking account of the specific features of various processing sectors
# * Considering the specific needs of micro, small, and medium-sized enterprises.
#
# In other words, the allocation of responsibilities aims to ensure that the Regulation is effectively implemented in a way that takes into account the diverse characteristics of different industries and business sizes.
# 11
# closest distance in vector store:0.510
# closest article in vector store:8:article:27
# article_text:
#  Where a controller or a processor not established in the Union is processing personal data of data subjects who are in the Union whose processing activities are related to the offering of goods or services, irrespective of whether a payment of the data subject is required, to such data subjects in the Union, or to the monitoring of their behaviour as far as their behaviour takes place within the Union, the controller or the processor should designate a representative, unless the processing is occasional, does not include processing, on a large scale, of special categories of personal data or the processing of personal data relating to criminal convictions and offences, and is unlikely to result in a risk to the rights and freedoms of natural persons, taking into account the nature, context, scope and purposes of the processing or if the controller is a public authority or body. The representative should act on behalf of the controller or the processor and may be addressed by any supervisory authority. The representative should be explicitly designated by a written mandate of the controller or of the processor to act on its behalf with regard to its obligations under this Regulation. The designation of such a representative does not affect the responsibility or liability of the controller or of the processor under this Regulation. Such a representative should perform its tasks according to the mandate received from the controller or processor, including cooperating with the competent supervisory authorities with regard to any action taken to ensure compliance with this Regulation. The designated representative should be subject to enforcement proceedings in the event of non-compliance by the controller or processor.
# article question:
# When is it  necessary for a controller or processor to designate a representative?
# article answer:
# in the case a controller or a processor not established in the Union is processing personal data of data subjects who are in the Union whose processing activities are related to the offering of goods or services, irrespective of whether a payment of the data subject is required, to such data subjects in the Union, or to the monitoring of their behaviour as far as their behaviour takes place within the Union
# response from LLM:
# According to the given contextual data and reference knowledge graph, it is necessary for a controller or processor to designate a representative when:
#
# * The data subjects, whose personal data are processed in relation to the offering of goods or services to them, or whose behaviour is monitored, are located in one of the Member States.
#
# In other words, a representative needs to be designated when the processing of personal data affects individuals within the European Union.
# 12
# closest distance in vector store:0.546
# closest article in vector store:8:article:27
# article_text:
#  Where a controller or a processor not established in the Union is processing personal data of data subjects who are in the Union whose processing activities are related to the offering of goods or services, irrespective of whether a payment of the data subject is required, to such data subjects in the Union, or to the monitoring of their behaviour as far as their behaviour takes place within the Union, the controller or the processor should designate a representative, unless the processing is occasional, does not include processing, on a large scale, of special categories of personal data or the processing of personal data relating to criminal convictions and offences, and is unlikely to result in a risk to the rights and freedoms of natural persons, taking into account the nature, context, scope and purposes of the processing or if the controller is a public authority or body.
# article question:
# When is it not necessary for a controller or processor to designate a representative?
# article answer:
# The processing is occasional, does not include processing on a large scale, of special categories of personal data or the processing of personal data relating to criminal convictions and offences, and is unlikely to result in a risk to the rights and freedoms of natural persons, taking into account the nature, context, scope and purposes of the processing or if the controller is a public authority or body.
# response from LLM:
# According to the provided contextual data and knowledge graph, it is not necessary for a controller or processor to designate a representative in the following cases:
#
# 1. Occasional processing that does not include large-scale processing of special categories of data (Article 3(2)(a)) and is unlikely to result in a risk to the rights and freedoms of natural persons.
# 2. Processing carried out by a public authority or body.
#
# These exceptions are mentioned in Article 3(2) of the provided text.
# 13
# closest distance in vector store:0.678
# closest article in vector store:8:article:27
# article_text:
#  The representative should act on behalf of the controller or the processor and may be addressed by any supervisory authority. The representative should be explicitly designated by a written mandate of the controller or of the processor to act on its behalf with regard to its obligations under this Regulation. The designation of such a representative does not affect the responsibility or liability of the controller or of the processor under this Regulation. Such a representative should perform its tasks according to the mandate received from the controller or processor, including cooperating with the competent supervisory authorities with regard to any action taken to ensure compliance with this Regulation. The designated representative should be subject to enforcement proceedings in the event of non-compliance by the controller or processor.
# article question:
# What is the obligations of the representative?
# article answer:
# the representative should act on behalf of the controller or the processor and may be addressed by any supervisory authority. The representative should be explicitly designated by a written mandate of the controller or of the processor to act on its behalf with regard to its obligations under this Regulation. The designation of such a representative does not affect the responsibility or liability of the controller or of the processor under this Regulation. Such a representative should perform its tasks according to the mandate received from the controller or processor, including cooperating with the competent supervisory authorities with regard to any action taken to ensure compliance with this Regulation. The designated representative should be subject to enforcement proceedings in the event of non-compliance by the controller or processor.
# response from LLM:
# According to the reference knowledge graph, the obligations of the representative are:
#
# * To be established in one of the Member States where the data subjects, whose personal data are processed in relation to the offering of goods or services to them, or whose behaviour is monitored, are.
# * To be mandated by the controller or processor to be addressed in addition to or instead of the controller or the processor by, in particular, supervisory authorities and data subjects, on all issues related to processing, for the purposes of ensuring compliance with this Regulation.
#
# These obligations aim to ensure compliance with the Regulation.
# 14
# closest distance in vector store:0.680
# closest article in vector store:9:article:28
# article_text:
#  To ensure compliance with the requirements of this Regulation in respect of the processing to be carried out by the processor on behalf of the controller, when entrusting a processor with processing activities, the controller should use only processors providing sufficient guarantees, in particular in terms of expert knowledge, reliability and resources, to implement technical and organisational measures which will meet the requirements of this Regulation, including for the security of processing. The adherence of the processor to an approved code of conduct or an approved certification mechanism may be used as an element to demonstrate compliance with the obligations of the controller. The carrying-out of processing by a processor should be governed by a contract or other legal act under Union or Member State law, binding the processor to the controller, setting out the subject- matter and duration of the processing, the nature and purposes of the processing, the type of personal data and categories of data subjects, taking into account the specific tasks and responsibilities of the processor in the context of the processing to be carried out and the risk to the rights and freedoms of the data subject. The controller and processor may choose to use an individual contract or standard contractual clauses which are adopted either directly by the Commission or by a supervisory authority in accordance with the consistency mechanism and then adopted by the Commission. After the completion of the processing on behalf of the controller, the processor should, at the choice of the controller, return or delete the personal data, unless there is a requirement to store the personal data under Union or Member State law to which the processor is subject.
# article question:
# What are some key factors a controller should consider when selecting a processor to ensure compliance with the Regulation?
# article answer:
# The controller should use only processors providing sufficient guarantees, in particular in terms of expert knowledge, reliability and resources, to implement technical and organisational measures which will meet the requirements of this Regulation
# response from LLM:
# Based on the contextual data and reference knowledge graph, some key factors a controller should consider when selecting a processor to ensure compliance with the Regulation are:
#
# 1. **Sufficient guarantees**: The processor must provide sufficient guarantees to implement appropriate technical and organisational measures that meet the requirements of the Regulation.
# 2. **Technical and organisational measures**: The processor's measures should be designed to protect the rights of data subjects and ensure the protection of their personal data.
# 3. **Compliance with Articles 32-36**: The processor must assist the controller in ensuring compliance with obligations related to security, breach notification, data portability, and transparency.
# 4. **Nature of processing**: The controller should consider the nature of the processing activity and the information available to the processor when selecting a processor.
#
# By considering these factors, controllers can ensure that they are complying with their obligations under the Regulation when selecting a processor for carrying out processing activities on their behalf.
# 15
# closest distance in vector store:0.402
# closest article in vector store:12:article:28
# article_text:
# The carrying-out of processing by a processor should be governed by a contract or other legal act under Union or Member State law, binding the processor to the controller, setting out the subject- matter and duration of the processing, the nature and purposes of the processing, the type of personal data and categories of data subjects, taking into account the specific tasks and responsibilities of the processor in the context of the processing to be carried out and the risk to the rights and freedoms of the data subject.
# article question:
# What should a contract or other legal act governing processing by a processor contain?
# article answer:
# The contract or legal act should set out the subject-matter and duration of the processing, the nature and purposes of the processing, the type of personal data and categories of data subjects, taking into account the specific tasks and responsibilities of the processor in the context of the processing to be carried out and the risk to the rights and freedoms of the data subject.
# response from LLM:
# According to the given contextual data, a contract or other legal act governing processing by a processor should contain:
#
# * Subject-matter and duration of the processing
# * Nature and purpose of the processing
# * Type of personal data
# * Categories of data subjects
# * Obligations and rights of the controller
# 16
# closest distance in vector store:0.863
# closest article in vector store:106:article:42
# article_text:
# The controller and processor may choose to use an individual contract or standard contractual clauses which are adopted either directly by the Commission or by a supervisory authority in accordance with the consistency mechanism and then adopted by the Commission.
# article question:
# What are the options for controllers and processors when it comes to implementing data transfer agreements?
# article answer:
# The controller and processor may choose to use an individual contract or standard contractual clauses which are adopted either directly by the Commission or by a supervisory authority in accordance with the consistency mechanism and then adopted by the Commission.
# response from LLM:
# Based on the given contextual data and reference knowledge graph, controllers or processors subject to this Regulation have two options for implementing data transfer agreements:
#
# 1. **Establish data protection certification mechanisms, seals, or marks**: approved pursuant to paragraph 5 of this Article.
# 2. **Make binding and enforceable commitments**: via contractual or other legally binding instruments, to apply appropriate safeguards, including with regard to the rights of data subjects.
#
# These options are intended to demonstrate the existence of appropriate safeguards for personal data transfers to third countries or international organisations under the terms referred to in point (f) of Article 46(2).
# 17
# closest distance in vector store:0.803
# closest article in vector store:18:article:28
# article_text:
# After the completion of the processing on behalf of the controller, the processor should, at the choice of the controller, return or delete the personal data, unless there is a requirement to store the personal data under Union or Member State law to which the processor is subject.
# article question:
# What happens to personal data after processing is completed?
# article answer:
# The processor should, at the choice of the controller, return or delete the personal data, unless there is a requirement to store the personal data under Union or Member State law to which the processor is subject.
# response from LLM:
# According to the provided contextual data and reference knowledge graph, after processing is completed, the processor deletes or returns all personal data to the controller, and deletes existing copies, unless Union or Member State law requires storage of the personal data.
# 18
# closest distance in vector store:0.652
# closest article in vector store:19:article:28
# article_text:
#  In order to demonstrate compliance with this Regulation, the controller or processor should maintain records of processing activities under its responsibility. Each controller and processor should be obliged to cooperate with the supervisory authority and make those records, on request, available to it, so that it might serve for monitoring those processing operations.
# article question:
# What type of records do controllers or processors need to maintain to demonstrate compliance with this Regulation?
# article answer:
# Records of processing activities under its responsibility
# response from LLM:
# According to the provided contextual data and reference knowledge graph, controllers and processors need to maintain records of all categories of processing activities carried out on behalf of a controller. Specifically:
#
# * The record should contain:
# 	+ Name and contact details of the processor or processors.
# 	+ Name and contact details of each controller on whose behalf the processor is acting.
# 	+ Where applicable, name and contact details of the data protection officer.
#
# These records are necessary to demonstrate compliance with the obligations laid down in this Article and allow for audits, including inspections, conducted by the controller or another auditor mandated by the controller.
# 19
# closest distance in vector store:0.579
# closest article in vector store:57:article:35
# article_text:
#  In order to maintain security and to prevent processing in infringement of this Regulation, the controller or processor should evaluate the risks inherent in the processing and implement measures to mitigate those risks, such as encryption. Those measures should ensure an appropriate level of security, including confidentiality, taking into account the state of the art and the costs of implementation in relation to the risks and the nature of the personal data to be protected. In assessing data security risk, consideration should be given to the risks that are presented by personal data processing, such as accidental or unlawful destruction, loss, alteration, unauthorised disclosure of, or access to, personal data transmitted, stored or otherwise processed which may in particular lead to physical, material or non-material damage.
# article question:
# What measures can a controller or processor take to mitigate the risks inherent in processing personal data?
# article answer:
# Measures such as encryption
# response from LLM:
# Based on the given contextual data and reference knowledge graph, to mitigate the risks inherent in processing personal data, a controller or processor can take the following measures:
#
# 1. Carry out an assessment of the impact of the envisaged processing operations on the protection of personal data prior to processing, where a type of processing is likely to result in a high risk to the rights and freedoms of natural persons.
#
# Additionally, the controller and processor should:
#
# 2. Involve the Data Protection Officer (DPO) properly and in a timely manner in all issues related to the protection of personal data.
# 3. Implement appropriate technical and organisational measures to ensure that only necessary personal data are processed by default, including:
#    - Limiting the amount of personal data collected
#    - Restricting the extent of their processing
#    - Ensuring limited storage period
#    - Maintaining controlled accessibility
#
# By taking these measures, a controller or processor can mitigate the risks associated with processing personal data.
# 20
# closest distance in vector store:0.505
# closest article in vector store:57:article:35
# article_text:
#  In order to enhance compliance with this Regulation where processing operations are likely to result in a high risk to the rights and freedoms of natural persons, the controller should be responsible for the carrying-out of a data protection impact assessment to evaluate, in particular, the origin, nature, particularity and severity of that risk. The outcome of the assessment should be taken into account when determining the appropriate measures to be taken in order to demonstrate that the processing of personal data complies with this Regulation. Where a data-protection impact assessment indicates that processing operations involve a high risk which the controller cannot mitigate by appropriate measures in terms of available technology and costs of implementation, a consultation of the supervisory authority should take place prior to the processing.
# article question:
# What is the responsibility of the controller when processing operations are likely to result in a high risk to the rights and freedoms of natural persons?
# article answer:
# The controller should be responsible for the carrying-out of a data protection impact assessment to evaluate the origin, nature and severity of that risk. Where a data-protection impact assessment indicates that processing operations involve a high risk which the controller cannot mitigate by appropriate measures, a consultation of the supervisory authority should take place prior to the processing.
# response from LLM:
# According to the given reference knowledge graph and contextual data, when processing operations are likely to result in a high risk to the rights and freedoms of natural persons, the **responsibility of the controller is to carry out an assessment of the impact of the envisaged processing operations on the protection of personal data prior to the processing**.
# 21
# closest distance in vector store:0.441
# closest article in vector store:69:article:36
# article_text:
# Where a data-protection impact assessment indicates that processing operations involve a high risk which the controller cannot mitigate by appropriate measures in terms of available technology and costs of implementation, a consultation of the supervisory authority should take place prior to the processing.
# article question:
# What is the requirement when a data-protection impact assessment identifies a high-risk processing operation that cannot be mitigated?
# article answer:
# A consultation with the supervisory authority should take place prior to the processing.
# response from LLM:
# According to the given contextual data and reference knowledge graph, when a data-protection impact assessment identifies a high-risk processing operation that cannot be mitigated, the requirement is that the **controller shall consult the supervisory authority prior to processing**.
# 22
# closest distance in vector store:0.605
# closest article in vector store:54:article:34
# article_text:
#  A personal data breach may, if not addressed in an appropriate and timely manner, result in physical, material or non-material damage to natural persons such as loss of control over their personal data or limitation of their rights, discrimination, identity theft or fraud, financial loss, unauthorised reversal of pseudonymisation, damage to reputation, loss of confidentiality of personal data protected by professional secrecy or any other significant economic or social disadvantage to the natural person concerned. Therefore, as soon as the controller becomes aware that a personal data breach has occurred, the controller should notify the personal data breach to the supervisory authority without undue delay and, where feasible, not later than 72 hours after having become aware of it, unless the controller is able to demonstrate, in accordance with the accountability principle, that the personal data breach is unlikely to result in a risk to the rights and freedoms of natural persons. Where such notification cannot be achieved within 72 hours, the reasons for the delay should accompany the notification and information may be provided in phases without undue further delay.
# article question:
# What are the potential consequences of not addressing a personal data breach in an appropriate and timely manner?
# article answer:
# loss of control over their personal data or limitation of their rights, discrimination, identity theft or fraud, financial loss, unauthorised reversal of pseudonymisation, damage to reputation, loss of confidentiality of personal data protected by professional secrecy or any other significant economic or social disadvantage
# response from LLM:
# Based on the given contextual data and reference knowledge graph, the potential consequences of not addressing a personal data breach in an appropriate and timely manner are:
#
# * Failing to notify the data subject without undue delay, which may result in a high risk to their rights and freedoms (Article 33(3), point (a)).
# * Not notifying the supervisory authority competent in accordance with Article 55 within 72 hours after becoming aware of the breach, unless the breach is unlikely to result in a risk to the rights and freedoms of natural persons. This may lead to delayed or non-existent notification, which can compromise the effective handling and mitigation of the breach.
#
# In summary, not addressing a personal data breach in an appropriate and timely manner may have severe consequences for individuals' privacy and security, including potential harm to their rights and freedoms.
# 23
# closest distance in vector store:0.470
# closest article in vector store:48:article:33
# article_text:
# Therefore, as soon as the controller becomes aware that a personal data breach has occurred, the controller should notify the personal data breach to the supervisory authority without undue delay and, where feasible, not later than 72 hours after having become aware of it, unless the controller is able to demonstrate, in accordance with the accountability principle, that the personal data breach is unlikely to result in a risk to the rights and freedoms of natural persons.
# article question:
# What is the timeframe for notifying the supervisory authority about a personal data breach?
# article answer:
# not later than 72 hours after having become aware of it
# response from LLM:
# According to the provided contextual data, the timeframe for notifying the supervisory authority about a personal data breach is not later than 72 hours after becoming aware of it. This applies unless the personal data breach is unlikely to result in a risk to the rights and freedoms of natural persons.
# 24
# closest distance in vector store:0.955
# closest article in vector store:48:article:33
# article_text:
# Where such notification cannot be achieved within 72 hours, the reasons for the delay should accompany the notification and information may be provided in phases without undue further delay.
# article question:
# What happens if a notification cannot be completed within 72 hours?
# article answer:
# The reasons for the delay should accompany the notification and information may be provided in phases without undue further delay.
# response from LLM:
# According to the provided contextual data, if a notification cannot be completed within 72 hours, it shall be accompanied by reasons for the delay.
# 25
# closest distance in vector store:0.418
# ...
# * Processing is conducted on a large scale involving special categories of data referred to in Article 9(1) or personal data related to criminal convictions and offences referred to in Article 10 (condition (b)).
# * Systematic monitoring of a publicly accessible area is performed on a large scale (condition (c)).
#
# In these cases, the assessment is required "in particular" rather than just being limited to a single project.
# 36
# closest distance in vector store:0.634
# closest article in vector store:72:article:36
# article_text:
#  In the context of the adoption of the Member State law on which the performance of the tasks of the public authority or public body is based and which regulates the specific processing operation or set of operations in question, Member States may deem it necessary to carry out such assessment prior to the processing activities.
# article question:
# What provision allows Member States to conduct an assessment prior to processing activities?
# article answer:
# In the context of the adoption of the Member State law on which the performance of the tasks of the public authority or public body is based and which regulates the specific processing operation or set of operations in question
# response from LLM:
# According to the provided contextual data and reference knowledge graph, the provision that allows Member States to conduct an assessment prior to processing activities is:
#
# Paragraphs 1 to 7 shall not apply unless Member States deem it to be necessary to carry out such an assessment prior to processing activities.
#
# This provision can be found in the second piece of contextual data you provided.
# 37
# closest distance in vector store:0.585
# closest article in vector store:71:article:36
# article_text:
#  Where a data protection impact assessment indicates that the processing would, in the absence of safeguards, security measures and mechanisms to mitigate the risk, result in a high risk to the rights and freedoms of natural persons and the controller is of the opinion that the risk cannot be mitigated by reasonable means in terms of available technologies and costs of implementation, the supervisory authority should be consulted prior to the start of processing activities. Such high risk is likely to result from certain types of processing and the extent and frequency of processing, which may result also in a realisation of damage or interference with the rights and freedoms of the natural person. The supervisory authority should respond to the request for consultation within a specified period. However, the absence of a reaction of the supervisory authority within that period should be without prejudice to any intervention of the supervisory authority in accordance with its tasks and powers laid down in this Regulation, including the power to prohibit processing operations. As part of that consultation process, the outcome of a data protection impact assessment carried out with regard to the processing at issue may be submitted to the supervisory authority, in particular the measures envisaged to mitigate the risk to the rights and freedoms of natural persons.
# article question:
# What are the circumstances under which the controller is required to consult with the supervisory authority prior to starting data processing activities?
# article answer:
# Where a data protection impact assessment indicates that the processing would, in the absence of safeguards, security measures and mechanisms to mitigate the risk, result in a high risk to the rights and freedoms of natural persons and the controller is of the opinion that the risk cannot be mitigated by reasonable means in terms of available technologies and costs of implementation.
# response from LLM:
# According to the contextual data and reference knowledge graph, a controller is required to consult with the supervisory authority prior to starting data processing activities when:
#
# * The controller intends to process personal data (no specific condition mentioned).
# * This consultation is mandatory, as indicated by the modality "shall".
#
# The circumstances under which this obligation arises are not explicitly stated in the text.
# 38
# closest distance in vector store:0.770
# closest article in vector store:70:article:36
# article_text:
#  The supervisory authority should respond to the request for consultation within a specified period. However, the absence of a reaction of the supervisory authority within that period should be without prejudice to any intervention of the supervisory authority in accordance with its tasks and powers laid down in this Regulation, including the power to prohibit processing operations. As part of that consultation process, the outcome of a data protection impact assessment carried out with regard to the processing at issue may be submitted to the supervisory authority, in particular the measures envisaged to mitigate the risk to the rights and freedoms of natural persons.
# article question:
# How should the supervisory authority respond to the request for a consultation?
# article answer:
# The supervisory authority should respond to the request for consultation within a certain period. However the absence of a response should be without prejudice to any intervention of the supervisory authority
# response from LLM:
# According to the given query and reference knowledge graph, the supervisory authority shall respond to the request for consultation by providing written advice to the controller and, where applicable, to the processor. The condition for this response is that the supervisory authority is of the opinion that the intended processing would infringe the Regulation, particularly if the controller has insufficiently identified or mitigated the risk.
# 39
# closest distance in vector store:0.527
# closest article in vector store:80:article:38
# article_text:
#  The processor should assist the controller, where necessary and upon request, in ensuring compliance with the obligations deriving from the carrying out of data protection impact assessments and from prior consultation of the supervisory authority.
# article question:
# What is the processor's role in assisting the controller with data protection impact assessments?
# article answer:
# The processor should assist the controller, where necessary and upon request, in ensuring compliance with the obligations deriving from the carrying out of data protection impact assessments
# response from LLM:
# Based on the contextual data and reference knowledge graph, the processor's role in assisting the controller with data protection impact assessments is not explicitly mentioned. However, we can infer that the processor shall support the data protection officer (DPO) by providing resources necessary to carry out tasks related to data protection, which may include conducting data protection impact assessments.
#
# More specifically, Article 39 of the General Data Protection Regulation (GDPR) requires controllers and processors to conduct a data protection impact assessment when planning a type of processing that is likely to result in a high risk. The processor's role would be to provide resources and access to personal data and processing operations to support the DPO in performing these tasks.
#
# Therefore, while the specific role of the processor in conducting data protection impact assessments is not explicitly stated, it can be inferred that the processor shall play a supporting role in assisting the controller with these assessments by providing necessary resources to the DPO.
# 40
# closest distance in vector store:0.553
# closest article in vector store:72:article:36
# article_text:
#  A consultation of the supervisory authority should also take place in the course of the preparation of a legislative or regulatory measure which provides for the processing of personal data, in order to ensure compliance of the intended processing with this Regulation and in particular to mitigate the risk involved for the data subject.
# article question:
# What is the purpose of consulting the supervisory authority when preparing a legislative or regulatory measure that involves personal data processing?
# article answer:
# To ensure compliance with this Regulation and mitigate the risk involved for the data subject
# response from LLM:
# According to the provided contextual data and reference knowledge graph, the purpose of consulting the supervisory authority when preparing a legislative or regulatory measure that involves personal data processing is to inform the supervisory authority about the proposal and provide them with relevant information. This includes providing details such as the purposes and means of the intended processing, measures to protect data subjects' rights and freedoms, and any other requested information.
# 41
# closest distance in vector store:0.815
# closest article in vector store:78:article:37
# article_text:
#  Where the processing is carried out by a public authority, except for courts or independent judicial authorities when acting in their judicial capacity, where, in the private sector, processing is carried out by a controller whose core activities consist of processing operations that require regular and systematic monitoring of the data subjects on a large scale, or where the core activities of the controller or the processor consist of processing on a large scale of special categories of personal data and data relating to criminal convictions and offences, a person with expert knowledge of data protection law and practices should assist the controller or processor to monitor internal compliance with this Regulation. In the private sector, the core activities of a controller relate to its primary activities and do not relate to the processing of personal data as ancillary activities. The necessary level of expert knowledge should be determined in particular according to the data processing operations carried out and the protection required for the personal data processed by the controller or the processor. Such data protection officers, whether or not they are an employee of the controller, should be in a position to perform their duties and tasks in an independent manner.
# article question:
# what type of entities require assistance from a person with expert knowledge of data protection law and practices?
# article answer:
# a public authority, except for courts or independent judicial authorities when acting in their judicial capacity; the private sector, where processing is carried out by a controller whose core activities consist of processing operations that require regular and systematic monitoring of the data subjects on a large scale, or where the core activities of the controller or the processor consist of processing on a large scale of special categories of personal data and data relating to criminal convictions and offences
# response from LLM:
# Based on the given query and reference knowledge graph, a person with expert knowledge of data protection law and practices is required to assist:
#
# **The Data Protection Officer**
#
# This entity requires assistance from a person with expert knowledge of data protection law and practices in order to be designated and fulfill tasks referred to in Article 39.
# 42
# closest distance in vector store:1.317
# closest article in vector store:78:article:37
# article_text:
# The necessary level of expert knowledge should be determined in particular according to the data processing operations carried out and the protection required for the personal data processed by the controller or the processor.
# article question:
# What factors determine the necessary level of expert knowledge?
# article answer:
# The necessary level of expert knowledge should be determined in particular according to the data processing operations carried out and the protection required for the personal data processed by the controller or the processor.
# response from LLM:
# According to the given contextual data, the necessary level of expert knowledge is determined by "expert knowledge of data protection law and practices" and the ability to fulfill the tasks referred to in Article 39. This implies that the expert knowledge required for the designation of a data protection officer is specific to data protection law and practices, rather than a general or broad field of expertise.
# 43
# closest distance in vector store:0.613
# closest article in vector store:34:article:30
# article_text:
#  Associations or other bodies representing categories of controllers or processors should be encouraged to draw up codes of conduct, within the limits of this Regulation, so as to facilitate the effective application of this Regulation, taking account of the specific characteristics of the processing carried out in certain sectors and the specific needs of micro, small and medium enterprises. In particular, such codes of conduct could calibrate the obligations of controllers and processors, taking into account the risk likely to result from the processing for the rights and freedoms of natural persons.
# article question:
# What are associations or other bodies representing categories of controllers or processors encouraged to do under this Regulation?
# article answer:
# draw up codes of conduct, within the limits of this Regulation
# response from LLM:
# Based on the provided contextual data and reference knowledge graph, associations or other bodies representing categories of controllers or processors are encouraged to maintain a record of all categories of processing activities carried out on behalf of each controller.
# 44
# closest distance in vector store:0.873
# closest article in vector store:92:article:40
# article_text:
#  When drawing up a code of conduct, or when amending or extending such a code, associations and other bodies representing categories of controllers or processors should consult relevant stakeholders, including data subjects where feasible, and have regard to submissions received and views expressed in response to such consultations.
# article question:
# What steps should associations and other bodies take when drawing up a code of conduct, or amending or extending one?
# article answer:
# Associations and other bodies should consult relevant stakeholders, including data subjects where feasible, and have regard to submissions received and views expressed in response to such consultations.
# response from LLM:
# Based on the contextual data and reference knowledge graph, when drawing up a code of conduct or amending/extending one, associations and other bodies referred to in paragraph 2 should:
#
# 1. **Intend** to prepare a code of conduct or amend/extend an existing code.
# 2. **Submit** the draft code, amendment, or extension to the supervisory authority competent pursuant to Article 55.
#
# The supervisory authority shall then:
#
# 1. **Provide an opinion** on whether the draft code, amendment, or extension complies with this Regulation.
# 2. **Approve** that draft code, amendment, or extension if it finds that it provides sufficient appropriate safeguards.
# 45
# closest distance in vector store:0.481
# closest article in vector store:121:article:43
# article_text:
# In order to enhance transparency and compliance with this Regulation, the establishment of certification mechanisms and data protection seals and marks should be encouraged, allowing data subjects to quickly assess the level of data protection of relevant products and services.
# article question:
# What is the goal of encouraging certification mechanisms and data protection seals and marks in the context of this Regulation?
# article answer:
# To enhance transparency and compliance with this Regulation
# response from LLM:
# The goal of encouraging certification mechanisms and data protection seals and marks in the context of this Regulation is to demonstrate compliance with the Regulation by controllers and processors.

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import torch.nn as nn
import torch

query1 = "To enhance transparency and compliance with this Regulation"
query2 = " produce transparency and compliance with the regulation"

response = ollama.embed(
          model="all-minilm",
          input=query1
        )
embed1 = response['embeddings'][0]
embed1= np.array(embed1)


response = ollama.embed(
          model="all-minilm",
          input=query2
        )
embed2 = response['embeddings'][0]
embed2= np.array(embed2)

embed1 = embed1.reshape(1, -1)
print(embed1.shape)
embed2 = embed2.reshape(1, -1)

print( cosine_similarity(embed1,embed2)[0][0])

cos = nn.CosineSimilarity(dim=1, eps=1e-6)

embed1 = torch.from_numpy(embed1)

embed2 = torch.from_numpy(embed2)

print(cos(embed1,embed2).item())
# Out:
# (1, 384)
# 0.9084467754306719
# 0.9084467754306722

# %% [raw]
# Deepeval evaluation mechanism

# %%
from deepeval.metrics import (
  ContextualRelevancyMetric,
  ContextualRecallMetric,
  ContextualPrecisionMetric,
  AnswerRelevancyMetric,
  FaithfulnessMetric
)

from deepeval.metrics import GEval

metric_with_steps = False
# if steps are provided is this any better?
if metric_with_steps:

    correctness_metric = GEval(
    name="Correctness",
    criteria="Determine whether the actual output is factually correct based on the expected output.",
    evaluation_steps=[
        "Check whether the facts in 'actual output' contradicts any facts in 'expected output'",
        "You should also heavily penalize omission of detail",
        "Vague language, or contradicting OPINIONS, are OK"
    ],
    evaluation_params=[LLMTestCaseParams.ACTUAL_OUTPUT, LLMTestCaseParams.EXPECTED_OUTPUT],
    threshold=0.5

)
else:
    correctness_metric = GEval(
        name="Correctness",
        criteria="Determine if the 'actual output' is correct based on the 'expected output'.",
        evaluation_params=[LLMTestCaseParams.ACTUAL_OUTPUT, LLMTestCaseParams.EXPECTED_OUTPUT],
        threshold=0.5
    )


from deepeval import evaluate

contextual_precision = ContextualPrecisionMetric()
contextual_recall = ContextualRecallMetric()
contextual_relevancy = ContextualRelevancyMetric()
answer_relevancy = AnswerRelevancyMetric(threshold=0.8)
faithfulness = FaithfulnessMetric()

#evaluate(dataset, metrics=[contextual_precision, contextual_recall, contextual_relevancy, answer_relevancy, faithfulness])

evaluation_output = evaluate(deepeval_dataset, metrics=[correctness_metric])
#evaluation_output = evaluate(deepeval_dataset, metrics=[correctness_metric,answer_relevancy])
# Out:
# ✨ You're running DeepEval's latest Correctness [GEval] Metric! (using llama3:8b (Ollama), strict=False,
# async_mode=True)...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Correctness [GEval] (score: 0.8, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output provides a clear explanation of the main objectives for ensuring free movement of personal data in the EU, aligning with the expected output's focus on protecting individuals' rights. However, it does not directly address the restriction or prohibition of personal data processing, which is a key aspect of the expected output., error: None)
#
# For test case:
#
#   - input: What are the main objectives of ensuring the free movement of personal data in the EU?
#   - actual output: Based on the given contextual data, the main objectives of ensuring the free movement of personal data in the EU are:
#
# 1. To process only necessary personal data for each specific purpose.
# 2. To limit access to personal data without individual's intervention.
# 3. To implement technical and organisational measures to ensure the security and integrity of personal data.
#
# These objectives aim to protect individuals' rights and freedoms by ensuring that their personal data is processed in a responsible and transparent manner.
#   - expected output: The proper functioning of the internal market requires that the free movement of personal data within the Union is not restricted or prohibited for reasons connected with the protection of natural persons with regard to the processing of personal data.
#   - context: None
#   - retrieval context: ["The controller shall implement appropriate technical and organisational measures for ensuring that, by default, only personal data which are necessary for each specific purpose of the processing are processed.  That obligation applies to the amount of personal data collected, the extent of their processing, the period of their storage and their accessibility.  In particular, such measures shall ensure that by default personal data are not made accessible without the individual's intervention to an indefinite number of natural persons.", 'The communication to the data subject referred to in paragraph 1 of this Article shall describe in clear and plain language the nature of the personal data breach and contain at least the information and measures referred to in points (b) (c) and (d) of Article 33 (3)', ' The communication to the data subject referred to in paragraph 1 shall not be required if any of the following conditions are met: (a) the controller has implemented appropriate technical and organisational protection measures, and those measures were applied to the personal data affected by the personal data breach, in particular those that render the personal data unintelligible to any person who is not authorised to access it, such as encryption; (b) the controller has taken subsequent measures which ensure that the high risk to the rights and freedoms of data subjects referred to in paragraph 1 is no longer likely to materialise; (c) it would involve disproportionate effort. In such a case, there shall instead be a public communication or similar measure whereby the data subjects are informed in an equally effective manner. ']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Correctness [GEval] (score: 0.8, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output provides a clear explanation of the primary objective of introducing a Regulation, which aligns with the expected output's focus on providing legal certainty and transparency. However, the actual output does not explicitly mention the need for equivalent sanctions in all Member States or effective cooperation between supervisory authorities, which are key aspects of the expected output., error: None)
#
# For test case:
#
#   - input: What is the primary objective of introducing a Regulation to ensure consistent protection for natural persons throughout the Union?
#   - actual output: Based on the provided contextual data, the primary objective of introducing a Regulation to ensure consistent protection for natural persons throughout the Union is to implement appropriate technical and organisational measures to ensure that processing is performed in accordance with the Regulation. This is stated in the first sentence: "The controller shall implement appropriate technical and organisational measures to ensure and to be able to demonstrate that processing is performed in accordance with this Regulation."
#   - expected output: to provide legal certainty and transparency for economic operators, including micro, small and medium-sized enterprises and to provide natural persons in all Member states with the same legal of legally enforceable rights and obligations and responsibilities for controllers and processors, to ensure consistent monitoring of the processing of personal data, and equivalent sanctions in all Member States as well as effective cooperation between the supervisory authorities of different Member States.
#   - context: None
#   - retrieval context: ['Taking into account the nature, scope, context and purposes of processing as well as the risks of varying likelihood and severity for the rights and freedoms of natural persons, the controller shall implement appropriate technical and organisational measures to ensure and to be able to demonstrate that processing is performed in accordance with this Regulation.  Those measures shall be reviewed and updated where necessary.', 'Representatives of controllers or processors not established in the Union 1.  Where Article 3 (2) applies, the controller or the processor shall designate in writing a representative in the Union.  The obligation laid down in paragraph 1 of this Article shall not apply to: (a) processing which is occasional, does not include, on a large scale, processing of special categories of data as referred to in Article 9 (1) or processing of personal data relating to criminal convictions and offences referred to in Article 10, and is unlikely to result in a risk to the rights and freedoms of natural persons, taking into account the nature, context, scope and purposes of the processing; or (b) a public authority or body.', 'The Member States, the supervisory authorities, the Board and the Commission shall encourage, in particular at Union level, the establishment of data protection certification mechanisms and of data protection seals and marks, for the purpose of demonstrating compliance with this Regulation of processing operations by controllers and processors. The specific needs of micro, small and medium-sized enterprises shall be taken into account.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Correctness [GEval] (score: 0.2, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output is partially correct, but the expected output is a simple statement about organizations with fewer than 250 employees. The actual output provides more specific conditions for exemption from record-keeping requirements, which are not fully captured by the expected output., error: None)
#
# For test case:
#
#   - input: What is the exemption from record-keeping requirements for?
#   - actual output: According to the given contextual data and reference knowledge graph, the exemption from record-keeping requirements is for an enterprise or organization employing fewer than 250 persons unless:
#
# * The processing carried out is likely to result in a risk to the rights and freedoms of data subjects.
# * The processing is not occasional.
# * The processing includes special categories of data as referred to in Article 9 (1) or personal data relating to criminal convictions and offences referred to in Article 10.
#   - expected output: organisations with fewer than 250 employees
#   - context: None
#   - retrieval context: ['The obligations referred to in paragraphs 1 and 2 shall not apply to an enterprise or an organisation employing fewer than 250 persons unless the processing it carries out is likely to result in a risk to the rights and freedoms of data subjects, the processing is not occasional, or the processing includes special categories of data as referred to in Article 9 (1) or personal data relating to criminal convictions and offences referred to in Article 10.', 'The records referred to in paragraphs 1 and 2 shall be in writing, including in electronic form.', 'The record  of processing activities shall contain where possible, the envisaged time limits for erasure of the different categories of data; ']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Correctness [GEval] (score: 0.6, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output partially aligns with the expected output by acknowledging that transparency may be necessary for informing data subjects. However, it does not explicitly state the principle of transparency as required in the expected output. The actual output also provides a broader context and references relevant points from the provided text, which is a strength. Nevertheless, the actual output lacks the specific requirements outlined in the expected output regarding concise, easily accessible, and easy-to-understand information., error: None)
#
# For test case:
#
#   - input: What is the principle of transparency required for information addressed to the public or data subjects?
#   - actual output: According to the given contextual data, the principle of transparency required for information addressed to the public or data subjects is not explicitly stated. However, based on the provided text, we can infer that the condition (a) in paragraph 1 states that "the communication to the data subject referred to in paragraph 1 shall not be required if...". This implies that some level of transparency may be necessary for informing data subjects.
#
# In a broader context, taking into account the reference knowledge graph and the provided text, we can argue that the principle of transparency is implied as part of the obligation to "provide information to the public and to data subjects" (point (e) in paragraph 2). This suggests that controllers should provide clear and understandable information about their processing activities to both the general public and affected data subjects.
#   - expected output: The principle of transparency requires that any information be concise, easily accessible, and easy to understand, using clear and plain language and additionally visualisation where appropriate.
#   - context: None
#   - retrieval context: [' The communication to the data subject referred to in paragraph 1 shall not be required if any of the following conditions are met: (a) the controller has implemented appropriate technical and organisational protection measures, and those measures were applied to the personal data affected by the personal data breach, in particular those that render the personal data unintelligible to any person who is not authorised to access it, such as encryption; (b) the controller has taken subsequent measures which ensure that the high risk to the rights and freedoms of data subjects referred to in paragraph 1 is no longer likely to materialise; (c) it would involve disproportionate effort. In such a case, there shall instead be a public communication or similar measure whereby the data subjects are informed in an equally effective manner. ', 'Associations and other bodies representing categories of controllers or processors may prepare codes of conduct, or amend or extend such codes, for the purpose of specifying the application of this Regulation, such as with regard to: (a) fair and transparent processing; 4.(b) the legitimate interests pursued by controllers in specific contexts; (c) the collection of personal data; (d) the pseudonymisation of personal data; (e) the information provided to the public and to data subjects; (f) the exercise of the rights of data subjects; (g) the information provided to, and the protection of, children, and the manner in which the consent of the holders of parental responsibility over children is to be obtained; (h) the measures and procedures referred to in Articles 24 and 25 and the measures to ensure security of processing referred to in Article 32 ; (i) the notification of personal data breaches to supervisory authorities and the communication of such personal data breaches to data subjects; (j) the transfer of personal data to third countries or international organisations; or (k) out-of-court proceedings and other dispute resolution procedures for resolving disputes between controllers and data subjects with regard to processing, without prejudice to the rights of data subjects pursuant to Articles 77 and 79.', 'Taking into account the state of the art, the cost of implementation and the nature, scope, context and purposes of processing as well as the risks of varying likelihood and severity for rights and freedoms of natural persons posed by the processing, the controller shall, both at the time of the determination of the means for processing and at the time of the processing itself, implement appropriate technical and organisational measures, such as pseudonymisation, which are designed to implement data-protection principles, such as data minimisation, in an effective manner and to integrate the necessary safeguards into the processing in order to meet the requirements of this Regulation and protect the rights of data subjects.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Correctness [GEval] (score: 0.9, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output provides a clear explanation of the measures that should be taken to establish data protection policies, including implementing technical and organisational measures that take into account the nature, scope, context, and purposes of processing. The output also mentions adherence to approved codes of conduct or certification mechanisms as an element to demonstrate compliance. While it does not explicitly state 'Appropriate and effective measures', the provided explanation is comprehensive and aligns with the expected outcome., error: None)
#
# For test case:
#
#   - input: What kind of measures should a controller establish to demonstrate compliance with this Regulation?
#   - actual output: According to the given contextual data, a controller should establish:
#
# * Appropriate data protection policies by implementing measures referred to in paragraph 1.
# * Technical and organisational measures that ensure and demonstrate processing is performed in accordance with this Regulation, taking into account the nature, scope, context, and purposes of processing.
#
# Additionally, adherence to approved codes of conduct or certification mechanisms can be used as an element to demonstrate compliance.
#   - expected output: Appropriate and effective measures and be able to demonstrate the compliance of processing activities within this Regulation. Also those measures should take into account the nature, scope, context and purposes of the processing and the risk to the rights and freedoms of natural persons.
#   - context: None
#   - retrieval context: ['Where proportionate in relation to processing activities, the measures referred to in paragraph 1 shall include the implementation of appropriate data protection policies by the controller.  Adherence to approved codes of conduct as referred to in Article 40 or approved certification mechanisms as referred to in Article 42 may be used as an element by which to demonstrate compliance with the obligations of the controller.', 'Taking into account the nature, scope, context and purposes of processing as well as the risks of varying likelihood and severity for the rights and freedoms of natural persons, the controller shall implement appropriate technical and organisational measures to ensure and to be able to demonstrate that processing is performed in accordance with this Regulation.  Those measures shall be reviewed and updated where necessary.', 'A code of conduct referred to in paragraph 2 of this Article shall contain mechanisms which enable the body referred to in Article 41 (1) to carry out the mandatory monitoring of compliance with its provisions by the controllers or processors which undertake to apply it, without prejudice to the tasks and powers of supervisory authorities competent pursuant to Article 55 or 56.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Correctness [GEval] (score: 0.8, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output provides a clear explanation of the types of harm that can result from personal data processing, aligning with the expected outcome's mention of physical, material or non-material damage. However, it lacks specific examples and details about the potential consequences, such as financial loss, damage to reputation, or unauthorised reversal of pseudonymisation, which are present in the expected output., error: None)
#
# For test case:
#
#   - input: What types of harm can result from personal data processing?
#   - actual output: According to the provided contextual data, the types of harm that can result from personal data processing are:
#
# * A high risk to the rights and freedoms of natural persons.
#
# This is based on Article 35(1) which states that if a type of processing is likely to result in a high risk to the rights and freedoms of natural persons, the controller shall carry out an assessment of the impact of the envisaged processing operations on the protection of personal data.
#
# Note that the reference knowledge graph provided does not directly relate to this question.
#   - expected output: The risk to the rights and freedoms of natural persons may result in physical, material or non-material damage, including discrimination, identity theft or fraud, financial loss, damage to reputation, loss of confidentiality, unauthorised reversal of pseudonymisation, or any other significant economic or social disadvantage; where data subjects might be deprived of their rights and freedoms or prevented from exercising control over their personal data;  where personal data are processed which reveal racial or ethnic origin, political opinions, religion or philosophical beliefs, trade union membership, and the processing of genetic data, data concerning health or data concerning sex life or criminal convictions and offences or related security measures; where personal aspects are evaluated, in particular analysing or predicting aspects concerning performance at work, economic situation, health, personal preferences or interests, reliability or behaviour, location or movements, in order to create or use personal profiles; where personal data of vulnerable natural persons, in particular of children, are processed; or where processing involves a large amount of personal data and affects a large number of data subjects.
#   - context: None
#   - retrieval context: ['Where a type of processing in particular using new technologies, and taking into account the nature, scope, context and purposes of the processing, is likely to result in a high risk to the rights and freedoms of natural persons, the controller shall, prior to the processing, carry out an assessment of the impact of the envisaged processing operations on the protection of personal data.', 'The communication to the data subject referred to in paragraph 1 of this Article shall describe in clear and plain language the nature of the personal data breach and contain at least the information and measures referred to in points (b) (c) and (d) of Article 33 (3)', 'A data protection impact assessment referred to in paragraph 1 shall in particular be required in the case of: (a) a systematic and extensive evaluation of personal aspects relating to natural persons which is based on automated processing, including profiling, and on which decisions are based that produce legal effects concerning the natural person or similarly significantly affect the natural person; (b) processing on a large scale of special categories of data referred to in Article 9 (1) or of personal data relating to criminal convictions and offences referred to in Article 10 ; or (c) a systematic monitoring of a publicly accessible area on a large scale.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Correctness [GEval] (score: 0.6, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output partially aligns with the expected output by considering relevant factors such as state of the art, cost of implementation, nature, scope, context, and purposes of processing. However, it also includes additional factors not mentioned in the expected output, specifically accidental or unlawful destruction, loss, alteration, unauthorized disclosure, or access to personal data., error: None)
#
# For test case:
#
#   - input: How does one determine the likelihood and severity of the risk to the rights and freedoms of the data subject?
#   - actual output: Based on the contextual data and reference knowledge graph, one determines the likelihood and severity of the risk to the rights and freedoms of the data subject by taking into account:
#
# * The state of the art
# * The cost of implementation
# * The nature, scope, context, and purposes of processing
# * The risks posed by the processing
#
# This assessment considers potential risks from accidental or unlawful destruction, loss, alteration, unauthorized disclosure, or access to personal data.
#   - expected output: The likelihood and severity of the risk to the rights and freedoms of the data subject should be determined by reference to the nature, scope, context and purposes of the processing.
#   - context: None
#   - retrieval context: ['The assessment shall contain at least: (a) a systematic description of the envisaged processing operations and the purposes of the processing, including, where applicable, the legitimate interest pursued by the controller; (b) an assessment of the necessity and proportionality of the processing operations in relation to the purposes; (c) an assessment of the risks to the rights and freedoms of data subjects referred to in paragraph 1; and (d) the measures envisaged to address the risks, including safeguards, security measures and mechanisms to ensure the protection of personal data and to demonstrate compliance with this Regulation taking into account the rights and legitimate interests of data subjects and other persons concerned. ', ' The communication to the data subject referred to in paragraph 1 shall not be required if any of the following conditions are met: (a) the controller has implemented appropriate technical and organisational protection measures, and those measures were applied to the personal data affected by the personal data breach, in particular those that render the personal data unintelligible to any person who is not authorised to access it, such as encryption; (b) the controller has taken subsequent measures which ensure that the high risk to the rights and freedoms of data subjects referred to in paragraph 1 is no longer likely to materialise; (c) it would involve disproportionate effort. In such a case, there shall instead be a public communication or similar measure whereby the data subjects are informed in an equally effective manner. ', 'Taking into account the state of the art, the cost of implementation and the nature, scope, context and purposes of processing as well as the risks of varying likelihood and severity for rights and freedoms of natural persons posed by the processing, the controller shall, both at the time of the determination of the means for processing and at the time of the processing itself, implement appropriate technical and organisational measures, such as pseudonymisation, which are designed to implement data-protection principles, such as data minimisation, in an effective manner and to integrate the necessary safeguards into the processing in order to meet the requirements of this Regulation and protect the rights of data subjects.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Correctness [GEval] (score: 0.8, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output provides specific guidance on how controllers and processors can identify and mitigate risks related to processing, aligning with the expected outcome. However, it does not explicitly mention approved codes of conduct, approved certifications, or guidelines provided by the Board, which are mentioned in the expected output., error: None)
#
# For test case:
#
#   - input: What types of guidance could be provided by the Board or data protection officer to help controllers and processors identify and mitigate risks related to processing?
#   - actual output: Based on the provided contextual data and reference knowledge graph, the types of guidance that could be provided by the Board or data protection officer to help controllers and processors identify and mitigate risks related to processing are:
#
# * Conduct a data protection impact assessment under Article 35 to identify high-risk processing operations.
# * Consult the supervisory authority prior to processing when a data protection impact assessment indicates a high risk in the absence of measures taken by the controller to mitigate the risk.
#
# Additionally, the data protection officer may provide guidance on how to take into account the nature, scope, context, and purposes of processing operations when assessing risks, as mentioned in the third contextual statement.
#   - expected output: Approved codes of conduct, approved certifications, guidelines provided by the Board, or indications provided by the the data protection officer
#   - context: None
#   - retrieval context: ['The data protection officer may fulfil other tasks and duties. The controller or processor shall ensure that any such tasks and duties do not result in a conflict of interests.', 'The controller and processor shall ensure that the data protection officer does not receive any instructions regarding the exercise of those tasks. He or she shall not be dismissed or penalised by the controller or the processor for performing his tasks. The data protection officer shall directly report to the highest management level of the controller or the processor. ', 'The data protection officer shall in the performance of his or her tasks have due regard to the risk associated with processing operations, taking into account the nature, scope, context and purposes of processing.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Correctness [GEval] (score: 0.6, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output provides some relevant measures for ensuring compliance with the Regulation, but lacks specific details on how to implement these measures. The expected output is more comprehensive in outlining the principles of data protection by design and default, including transparency and enabling monitoring. While the actual output mentions implementing technical and organisational measures, it does not provide a clear connection to the expected output's emphasis on minimising processing and pseudonymisation., error: None)
#
# For test case:
#
#   - input: What measures can a controller take to ensure compliance with the  Regulation?
#   - actual output: Based on the contextual data and reference knowledge graph, a controller can take the following measures to ensure compliance with the Regulation:
#
# 1. Implementing appropriate data protection policies.
# 2. Adhering to approved codes of conduct or certification mechanisms.
# 3. Implementing technical and organisational measures that are reviewed and updated as necessary.
#
# Additionally, the Regulation suggests that controllers should demonstrate their compliance by being able to show that processing is performed in accordance with the Regulation.
#   - expected output: The controller should adopt internal policies and implement measures which meet in particular the principles of data protection by design and data protection by default, such as minimising the processing of personal data, pseudonymising personal data as soon as possible, transparency with regard to the functions and processing of personal data, enabling the data subject to monitor the data processing, enabling the controller to create and improve security features.
#   - context: None
#   - retrieval context: ['Where proportionate in relation to processing activities, the measures referred to in paragraph 1 shall include the implementation of appropriate data protection policies by the controller.  Adherence to approved codes of conduct as referred to in Article 40 or approved certification mechanisms as referred to in Article 42 may be used as an element by which to demonstrate compliance with the obligations of the controller.', 'A code of conduct referred to in paragraph 2 of this Article shall contain mechanisms which enable the body referred to in Article 41 (1) to carry out the mandatory monitoring of compliance with its provisions by the controllers or processors which undertake to apply it, without prejudice to the tasks and powers of supervisory authorities competent pursuant to Article 55 or 56.', 'Taking into account the nature, scope, context and purposes of processing as well as the risks of varying likelihood and severity for the rights and freedoms of natural persons, the controller shall implement appropriate technical and organisational measures to ensure and to be able to demonstrate that processing is performed in accordance with this Regulation.  Those measures shall be reviewed and updated where necessary.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Correctness [GEval] (score: 0.8, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output aligns well with the expected output, as both emphasize the importance of considering data protection when developing products, services, and applications. The actual output provides a more detailed explanation of the obligation to assess the impact on personal data protection, which is not explicitly mentioned in the expected output. However, the core message of prioritizing data protection is present in both outputs., error: None)
#
# For test case:
#
#   - input: When developing, designing, selecting and using applications, services and products that are based on the processing of personal data or process personal data to fulfil their task, what should the producers of the products, services and applications be encouraged to do?
#   - actual output: Based on the provided contextual data and reference knowledge graph, when developing, designing, selecting, and using applications, services, and products that process personal data or process personal data to fulfill their task, producers of these products should be encouraged to carry out an assessment of the impact of the envisaged processing operations on the protection of personal data. This obligation applies where a type of processing in particular using new technologies is likely to result in a high risk to the rights and freedoms of natural persons.
#   - expected output:  take into account the right to data protection when developing and designing such products, services and applications and, with due regard to the state of the art, to make sure that controllers and processors are able to fulfil their data protection obligations.
#   - context: None
#   - retrieval context: ['Where a type of processing in particular using new technologies, and taking into account the nature, scope, context and purposes of the processing, is likely to result in a high risk to the rights and freedoms of natural persons, the controller shall, prior to the processing, carry out an assessment of the impact of the envisaged processing operations on the protection of personal data.', 'The record  of processing activities shall contain a description of the categories of data subjects and of the categories of personal data; ', "The controller shall implement appropriate technical and organisational measures for ensuring that, by default, only personal data which are necessary for each specific purpose of the processing are processed.  That obligation applies to the amount of personal data collected, the extent of their processing, the period of their storage and their accessibility.  In particular, such measures shall ensure that by default personal data are not made accessible without the individual's intervention to an indefinite number of natural persons."]
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Correctness [GEval] (score: 0.2, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output provides some relevant details about the reasons for allocating responsibilities under the Regulation, but it does not directly address the expected outcome of protecting data subjects' rights and freedoms. The actual output focuses on the obligations outlined in the reference knowledge graph, whereas the expected output emphasizes the importance of monitoring by supervisory authorities., error: None)
#
# For test case:
#
#   - input: What are the main reasons for allocating responsibilities under the Regulation?
#   - actual output: Based on the provided contextual data and reference knowledge graph, the main reasons for allocating responsibilities under the Regulation are:
#
# 1. Encouraging codes of conduct to contribute to the proper application of the Regulation.
# 2. Providing a framework for processing in specific sectors and catering to the needs of micro, small, and medium-sized enterprises.
# 3. Facilitating consultation and prior authorisation with the supervisory authority for certain types of processing.
#
# These reasons are reflected in the obligations outlined in the reference knowledge graph, such as the Board's duty to submit its opinion to the Commission where necessary.
#   - expected output: The protection of the rights and freedoms of data subjects as well as the responsibility and liability of controllers and processors, also in relation to the monitoring by and measures of supervisory authorities
#   - context: None
#   - retrieval context: ['The Member States, the supervisory authorities, the Board and the Commission shall encourage the drawing up of codes of conduct intended to contribute to the proper application of this Regulation, taking account of the specific features of the various processing sectors and the specific needs of micro, small and medium-sized enterprises.', 'Member States shall consult the supervisory authority during the preparation of a proposal for a legislative measure to be adopted by a national parliament, or of a regulatory measure based on such a legislative measure, which relates to processing.', 'Notwithstanding paragraph 1, Member State law may require controllers to consult with, and obtain prior authorisation from, the supervisory authority in relation to processing by a controller for the performance of a task carried out by the controller in the public interest, including processing in relation to social protection and public health.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Correctness [GEval] (score: 0.9, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output is well-structured and accurately summarizes the exceptions mentioned in Article 27(1) of the Regulation. The language used is clear and concise, mirroring the expected output's phrasing. However, there is a slight mismatch in wording between 'unlikely to result in a risk' and 'taking into account the nature, context, scope and purposes of the processing or if the controller is a public authority or body', which prevents a perfect score., error: None)
#
# For test case:
#
#   - input: When is it not necessary for a controller or processor to designate a representative?
#   - actual output: Based on the provided contextual data, it is not necessary for a controller or processor to designate a representative in the following situations:
#
# 1. Occasional processing that does not include, on a large scale, processing of special categories of data or processing of personal data relating to criminal convictions and offences, and is unlikely to result in a risk to the rights and freedoms of natural persons.
# 2. A public authority or body.
#
# These exceptions are mentioned in Article 27(1) of the Regulation.
#   - expected output: The processing is occasional, does not include processing on a large scale, of special categories of personal data or the processing of personal data relating to criminal convictions and offences, and is unlikely to result in a risk to the rights and freedoms of natural persons, taking into account the nature, context, scope and purposes of the processing or if the controller is a public authority or body.
#   - context: None
#   - retrieval context: ['The representative shall be established in one of the Member States where the data subjects, whose personal data are processed in relation to the offering of goods or services to them, or whose behaviour is monitored, are. The representative shall be mandated by the controller or processor to be addressed in addition to or instead of the controller or the processor by, in particular, supervisory authorities and data subjects, on all issues related to processing, for the purposes of ensuring compliance with this Regulation. The designation of a representative by the controller or processor shall be without prejudice to legal actions which could be initiated against the controller or the processor themselves.', 'Representatives of controllers or processors not established in the Union 1.  Where Article 3 (2) applies, the controller or the processor shall designate in writing a representative in the Union.  The obligation laid down in paragraph 1 of this Article shall not apply to: (a) processing which is occasional, does not include, on a large scale, processing of special categories of data as referred to in Article 9 (1) or processing of personal data relating to criminal convictions and offences referred to in Article 10, and is unlikely to result in a risk to the rights and freedoms of natural persons, taking into account the nature, context, scope and purposes of the processing; or (b) a public authority or body.', " Each processor and, where applicable, the processor's representative shall maintain a record of all categories of processing activities carried out on behalf of a controller, containing: the name and contact details of the processor or processors and of each controller on behalf of which the processor is acting, and, where applicable, of the controller's or the processor's representative, and the data protection officer; "]
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Correctness [GEval] (score: 0.9, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output accurately summarizes the necessary conditions for a controller or processor to designate a representative, correctly referencing Article 27(1) of the GDPR. However, it does not fully align with the expected output as it only mentions two scenarios whereas the expected output provides additional circumstances that require a representative., error: None)
#
# For test case:
#
#   - input: When is it  necessary for a controller or processor to designate a representative?
#   - actual output: Based on the provided contextual data and reference knowledge graph, it is necessary for a controller or processor to designate a representative when:
#
# * The representative shall be established in one of the Member States where the data subjects are located (Article 27(1)).
# * The controller or processor is not established in the Union (Article 27(1), paragraph 2).
#
# In other words, a controller or processor must designate a representative if they are not based in the European Union, or if the data subjects whose personal data they process are located in the EU.
#   - expected output: in the case a controller or a processor not established in the Union is processing personal data of data subjects who are in the Union whose processing activities are related to the offering of goods or services, irrespective of whether a payment of the data subject is required, to such data subjects in the Union, or to the monitoring of their behaviour as far as their behaviour takes place within the Union
#   - context: None
#   - retrieval context: ['The representative shall be established in one of the Member States where the data subjects, whose personal data are processed in relation to the offering of goods or services to them, or whose behaviour is monitored, are. The representative shall be mandated by the controller or processor to be addressed in addition to or instead of the controller or the processor by, in particular, supervisory authorities and data subjects, on all issues related to processing, for the purposes of ensuring compliance with this Regulation. The designation of a representative by the controller or processor shall be without prejudice to legal actions which could be initiated against the controller or the processor themselves.', " Each processor and, where applicable, the processor's representative shall maintain a record of all categories of processing activities carried out on behalf of a controller, containing: the name and contact details of the processor or processors and of each controller on behalf of which the processor is acting, and, where applicable, of the controller's or the processor's representative, and the data protection officer; ", 'Representatives of controllers or processors not established in the Union 1.  Where Article 3 (2) applies, the controller or the processor shall designate in writing a representative in the Union.  The obligation laid down in paragraph 1 of this Article shall not apply to: (a) processing which is occasional, does not include, on a large scale, processing of special categories of data as referred to in Article 9 (1) or processing of personal data relating to criminal convictions and offences referred to in Article 10, and is unlikely to result in a risk to the rights and freedoms of natural persons, taking into account the nature, context, scope and purposes of the processing; or (b) a public authority or body.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Correctness [GEval] (score: 0.9, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output accurately summarizes the requirements for a contract or legal act governing processing by a processor, including subject-matter and duration of processing, nature and purpose of processing, type of personal data and categories of data subjects. The only minor discrepancy is that the expected output provides more context about specific tasks and responsibilities of the processor, which is not explicitly mentioned in the actual output., error: None)
#
# For test case:
#
#   - input: What should a contract or other legal act governing processing by a processor contain?
#   - actual output: According to the given contextual data, a contract or other legal act governing processing by a processor should contain:
#
# * The subject-matter and duration of the processing
# * The nature and purpose of the processing
# * The type of personal data and categories of data subjects
# * The obligations and rights of the controller
#
# These requirements are mentioned in paragraph 3.
#   - expected output: The contract or legal act should set out the subject-matter and duration of the processing, the nature and purposes of the processing, the type of personal data and categories of data subjects, taking into account the specific tasks and responsibilities of the processor in the context of the processing to be carried out and the risk to the rights and freedoms of the data subject.
#   - context: None
# ...
#   - expected output: To ensure compliance with this Regulation and mitigate the risk involved for the data subject
#   - context: None
#   - retrieval context: ['Member States shall consult the supervisory authority during the preparation of a proposal for a legislative measure to be adopted by a national parliament, or of a regulatory measure based on such a legislative measure, which relates to processing.', 'When consulting the supervisory authority pursuant to paragraph 1, the controller shall provide the supervisory authority with: (a) where applicable, the respective responsibilities of the controller, joint controllers and processors involved in the processing, in particular for processing within a group of undertakings; (b) the purposes and means of the intended processing; (c) the measures and safeguards provided to protect the rights and freedoms of data subjects pursuant to this Regulation; (d) where applicable, the contact details of the data protection officer; 4.(e) the data protection impact assessment provided for in Article 35 ; and (f) any other information requested by the supervisory authority.', 'The data protection officer shall have at least the following tasks: (a) to inform and advise the controller or the processor and the employees who carry out processing of their obligations pursuant to this Regulation and to other Union or Member State data protection provisions; (b) to monitor compliance with this Regulation, with other Union or Member State data protection provisions and with the policies of the controller or processor in relation to the protection of personal data, including the assignment of responsibilities, awareness-raising and training of staff involved in processing operations, and the related audits; (c) to provide advice where requested as regards the data protection impact assessment and monitor its performance pursuant to Article 35 ; (d) to cooperate with the supervisory authority; (e) to act as the contact point for the supervisory authority on issues relating to processing, including the prior consultation referred to in Article 36 , and to consult, where appropriate, with regard to any other matter.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Correctness [GEval] (score: 0.2, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output does not match the expected output in terms of specificity. While it mentions a group of undertakings requiring assistance, it lacks the detailed criteria outlined in the expected output, such as public authorities and private sector entities with specific core activities., error: None)
#
# For test case:
#
#   - input: what type of entities require assistance from a person with expert knowledge of data protection law and practices?
#   - actual output: According to the contextual data, a group of undertakings requires assistance from a person with expert knowledge of data protection law and practices.
#   - expected output: a public authority, except for courts or independent judicial authorities when acting in their judicial capacity; the private sector, where processing is carried out by a controller whose core activities consist of processing operations that require regular and systematic monitoring of the data subjects on a large scale, or where the core activities of the controller or the processor consist of processing on a large scale of special categories of personal data and data relating to criminal convictions and offences
#   - context: None
#   - retrieval context: ['The data protection officer shall be designated on the basis of professional qualities and, in particular, expert knowledge of data protection law and practices and the ability to fulfil the tasks referred to in Article 39 .', 'A group of undertakings may appoint a single data protection officier provided that a data protection officer is easily accessible from each establishment.', 'The controller shall seek the advice of the data protection officer, where designated, when carrying out a data protection impact assessment.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Correctness [GEval] (score: 0.2, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output partially aligns with the expected output by mentioning expert knowledge of data protection law and practices as a requirement for a Data Protection Officer. However, it does not consider the specific data processing operations carried out and the protection required for personal data processed by the controller or processor, which is a crucial aspect in determining the necessary level of expert knowledge., error: None)
#
# For test case:
#
#   - input: What factors determine the necessary level of expert knowledge?
#   - actual output: According to the provided contextual data, the necessary level of expert knowledge for a Data Protection Officer (DPO) is determined by their professional qualities and "expert knowledge of data protection law and practices". This suggests that the DPO must possess specialized knowledge in the field of data protection law and practices to effectively fulfill their tasks.
#   - expected output: The necessary level of expert knowledge should be determined in particular according to the data processing operations carried out and the protection required for the personal data processed by the controller or the processor.
#   - context: None
#   - retrieval context: ['The data protection officer shall be designated on the basis of professional qualities and, in particular, expert knowledge of data protection law and practices and the ability to fulfil the tasks referred to in Article 39 .', 'Certification bodies referred to in paragraph 1 shall be accredited in accordance with that paragraph only where they have: (a) demonstrated their independence and expertise in relation to the subject-matter of the certification to the satisfaction of the competent supervisory authority; (b) undertaken to respect the criteria referred to in Article 42 (5) and approved by the supervisory authority which is competent pursuant to Article 55 or 56 or by the Board pursuant to (c) established procedures for the issuing, periodic review and withdrawal of data protection certification, seals and marks; (d) established procedures and structures to handle complaints about infringements of the certification or the manner in which the certification has been, or is being, implemented by the controller or processor, and to make those procedures and structures transparent to data subjects and the public; and (e) demonstrated, to the satisfaction of the competent supervisory authority, that their tasks and duties do not result in a conflict of interests.', 'The requirements referred to in paragraph 3 of this Article and the criteria referred to in Article 42 (5) shall be made public by the supervisory authority in an easily accessible form. The supervisory authorities shall also transmit those requirements and criteria to the Board.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Correctness [GEval] (score: 0.2, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output does not align with the expected output, as it discusses maintaining records of processing activities and providing contact details, whereas the expected output is to draw up codes of conduct. The actual output also provides specific details about the record's contents, which are not mentioned in the expected output., error: None)
#
# For test case:
#
#   - input: What are associations or other bodies representing categories of controllers or processors encouraged to do under this Regulation?
#   - actual output: According to the provided contextual data, associations and other bodies representing categories of controllers or processors are encouraged to:
#
# * Maintain a record of all categories of processing activities carried out on behalf of each controller.
# * The record should contain:
# 	+ Categories of processing carried out on behalf of each controller.
# 	+ Name and contact details of the processor or processors and of each controller on behalf of which the processor is acting, as well as the data protection officer (where applicable).
# 	+ A general description of the technical and organisational security measures referred to in Article 32(1) (where possible).
#
# These obligations are mentioned in the contextual data provided.
#   - expected output: draw up codes of conduct, within the limits of this Regulation
#   - context: None
#   - retrieval context: [" Each processor and, where applicable, the processor's representative shall maintain a record of all categories of processing activities carried out on behalf of a controller, containing: the categories of processing carried out on behalf of each controller; ", " Each processor and, where applicable, the processor's representative shall maintain a record of all categories of processing activities carried out on behalf of a controller, containing: the name and contact details of the processor or processors and of each controller on behalf of which the processor is acting, and, where applicable, of the controller's or the processor's representative, and the data protection officer; ", " Each processor and, where applicable, the processor's representative shall maintain a record of all categories of processing activities carried out on behalf of a controller, containing: where possible, a general description of the technical and organisational security measures referred to in Article 32 (1) "]
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Correctness [GEval] (score: 0.2, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output does not align with the expected output. The actual output discusses submitting a draft code to a supervisory authority, whereas the expected output emphasizes consulting relevant stakeholders and having regard to their submissions., error: None)
#
# For test case:
#
#   - input: What steps should associations and other bodies take when drawing up a code of conduct, or amending or extending one?
#   - actual output: Based on the contextual data, when drawing up a code of conduct, or amending or extending one, associations and other bodies should:
#
# * Submit the draft code, amendment or extension to the supervisory authority which is competent pursuant to Article 55.
# * Provide an opinion from the supervisory authority on whether the draft code, amendment or extension complies with this Regulation.
#
# This information can be found in the first paragraph of the contextual data.
#   - expected output: Associations and other bodies should consult relevant stakeholders, including data subjects where feasible, and have regard to submissions received and views expressed in response to such consultations.
#   - context: None
#   - retrieval context: ['Associations and other bodies referred to in paragraph 2 of this Article which intend to prepare a code of conduct or to amend or extend an existing code shall submit the draft code, amendment or extension to the supervisory authority which is competent pursuant to Article 55 .  The supervisory authority shall provide an opinion on whether the draft code, amendment or extension complies with this Regulation and shall approve that draft code, amendment or extension if it finds that it provides sufficient appropriate safeguards.', 'The Commission may, by way of implementing acts, decide that the approved code of conduct, amendment or extension submitted to it pursuant to paragraph 8 of this Article have general validity within the Union. Those implementing acts shall be adopted in accordance with the examination procedure set out in Article 93 (2)', 'The Member States, the supervisory authorities, the Board and the Commission shall encourage the drawing up of codes of conduct intended to contribute to the proper application of this Regulation, taking account of the specific features of the various processing sectors and the specific needs of micro, small and medium-sized enterprises.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Correctness [GEval] (score: 0.2, threshold: 0.5, strict: False, evaluation model: llama3:8b (Ollama), reason: The actual output partially aligns with the expected output, as it mentions certification mechanisms and data protection seals, but does not explicitly state enhancing transparency. The actual output also includes additional information about demonstrating compliance with the Regulation., error: None)
#
# For test case:
#
#   - input: What is the goal of encouraging certification mechanisms and data protection seals and marks in the context of this Regulation?
#   - actual output: The goal of encouraging certification mechanisms and data protection seals and marks is to demonstrate compliance with this Regulation for processing operations by controllers and processors.
#   - expected output: To enhance transparency and compliance with this Regulation
#   - context: None
#   - retrieval context: ['The Commission may adopt implementing acts laying down technical standards for certification mechanisms and data protection seals and marks, and mechanisms to promote and recognise those certification mechanisms, seals and marks.  Those implementing acts shall be adopted in accordance with the examination procedure referred to in Article 93 (2)', 'The Member States, the supervisory authorities, the Board and the Commission shall encourage, in particular at Union level, the establishment of data protection certification mechanisms and of data protection seals and marks, for the purpose of demonstrating compliance with this Regulation of processing operations by controllers and processors. The specific needs of micro, small and medium-sized enterprises shall be taken into account.', 'The Board shall collate all certification mechanisms and data protection seals and marks in a register and shall make them publicly available by any appropriate means.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Correctness [GEval]: 71.74% pass rate
#
# ======================================================================
# ✓ Tests finished 🎉! Run 'deepeval view' to analyze, debug, and save evaluation results on Confident AI.

# %%
test_results = evaluation_output.test_results

# %%
sorted_test_results = sorted(test_results, key=lambda x: int(x.name.replace("test_case_","")))

# %%
print("Answer correctness")
number_success=0
for test in sorted_test_results:
    print(test.name)
    print(test.input)
    print(test.actual_output)
    print(test.expected_output)
    print("%s" %test.metrics_data[0].success)
    if (test.metrics_data[0].success==True):
        
        number_success+=1
    print(test.metrics_data[0].score)
    print(test.metrics_data[0].reason)
    print(" ")
    

print("number Correctness successful:%d" %number_success)
# Out:
# Answer correctness
# test_case_0
# What is the primary objective of introducing a Regulation to ensure consistent protection for natural persons throughout the Union?
# Based on the provided contextual data, the primary objective of introducing a Regulation to ensure consistent protection for natural persons throughout the Union is to implement appropriate technical and organisational measures to ensure that processing is performed in accordance with the Regulation. This is stated in the first sentence: "The controller shall implement appropriate technical and organisational measures to ensure and to be able to demonstrate that processing is performed in accordance with this Regulation."
# to provide legal certainty and transparency for economic operators, including micro, small and medium-sized enterprises and to provide natural persons in all Member states with the same legal of legally enforceable rights and obligations and responsibilities for controllers and processors, to ensure consistent monitoring of the processing of personal data, and equivalent sanctions in all Member States as well as effective cooperation between the supervisory authorities of different Member States.
# True
# 0.8
# The actual output provides a clear explanation of the primary objective of introducing a Regulation, which aligns with the expected output's focus on providing legal certainty and transparency. However, the actual output does not explicitly mention the need for equivalent sanctions in all Member States or effective cooperation between supervisory authorities, which are key aspects of the expected output.
#
# test_case_1
# What are the main objectives of ensuring the free movement of personal data in the EU?
# Based on the given contextual data, the main objectives of ensuring the free movement of personal data in the EU are:
#
# 1. To process only necessary personal data for each specific purpose.
# 2. To limit access to personal data without individual's intervention.
# 3. To implement technical and organisational measures to ensure the security and integrity of personal data.
#
# These objectives aim to protect individuals' rights and freedoms by ensuring that their personal data is processed in a responsible and transparent manner.
# The proper functioning of the internal market requires that the free movement of personal data within the Union is not restricted or prohibited for reasons connected with the protection of natural persons with regard to the processing of personal data.
# True
# 0.8
# The actual output provides a clear explanation of the main objectives for ensuring free movement of personal data in the EU, aligning with the expected output's focus on protecting individuals' rights. However, it does not directly address the restriction or prohibition of personal data processing, which is a key aspect of the expected output.
#
# test_case_2
# What is the exemption from record-keeping requirements for?
# According to the given contextual data and reference knowledge graph, the exemption from record-keeping requirements is for an enterprise or organization employing fewer than 250 persons unless:
#
# * The processing carried out is likely to result in a risk to the rights and freedoms of data subjects.
# * The processing is not occasional.
# * The processing includes special categories of data as referred to in Article 9 (1) or personal data relating to criminal convictions and offences referred to in Article 10.
# organisations with fewer than 250 employees
# False
# 0.2
# The actual output is partially correct, but the expected output is a simple statement about organizations with fewer than 250 employees. The actual output provides more specific conditions for exemption from record-keeping requirements, which are not fully captured by the expected output.
#
# test_case_3
# What is the principle of transparency required for information addressed to the public or data subjects?
# According to the given contextual data, the principle of transparency required for information addressed to the public or data subjects is not explicitly stated. However, based on the provided text, we can infer that the condition (a) in paragraph 1 states that "the communication to the data subject referred to in paragraph 1 shall not be required if...". This implies that some level of transparency may be necessary for informing data subjects.
#
# In a broader context, taking into account the reference knowledge graph and the provided text, we can argue that the principle of transparency is implied as part of the obligation to "provide information to the public and to data subjects" (point (e) in paragraph 2). This suggests that controllers should provide clear and understandable information about their processing activities to both the general public and affected data subjects.
# The principle of transparency requires that any information be concise, easily accessible, and easy to understand, using clear and plain language and additionally visualisation where appropriate.
# True
# 0.6
# The actual output partially aligns with the expected output by acknowledging that transparency may be necessary for informing data subjects. However, it does not explicitly state the principle of transparency as required in the expected output. The actual output also provides a broader context and references relevant points from the provided text, which is a strength. Nevertheless, the actual output lacks the specific requirements outlined in the expected output regarding concise, easily accessible, and easy-to-understand information.
#
# test_case_4
# What kind of measures should a controller establish to demonstrate compliance with this Regulation?
# According to the given contextual data, a controller should establish:
#
# * Appropriate data protection policies by implementing measures referred to in paragraph 1.
# * Technical and organisational measures that ensure and demonstrate processing is performed in accordance with this Regulation, taking into account the nature, scope, context, and purposes of processing.
#
# Additionally, adherence to approved codes of conduct or certification mechanisms can be used as an element to demonstrate compliance.
# Appropriate and effective measures and be able to demonstrate the compliance of processing activities within this Regulation. Also those measures should take into account the nature, scope, context and purposes of the processing and the risk to the rights and freedoms of natural persons.
# True
# 0.9
# The actual output provides a clear explanation of the measures that should be taken to establish data protection policies, including implementing technical and organisational measures that take into account the nature, scope, context, and purposes of processing. The output also mentions adherence to approved codes of conduct or certification mechanisms as an element to demonstrate compliance. While it does not explicitly state 'Appropriate and effective measures', the provided explanation is comprehensive and aligns with the expected outcome.
#
# test_case_5
# What types of harm can result from personal data processing?
# According to the provided contextual data, the types of harm that can result from personal data processing are:
#
# * A high risk to the rights and freedoms of natural persons.
#
# This is based on Article 35(1) which states that if a type of processing is likely to result in a high risk to the rights and freedoms of natural persons, the controller shall carry out an assessment of the impact of the envisaged processing operations on the protection of personal data.
#
# Note that the reference knowledge graph provided does not directly relate to this question.
# The risk to the rights and freedoms of natural persons may result in physical, material or non-material damage, including discrimination, identity theft or fraud, financial loss, damage to reputation, loss of confidentiality, unauthorised reversal of pseudonymisation, or any other significant economic or social disadvantage; where data subjects might be deprived of their rights and freedoms or prevented from exercising control over their personal data;  where personal data are processed which reveal racial or ethnic origin, political opinions, religion or philosophical beliefs, trade union membership, and the processing of genetic data, data concerning health or data concerning sex life or criminal convictions and offences or related security measures; where personal aspects are evaluated, in particular analysing or predicting aspects concerning performance at work, economic situation, health, personal preferences or interests, reliability or behaviour, location or movements, in order to create or use personal profiles; where personal data of vulnerable natural persons, in particular of children, are processed; or where processing involves a large amount of personal data and affects a large number of data subjects.
# True
# 0.8
# The actual output provides a clear explanation of the types of harm that can result from personal data processing, aligning with the expected outcome's mention of physical, material or non-material damage. However, it lacks specific examples and details about the potential consequences, such as financial loss, damage to reputation, or unauthorised reversal of pseudonymisation, which are present in the expected output.
#
# test_case_6
# How does one determine the likelihood and severity of the risk to the rights and freedoms of the data subject?
# Based on the contextual data and reference knowledge graph, one determines the likelihood and severity of the risk to the rights and freedoms of the data subject by taking into account:
#
# * The state of the art
# * The cost of implementation
# * The nature, scope, context, and purposes of processing
# * The risks posed by the processing
#
# This assessment considers potential risks from accidental or unlawful destruction, loss, alteration, unauthorized disclosure, or access to personal data.
# The likelihood and severity of the risk to the rights and freedoms of the data subject should be determined by reference to the nature, scope, context and purposes of the processing.
# True
# 0.6
# The actual output partially aligns with the expected output by considering relevant factors such as state of the art, cost of implementation, nature, scope, context, and purposes of processing. However, it also includes additional factors not mentioned in the expected output, specifically accidental or unlawful destruction, loss, alteration, unauthorized disclosure, or access to personal data.
#
# test_case_7
# What types of guidance could be provided by the Board or data protection officer to help controllers and processors identify and mitigate risks related to processing?
# Based on the provided contextual data and reference knowledge graph, the types of guidance that could be provided by the Board or data protection officer to help controllers and processors identify and mitigate risks related to processing are:
#
# * Conduct a data protection impact assessment under Article 35 to identify high-risk processing operations.
# * Consult the supervisory authority prior to processing when a data protection impact assessment indicates a high risk in the absence of measures taken by the controller to mitigate the risk.
#
# Additionally, the data protection officer may provide guidance on how to take into account the nature, scope, context, and purposes of processing operations when assessing risks, as mentioned in the third contextual statement.
# Approved codes of conduct, approved certifications, guidelines provided by the Board, or indications provided by the the data protection officer
# True
# 0.8
# The actual output provides specific guidance on how controllers and processors can identify and mitigate risks related to processing, aligning with the expected outcome. However, it does not explicitly mention approved codes of conduct, approved certifications, or guidelines provided by the Board, which are mentioned in the expected output.
#
# test_case_8
# What measures can a controller take to ensure compliance with the  Regulation?
# Based on the contextual data and reference knowledge graph, a controller can take the following measures to ensure compliance with the Regulation:
#
# 1. Implementing appropriate data protection policies.
# 2. Adhering to approved codes of conduct or certification mechanisms.
# 3. Implementing technical and organisational measures that are reviewed and updated as necessary.
#
# Additionally, the Regulation suggests that controllers should demonstrate their compliance by being able to show that processing is performed in accordance with the Regulation.
# The controller should adopt internal policies and implement measures which meet in particular the principles of data protection by design and data protection by default, such as minimising the processing of personal data, pseudonymising personal data as soon as possible, transparency with regard to the functions and processing of personal data, enabling the data subject to monitor the data processing, enabling the controller to create and improve security features.
# True
# 0.6
# The actual output provides some relevant measures for ensuring compliance with the Regulation, but lacks specific details on how to implement these measures. The expected output is more comprehensive in outlining the principles of data protection by design and default, including transparency and enabling monitoring. While the actual output mentions implementing technical and organisational measures, it does not provide a clear connection to the expected output's emphasis on minimising processing and pseudonymisation.
#
# test_case_9
# When developing, designing, selecting and using applications, services and products that are based on the processing of personal data or process personal data to fulfil their task, what should the producers of the products, services and applications be encouraged to do?
# Based on the provided contextual data and reference knowledge graph, when developing, designing, selecting, and using applications, services, and products that process personal data or process personal data to fulfill their task, producers of these products should be encouraged to carry out an assessment of the impact of the envisaged processing operations on the protection of personal data. This obligation applies where a type of processing in particular using new technologies is likely to result in a high risk to the rights and freedoms of natural persons.
#  take into account the right to data protection when developing and designing such products, services and applications and, with due regard to the state of the art, to make sure that controllers and processors are able to fulfil their data protection obligations.
# True
# 0.8
# The actual output aligns well with the expected output, as both emphasize the importance of considering data protection when developing products, services, and applications. The actual output provides a more detailed explanation of the obligation to assess the impact on personal data protection, which is not explicitly mentioned in the expected output. However, the core message of prioritizing data protection is present in both outputs.
#
# test_case_10
# What are the main reasons for allocating responsibilities under the Regulation?
# Based on the provided contextual data and reference knowledge graph, the main reasons for allocating responsibilities under the Regulation are:
#
# 1. Encouraging codes of conduct to contribute to the proper application of the Regulation.
# 2. Providing a framework for processing in specific sectors and catering to the needs of micro, small, and medium-sized enterprises.
# 3. Facilitating consultation and prior authorisation with the supervisory authority for certain types of processing.
#
# These reasons are reflected in the obligations outlined in the reference knowledge graph, such as the Board's duty to submit its opinion to the Commission where necessary.
# The protection of the rights and freedoms of data subjects as well as the responsibility and liability of controllers and processors, also in relation to the monitoring by and measures of supervisory authorities
# False
# 0.2
# The actual output provides some relevant details about the reasons for allocating responsibilities under the Regulation, but it does not directly address the expected outcome of protecting data subjects' rights and freedoms. The actual output focuses on the obligations outlined in the reference knowledge graph, whereas the expected output emphasizes the importance of monitoring by supervisory authorities.
#
# test_case_11
# When is it  necessary for a controller or processor to designate a representative?
# Based on the provided contextual data and reference knowledge graph, it is necessary for a controller or processor to designate a representative when:
#
# * The representative shall be established in one of the Member States where the data subjects are located (Article 27(1)).
# * The controller or processor is not established in the Union (Article 27(1), paragraph 2).
#
# In other words, a controller or processor must designate a representative if they are not based in the European Union, or if the data subjects whose personal data they process are located in the EU.
# in the case a controller or a processor not established in the Union is processing personal data of data subjects who are in the Union whose processing activities are related to the offering of goods or services, irrespective of whether a payment of the data subject is required, to such data subjects in the Union, or to the monitoring of their behaviour as far as their behaviour takes place within the Union
# True
# 0.9
# The actual output accurately summarizes the necessary conditions for a controller or processor to designate a representative, correctly referencing Article 27(1) of the GDPR. However, it does not fully align with the expected output as it only mentions two scenarios whereas the expected output provides additional circumstances that require a representative.
#
# test_case_12
# When is it not necessary for a controller or processor to designate a representative?
# Based on the provided contextual data, it is not necessary for a controller or processor to designate a representative in the following situations:
#
# 1. Occasional processing that does not include, on a large scale, processing of special categories of data or processing of personal data relating to criminal convictions and offences, and is unlikely to result in a risk to the rights and freedoms of natural persons.
# 2. A public authority or body.
#
# These exceptions are mentioned in Article 27(1) of the Regulation.
# The processing is occasional, does not include processing on a large scale, of special categories of personal data or the processing of personal data relating to criminal convictions and offences, and is unlikely to result in a risk to the rights and freedoms of natural persons, taking into account the nature, context, scope and purposes of the processing or if the controller is a public authority or body.
# True
# 0.9
# The actual output is well-structured and accurately summarizes the exceptions mentioned in Article 27(1) of the Regulation. The language used is clear and concise, mirroring the expected output's phrasing. However, there is a slight mismatch in wording between 'unlikely to result in a risk' and 'taking into account the nature, context, scope and purposes of the processing or if the controller is a public authority or body', which prevents a perfect score.
#
# test_case_13
# What is the obligations of the representative?
# According to the provided contextual data, the representative's obligations are:
#
# * To be established in one of the Member States where the data subjects are located.
# * To be mandated by the controller or processor to be addressed on all issues related to processing, for ensuring compliance with this Regulation.
#
# Additionally, the representative shall contain the purposes of the processing (as per the reference knowledge graph).
# the representative should act on behalf of the controller or the processor and may be addressed by any supervisory authority. The representative should be explicitly designated by a written mandate of the controller or of the processor to act on its behalf with regard to its obligations under this Regulation. The designation of such a representative does not affect the responsibility or liability of the controller or of the processor under this Regulation. Such a representative should perform its tasks according to the mandate received from the controller or processor, including cooperating with the competent supervisory authorities with regard to any action taken to ensure compliance with this Regulation. The designated representative should be subject to enforcement proceedings in the event of non-compliance by the controller or processor.
# False
# 0.2
# The actual output partially aligns with the expected output, as it mentions some of the representative's obligations, such as being established in a Member State or mandated by the controller. However, it lacks crucial details about the representative's role and responsibilities, specifically regarding its mandate to act on behalf of the controller or processor and cooperate with supervisory authorities.
#
# test_case_14
# What are some key factors a controller should consider when selecting a processor to ensure compliance with the Regulation?
# Based on the given contextual data and reference knowledge graph, some key factors a controller should consider when selecting a processor to ensure compliance with the Regulation are:
#
# 1. **Sufficient guarantees**: The processor must provide sufficient guarantees to implement appropriate technical and organisational measures.
# 2. **Meeting requirements of this Regulation**: The processor's measures must ensure that processing meets the requirements of the General Data Protection Regulation (GDPR).
# 3. **Protection of data subject rights**: The processor must ensure the protection of the rights of the data subjects, as required by the GDPR.
#
# These factors are crucial for a controller to consider when selecting a processor to ensure compliance with the GDPR and protect personal data.
# The controller should use only processors providing sufficient guarantees, in particular in terms of expert knowledge, reliability and resources, to implement technical and organisational measures which will meet the requirements of this Regulation
# True
# 0.9
# The actual output provides a clear and comprehensive list of key factors for selecting a processor, aligning well with the expected output. The output effectively highlights the importance of sufficient guarantees, meeting requirements, and protecting data subject rights, demonstrating strong understanding of the Regulation's requirements.
#
# test_case_15
# What should a contract or other legal act governing processing by a processor contain?
# According to the given contextual data, a contract or other legal act governing processing by a processor should contain:
#
# * The subject-matter and duration of the processing
# * The nature and purpose of the processing
# * The type of personal data and categories of data subjects
# * The obligations and rights of the controller
#
# These requirements are mentioned in paragraph 3.
# The contract or legal act should set out the subject-matter and duration of the processing, the nature and purposes of the processing, the type of personal data and categories of data subjects, taking into account the specific tasks and responsibilities of the processor in the context of the processing to be carried out and the risk to the rights and freedoms of the data subject.
# True
# 0.9
# The actual output accurately summarizes the requirements for a contract or legal act governing processing by a processor, including subject-matter and duration of processing, nature and purpose of processing, type of personal data and categories of data subjects. The only minor discrepancy is that the expected output provides more context about specific tasks and responsibilities of the processor, which is not explicitly mentioned in the actual output.
#
# test_case_16
# What are the options for controllers and processors when it comes to implementing data transfer agreements?
# Based on the provided contextual data and reference knowledge graph, controllers have two options for implementing data transfer agreements:
#
# 1. **Use only processors providing sufficient guarantees**: When processing is carried out on their behalf, controllers must use only processors that can provide sufficient guarantees to implement appropriate technical and organisational measures.
# 2. **Establish data protection certification mechanisms, seals or marks approved pursuant to paragraph 5 of this Article**: Controllers not subject to the Regulation may establish data protection certification mechanisms, seals, or marks to demonstrate the existence of appropriate safeguards for personal data transfers to third countries or international organisations.
#
# Additionally, codes of conduct approved under paragraph 5 of this Article can also be used by controllers and processors not subject to the Regulation to provide appropriate safeguards for such data transfers.
# The controller and processor may choose to use an individual contract or standard contractual clauses which are adopted either directly by the Commission or by a supervisory authority in accordance with the consistency mechanism and then adopted by the Commission.
# False
# 0.2
# The actual output does not directly address the expected outcome, which is about using individual contracts or standard contractual clauses. Instead, it provides two options for implementing data transfer agreements, which are relevant but do not align with the expected output.
#
# test_case_17
# What happens to personal data after processing is completed?
# According to the given contextual data, after processing is completed, "the processor at the choice of the controller, deletes or returns all the personal data to the controller after the end of the provision of services relating to processing, and deletes existing copies unless Union or Member State law requires storage of the personal data."
# The processor should, at the choice of the controller, return or delete the personal data, unless there is a requirement to store the personal data under Union or Member State law to which the processor is subject.
# True
# 0.9
# The actual output closely matches the expected output, with only minor differences in wording. The key point about the processor's responsibility to return or delete personal data at the controller's choice is accurately conveyed.
#
# test_case_18
# What type of records do controllers or processors need to maintain to demonstrate compliance with this Regulation?
# Based on the contextual data and reference knowledge graph, controllers or processors need to maintain records containing:
#
# * The name and contact details of the processor(s) and each controller they act on behalf of
# * The name and contact details of the data protection officer (where applicable)
#
# These records are necessary for demonstrating compliance with this Regulation and making them available to supervisory authorities upon request.
# Records of processing activities under its responsibility
# True
# 0.9
# The actual output accurately reflects the expected outcome, with a clear description of the records required for demonstrating compliance. The only minor discrepancy is that the expected output does not explicitly mention the processor(s) and data protection officer's contact details, which are included in the actual output.
#
# test_case_19
# What measures can a controller or processor take to mitigate the risks inherent in processing personal data?
# According to the reference knowledge graph and the given contextual data, controllers or processors can take the following measures to mitigate the risks inherent in processing personal data:
#
# * Carry out an assessment of the impact of the envisaged processing operations on the protection of personal data prior to the processing, where a type of processing is likely to result in a high risk to the rights and freedoms of natural persons.
# * Implement appropriate technical and organisational measures for ensuring that only personal data which are necessary for each specific purpose of the processing are processed, by default. This includes measures such as limiting the amount of personal data collected, the extent of their processing, the period of their storage, and their accessibility.
#
# These measures aim to ensure that personal data is protected from potential risks and that controllers or processors take a proactive approach to mitigating those risks.
# Measures such as encryption
# False
# 0.2
# The actual output provides a detailed explanation of measures to mitigate risks in processing personal data, but it does not directly address the expected measure 'Measures such as encryption'. While the actual output mentions implementing technical and organisational measures, it does not specifically mention encryption. The actual output also goes beyond the scope of the expected output by providing additional details on limiting data collection, processing, storage, and accessibility.
#
# test_case_20
# What is the responsibility of the controller when processing operations are likely to result in a high risk to the rights and freedoms of natural persons?
# According to the provided contextual data and reference knowledge graph, when processing operations are likely to result in a high risk to the rights and freedoms of natural persons, the **controller** shall **carry out an assessment of the impact of the envisaged processing operations on the protection of personal data**.
# The controller should be responsible for the carrying-out of a data protection impact assessment to evaluate the origin, nature and severity of that risk. Where a data-protection impact assessment indicates that processing operations involve a high risk which the controller cannot mitigate by appropriate measures, a consultation of the supervisory authority should take place prior to the processing.
# True
# 0.9
# The actual output closely matches the expected output, with both emphasizing the controller's responsibility in conducting a data protection impact assessment to evaluate the risk. The only minor difference is the wording used to describe the assessment and consultation process.
#
# test_case_21
# What is the requirement when a data-protection impact assessment identifies a high-risk processing operation that cannot be mitigated?
# According to the given contextual data and reference knowledge graph, when a data-protection impact assessment identifies a high-risk processing operation that cannot be mitigated, the requirement is that the controller shall consult the supervisory authority prior to processing. This is stated in Article 35.
# A consultation with the supervisory authority should take place prior to the processing.
# True
# 1.0
# The actual output accurately reflects the expected outcome, clearly stating that a consultation with the supervisory authority should take place prior to processing. The response demonstrates strong alignment with the evaluation steps, as it correctly identifies the requirement for high-risk processing operations and provides a clear explanation of the necessary action.
#
# test_case_22
# What are the potential consequences of not addressing a personal data breach in an appropriate and timely manner?
# According to the provided contextual data and reference knowledge graph, not addressing a personal data breach in an appropriate and timely manner can lead to:
#
# * Failure to notify the supervisory authority within 72 hours, which must be accompanied by reasons for the delay (Article 33(3)).
# * Potential risk to the rights and freedoms of natural persons.
# * Requirement to communicate the personal data breach to the data subject without undue delay when it's likely to result in a high risk to their rights and freedoms (Article 34).
#
# In summary, not addressing a personal data breach in an appropriate and timely manner can lead to non-compliance with regulations, potential harm to individuals' rights and freedoms, and reputational damage.
# loss of control over their personal data or limitation of their rights, discrimination, identity theft or fraud, financial loss, unauthorised reversal of pseudonymisation, damage to reputation, loss of confidentiality of personal data protected by professional secrecy or any other significant economic or social disadvantage
# True
# 0.8
# The actual output provides a clear explanation of the potential consequences of not addressing a personal data breach in an appropriate and timely manner, aligning with the expected outcome. However, it does not explicitly mention all the possible outcomes listed in the expected output, such as loss of control over their personal data or limitation of their rights.
#
# test_case_23
# What is the timeframe for notifying the supervisory authority about a personal data breach?
# According to the given contextual data, the timeframe for notifying the supervisory authority about a personal data breach is "not later than 72 hours after having become aware of it". This timeframe applies unless the personal data breach is unlikely to result in a risk to the rights and freedoms of natural persons.
# not later than 72 hours after having become aware of it
# True
# 1.0
# The actual output is identical to the expected output, accurately reflecting the timeframe for notifying the supervisory authority about a personal data breach. The response demonstrates strong alignment with the evaluation steps, as it matches the expected outcome and meets the criteria outlined in the expected output.
#
# test_case_24
# What happens if a notification cannot be completed within 72 hours?
# According to the given contextual data, if a notification cannot be completed within 72 hours, it shall be accompanied by reasons for the delay. This implies that while the 72-hour deadline is not met, the reason(s) for the delay must also be provided in addition to the notification.
# The reasons for the delay should accompany the notification and information may be provided in phases without undue further delay.
# True
# 0.8
# The actual output aligns well with the expected output, as both emphasize the importance of providing reasons for delays. However, the actual output does not explicitly mention that information may be provided in phases without undue further delay, which is a key aspect of the expected output.
#
# test_case_25
# What is the controller's responsibility when communicating a personal data breach to a data subject?
# According to the given contextual data, the controller's responsibility when communicating a personal data breach to a data subject is to do so "without undue delay" if the breach is likely to result in a high risk to the rights and freedoms of natural persons.
# The controller should communicate the personal data breach without undue delay, where it is likely to result in a high risk to the rights and freedoms of the natural person, to allow him or her to take necessary precautions.
# True
# 0.9
# The actual output closely matches the expected output, with both emphasizing the importance of timely communication in cases where a personal data breach poses a high risk to individuals' rights and freedoms. The only minor difference is the use of 'natural persons' versus 'him or her', but this does not detract from the overall alignment.
#
# test_case_26
# What information should a communication contain regarding a personal data breach?
# According to the provided contextual data, a communication regarding a personal data breach should contain at least the following information:
#
# 1. The nature of the personal data breach, including:
# 	* Categories and approximate number of data subjects concerned
# 	* Categories and approximate number of personal data records concerned (where possible)
# 2. Name and contact details of the data protection officer or other contact point where more information can be obtained
# 3. Likely consequences of the personal data breach
# 4. Measures taken or proposed to be taken by the controller to address the personal data breach, including measures to mitigate its possible adverse effects
# The communication should describe the nature of the personal data breach as well as recommendations for the natural person concerned to mitigate potential adverse effects.
# True
# 0.8
# The actual output provides a clear description of the personal data breach, including categories and approximate number of data subjects concerned, as well as measures taken or proposed to be taken by the controller. However, it lacks specific information on the likely consequences of the breach and does not provide recommendations for the natural person concerned to mitigate potential adverse effects.
#
# test_case_27
# What is the recommended timeframe for making communications to data subjects?
# The recommended timeframe for making communications to data subjects is "without undue delay" when the personal data breach is likely to result in a high risk to the rights and freedoms of natural persons. This is stated in the reference knowledge graph as an obligation of the controller, according to the GDPR.
# As soon as reasonably feasible and in close cooperation with the supervisory authority
# False
# 0.2
# The actual output partially aligns with the expected output, as it mentions a timeframe for making communications to data subjects. However, the specific phrase 'without undue delay' is not explicitly mentioned in the expected output, which suggests that the actual output does not fully meet the criteria outlined in the expected output.
#
# test_case_28
# What measures should be implemented to establish whether a personal data breach has taken place and to inform the supervisory authority and data subject promptly?
# According to the provided contextual data, the measures that should be implemented to establish whether a personal data breach has taken place and to inform the supervisory authority and data subject promptly are:
#
# 1. Monitor for potential breaches and become aware of them without undue delay.
# 2. Assess the likelihood of the breach resulting in a risk to the rights and freedoms of natural persons.
# 3. If the breach is likely to result in a risk, notify the supervisory authority competent in accordance with Article 55 within 72 hours after becoming aware of it.
#
# Additionally, if the notification is not made within 72 hours, provide reasons for the delay.
# All appropriate technological protection and organisational measures
# False
# 0.2
# The actual output does not align with the expected output, as it provides specific measures to establish a personal data breach, whereas the expected output is more general, focusing on technological protection and organisational measures. The actual output also includes details about notification timelines and reasons for delay, which are not present in the expected output.
#
# test_case_29
# What factors should be considered when setting rules for notification of personal data breaches?
# Based on the provided contextual data and reference knowledge graph, when setting rules for notification of personal data breaches, the following factors should be considered:
#
# 1. **Nature of the breach**: Describe the nature of the breach, including the categories and approximate number of data subjects concerned, categories and approximate number of personal data records concerned.
# 2. **Likely consequences**: Describe the likely consequences of the breach.
# 3. **Measures taken or proposed**: Describe the measures taken or proposed to address the breach, including those to mitigate its possible adverse effects.
# 4. **Timeframe for notification**: Ensure that notifications are made without undue delay and, where feasible, not later than 72 hours after becoming aware of the breach (unless the breach is unlikely to result in a risk to the rights and freedoms of natural persons).
# 5. **Risk assessment**: Consider whether the breach is likely to result in a high risk to the rights and freedoms of natural persons, which may trigger an obligation to notify the data subject.
#
# These factors should be taken into account when setting rules for notification of personal data breaches to ensure compliance with relevant regulations and effective communication with affected individuals.
# The circumstances of that breach, including whether or not personal data had been protected by appropriate technical protection measures, effectively limiting the likelihood of identity fraud or other forms of misuse.
# True
# 0.8
# The actual output provides a clear and comprehensive framework for setting rules on notification of personal data breaches, aligning with the expected output. However, it does not explicitly address whether personal data was protected by appropriate technical protection measures, which is an important consideration mentioned in the expected output.
#
# test_case_30
# What was the intention behind abolishing general notification obligations under Directive 95/46/EC?
# The intention behind abolishing general notification obligations under Directive 95/46/EC was to remove the requirement for controllers to notify personal data breaches to the supervisory authority. Instead, controllers are required to notify the breach directly to the individuals concerned (data subjects) and provide them with information about the nature of the breach, likely consequences, measures taken or proposed to be taken by the controller, and contact details of the data protection officer or other contact point where more information can be obtained.
# To replace them with effective procedures and mechanisms that focus on processing operations likely to result in a high risk to individuals' rights and freedoms. Such processing operations may involve new technologies or of a kind where no data protection has been carried out before
# True
# 0.8
# The actual output provides a clear explanation of the intention behind abolishing general notification obligations, aligning with the expected outcome. However, it does not explicitly mention replacing these obligations with effective procedures and mechanisms that focus on processing operations likely to result in a high risk to individuals' rights and freedoms, as stated in the expected output.
#
# test_case_31
# What factors should a controller consider when conducting a data protection impact assessment prior to processing?
# Based on the given contextual data and reference knowledge graph, the factors that a controller should consider when conducting a data protection impact assessment prior to processing are:
#
# * Whether the processing is performed in accordance with the data protection impact assessment at least when there is a change of risk represented by processing operations.
#
# Additionally, the following considerations may be relevant:
#
# * The potential risk represented by the processing operations (as indicated by a data protection impact assessment)
# * The need for measures to mitigate high risks identified during the assessment
# * Seeking advice from the data protection officer (if designated) when carrying out the assessment
#
# These factors should guide the controller's review and assessment of whether processing is performed in accordance with the data protection impact assessment, particularly when there is a change of risk represented by processing operations.
# The nature, scope, context, and purposes of the processing, as well as the sources of the risk. The assessment should include measures, safeguards and mechanisms for mitigating the risk
# True
# 0.8
# The actual output provides a clear and relevant discussion of the factors that a controller should consider when conducting a data protection impact assessment, including whether processing is performed in accordance with the assessment and potential risks. However, it does not explicitly mention the nature, scope, context, and purposes of the processing, as well as measures, safeguards, and mechanisms for mitigating risk, which are key aspects outlined in the expected output.
#
# test_case_32
# What types of processing operations would require a data protection impact assessment?
# According to the reference knowledge graph and the provided contextual data, a Data Protection Impact Assessment (DPIA) would be required for:
#
# * A systematic and extensive evaluation of personal aspects relating to natural persons which is based on automated processing, including profiling, and on which decisions are based that produce legal effects concerning the natural person or similarly significantly affect the natural person.
# * Processing on a large scale of special categories of data referred to in Article 9(1) or of personal data relating to criminal convictions and offences referred to in Article 10.
# * A systematic monitoring of a publicly accessible area on a large scale.
# Processing operations that aim to process a considerable amount of personal data at regional, national or supranational level and which could affect a large number of data subjects and which are likely to result in a high risk, for example, on account of their sensitivity, where in accordance with the achieved state of technological knowledge a new technology is used on a large scale.
# True
# 0.8
# The actual output provides a clear explanation of the scenarios that require a Data Protection Impact Assessment (DPIA), aligning with the expected outcome. The actual output is specific, detailed, and relevant to the parameters provided. However, it does not exactly match the expected output in terms of phrasing and scope.
#
# test_case_33
# What types of data require a protection impact assessment?
# Based on the contextual data and the reference knowledge graph, the types of data that require a data protection impact assessment are:
#
# * Personal aspects relating to natural persons which are based on automated processing, including profiling, and produce legal effects or significantly affect the natural person.
# * Special categories of data referred to in Article 9(1) processed on a large scale.
# * Personal data relating to criminal convictions and offences referred to in Article 10 processed on a large scale.
# * Data that is subject to systematic monitoring of a publicly accessible area on a large scale.
#
# These types of data require a data protection impact assessment as they involve high-risk processing activities, such as profiling, processing sensitive data, or monitoring public areas.
# Personal data processed for taking decisions regarding specific natural persons, including profiling, as well as special categories of personal data, biometric data, or data on criminal convictions and offences or related security measures
# True
# 0.8
# The actual output provides a clear and detailed explanation of the types of data that require a data protection impact assessment, aligning with the expected outcome. While it does not exactly match the expected output in terms of wording, the concepts and categories mentioned are largely identical. The only deviation is the inclusion of 'systematic monitoring of a publicly accessible area' which is not explicitly mentioned in the expected output.
#
# test_case_34
# When would a data protection impact assessment be required for monitoring publicly accessible areas?
# According to the given contextual data, a data protection impact assessment would be required in case of "a systematic monitoring of a publicly accessible area on a large scale."
# Especially when using optic-electronic devices or when the competent supervisory authority considers that the processing is likely to result in a high risk to the rights and freedoms of data subjects, in particular because they prevent data subjects from exercising a right or using a service or a contract, or because they are carried out systematically on a large scale.
# True
# 0.8
# The actual output is mostly aligned with the expected output, as it correctly identifies a situation that would require a data protection impact assessment. However, the actual output does not fully capture the nuances of the expected output, particularly regarding the use of optic-electronic devices and the role of the competent supervisory authority in determining high-risk scenarios.
#
# test_case_35
# Under what circumstances may the scope of a data protection impact assessment be broader than a single project?
# According to the contextual data, a data protection impact assessment may have a broader scope than a single project under circumstances (a), (b), or (c) as listed:
#
# * (a): Systematic and extensive evaluation of personal aspects relating to natural persons based on automated processing, including profiling, and producing legal effects.
# * (b): Processing on a large scale of special categories of data or personal data relating to criminal convictions and offenses.
# * (c): Systematic monitoring of a publicly accessible area on a large scale.
#
# In these cases, the scope of the assessment is broader than a single project as it involves complex processing operations that require a comprehensive evaluation of their impact on individuals.
# There are circumstances under which it may be reasonable and economical for the subject of a data protection impact assessment to be broader than a single project, for example where public authorities or bodies intend to establish a common application or processing platform or where several controllers plan to introduce a common application or processing environment across an industry sector or segment or for a widely used horizontal activity.
# True
# 0.8
# The actual output provides a clear explanation of the circumstances under which a data protection impact assessment may have a broader scope than a single project, aligning with the expected outcome. However, it does not explicitly mention public authorities or bodies establishing a common application or processing platform, as mentioned in the expected output.
#
# test_case_36
# What provision allows Member States to conduct an assessment prior to processing activities?
# Based on the provided contextual data and reference knowledge graph, the provision that allows Member States to conduct an assessment prior to processing activities is:
#
# "Where processing pursuant to point (c) or (e) of Article 6 (1) has a legal basis in Union law or in the law of the Member State to which the controller is subject, that law regulates the specific processing operation or set of operations in question, and a data protection impact assessment has already been carried out as part of a general impact assessment in the context of the adoption of that legal basis, paragraphs 1 to 7 shall not apply unless Member States deem it to be necessary to carry out such an assessment prior to processing activities."
#
# This provision allows Member States to conduct an assessment prior to processing activities if they deem it necessary, under certain conditions.
# In the context of the adoption of the Member State law on which the performance of the tasks of the public authority or public body is based and which regulates the specific processing operation or set of operations in question
# True
# 0.9
# The actual output accurately reflects the expected outcome by highlighting the provision that allows Member States to conduct an assessment prior to processing activities, aligning with the expected output's context of adopting Member State law. The actual output also provides specific conditions for conducting such assessments, which is not explicitly mentioned in the expected output but is a crucial aspect of the evaluation steps.
#
# test_case_37
# What are the circumstances under which the controller is required to consult with the supervisory authority prior to starting data processing activities?
# According to the given contextual data, the controller is required to consult with the supervisory authority prior to starting data processing activities under the following circumstances:
#
# * When consulting the supervisory authority pursuant to paragraph 1 (Article 36), the controller shall provide the supervisory authority with information regarding the intended processing.
# * In cases where Member State law requires controllers to consult with, and obtain prior authorisation from, the supervisory authority in relation to processing by a controller for the performance of a task carried out by the controller in the public interest.
#
# In other words, the controller is required to consult with the supervisory authority before starting data processing activities if they are involved in joint controllership or processing within a group of undertakings, or if the processing is related to social protection and public health.
# Where a data protection impact assessment indicates that the processing would, in the absence of safeguards, security measures and mechanisms to mitigate the risk, result in a high risk to the rights and freedoms of natural persons and the controller is of the opinion that the risk cannot be mitigated by reasonable means in terms of available technologies and costs of implementation.
# False
# 0.2
# The actual output does not directly address the expected outcome, which is related to data protection impact assessments and mitigation of risks. Instead, it provides general information about when a controller should consult with the supervisory authority. While there may be some overlap between the two, they are distinct concepts.
#
# test_case_38
# How should the supervisory authority respond to the request for a consultation?
# According to the given contextual data, when the supervisory authority is of the opinion that the intended processing would infringe this Regulation, it shall:
#
# * Provide written advice to the controller and, where applicable, the processor within a period of up to eight weeks of receipt of the request for consultation.
# * May use any of its powers referred to in Article 58.
#
# Additionally, if the request for consultation is complex, the supervisory authority may extend this period by six weeks, informing the controller and, where applicable, the processor of the extension within one month of receipt of the request, together with the reasons for the delay.
# The supervisory authority should respond to the request for consultation within a certain period. However the absence of a response should be without prejudice to any intervention of the supervisory authority
# True
# 0.8
# The actual output provides a clear and detailed response to the request for consultation, including specific timeframes and procedures. While it does not exactly match the expected output in terms of tone (the expected output is more concise), the actual output's level of detail and clarity aligns well with the evaluation steps.
#
# test_case_39
# What is the processor's role in assisting the controller with data protection impact assessments?
# Based on the provided contextual data and reference knowledge graph, the processor's role in assisting the controller with data protection impact assessments is to take into due account the data processing operations performed by the controller when assessing the impact of those operations. This obligation is specified in Article 40 of the reference knowledge graph.
# The processor should assist the controller, where necessary and upon request, in ensuring compliance with the obligations deriving from the carrying out of data protection impact assessments
# True
# 0.9
# The actual output accurately reflects the expected outcome, aligning with the evaluation steps. The response effectively summarizes the processor's role in assisting the controller with data protection impact assessments, referencing Article 40 of the reference knowledge graph. While minor adjustments could be made for clarity and concision, the overall alignment with the expected output is strong.
#
# test_case_40
# What is the purpose of consulting the supervisory authority when preparing a legislative or regulatory measure that involves personal data processing?
# The purpose of consulting the supervisory authority when preparing a legislative or regulatory measure that involves personal data processing is to provide the authority with relevant information about the intended processing, such as the purposes and means of processing, measures to protect data subjects' rights and freedoms, and contact details of the data protection officer. This consultation aims to ensure that the proposed measure complies with relevant data protection regulations and safeguards the rights of individuals whose personal data will be processed.
# To ensure compliance with this Regulation and mitigate the risk involved for the data subject
# True
# 0.8
# The actual output provides a clear explanation of the purpose of consulting the supervisory authority, including relevant details about the intended processing. However, it does not directly address the expected outcome of ensuring compliance with the Regulation and mitigating risk to data subjects.
#
# test_case_41
# what type of entities require assistance from a person with expert knowledge of data protection law and practices?
# According to the contextual data, a group of undertakings requires assistance from a person with expert knowledge of data protection law and practices.
# a public authority, except for courts or independent judicial authorities when acting in their judicial capacity; the private sector, where processing is carried out by a controller whose core activities consist of processing operations that require regular and systematic monitoring of the data subjects on a large scale, or where the core activities of the controller or the processor consist of processing on a large scale of special categories of personal data and data relating to criminal convictions and offences
# False
# 0.2
# The actual output does not match the expected output in terms of specificity. While it mentions a group of undertakings requiring assistance, it lacks the detailed criteria outlined in the expected output, such as public authorities and private sector entities with specific core activities.
#
# test_case_42
# What factors determine the necessary level of expert knowledge?
# According to the provided contextual data, the necessary level of expert knowledge for a Data Protection Officer (DPO) is determined by their professional qualities and "expert knowledge of data protection law and practices". This suggests that the DPO must possess specialized knowledge in the field of data protection law and practices to effectively fulfill their tasks.
# The necessary level of expert knowledge should be determined in particular according to the data processing operations carried out and the protection required for the personal data processed by the controller or the processor.
# False
# 0.2
# The actual output partially aligns with the expected output by mentioning expert knowledge of data protection law and practices as a requirement for a Data Protection Officer. However, it does not consider the specific data processing operations carried out and the protection required for personal data processed by the controller or processor, which is a crucial aspect in determining the necessary level of expert knowledge.
#
# test_case_43
# What are associations or other bodies representing categories of controllers or processors encouraged to do under this Regulation?
# According to the provided contextual data, associations and other bodies representing categories of controllers or processors are encouraged to:
#
# * Maintain a record of all categories of processing activities carried out on behalf of each controller.
# * The record should contain:
# 	+ Categories of processing carried out on behalf of each controller.
# 	+ Name and contact details of the processor or processors and of each controller on behalf of which the processor is acting, as well as the data protection officer (where applicable).
# 	+ A general description of the technical and organisational security measures referred to in Article 32(1) (where possible).
#
# These obligations are mentioned in the contextual data provided.
# draw up codes of conduct, within the limits of this Regulation
# False
# 0.2
# The actual output does not align with the expected output, as it discusses maintaining records of processing activities and providing contact details, whereas the expected output is to draw up codes of conduct. The actual output also provides specific details about the record's contents, which are not mentioned in the expected output.
#
# test_case_44
# What steps should associations and other bodies take when drawing up a code of conduct, or amending or extending one?
# Based on the contextual data, when drawing up a code of conduct, or amending or extending one, associations and other bodies should:
#
# * Submit the draft code, amendment or extension to the supervisory authority which is competent pursuant to Article 55.
# * Provide an opinion from the supervisory authority on whether the draft code, amendment or extension complies with this Regulation.
#
# This information can be found in the first paragraph of the contextual data.
# Associations and other bodies should consult relevant stakeholders, including data subjects where feasible, and have regard to submissions received and views expressed in response to such consultations.
# False
# 0.2
# The actual output does not align with the expected output. The actual output discusses submitting a draft code to a supervisory authority, whereas the expected output emphasizes consulting relevant stakeholders and having regard to their submissions.
#
# test_case_45
# What is the goal of encouraging certification mechanisms and data protection seals and marks in the context of this Regulation?
# The goal of encouraging certification mechanisms and data protection seals and marks is to demonstrate compliance with this Regulation for processing operations by controllers and processors.
# To enhance transparency and compliance with this Regulation
# False
# 0.2
# The actual output partially aligns with the expected output, as it mentions certification mechanisms and data protection seals, but does not explicitly state enhancing transparency. The actual output also includes additional information about demonstrating compliance with the Regulation.
#
# number Correctness successful:33
